# %% [markdown]
# # **Data Loading & Preprocessing**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
""" # get all ES_part_X files, 1 up to 5 and place in one df_es dataframe
df_es = pd.DataFrame()
for i in range(1, 6):
    df_temp = pd.read_csv(f'ES_part_{i}.csv')
    df_es = pd.concat([df_es, df_temp], ignore_index=True)
"""
# Out:
# " # get all ES_part_X files, 1 up to 5 and place in one df_es dataframe\ndf_es = pd.DataFrame()\nfor i in range(1, 6):\n    df_temp = pd.read_csv(f'ES_part_{i}.csv')\n    df_es = pd.concat([df_es, df_temp], ignore_index=True)\n"

# %%
"""

"""

df_es = pd.read_csv('/content/ES.csv')
df_es.drop(columns=['High', 'Low', 'Tick Count'], inplace=True)
# !git clone https://github.com/AditxML/Data-Science-Seminar-Group-Project-5.git
# Out:
# Cloning into 'Data-Science-Seminar-Group-Project-5'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 83 (delta 19), reused 12 (delta 6), pack-reused 42 (from 2)
# Receiving objects: 100% (83/83), 100.89 MiB | 6.69 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
"""

"""
# Out:
# '\n\n'

# %%
"""

"""
df_surprise = pd.read_csv('/content/Data-Science-Seminar-Group-Project-5/US_economic_releases_events.csv')
# Out:
# <ipython-input-5-bb98b893da65>:4: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_surprise = pd.read_csv('/content/Data-Science-Seminar-Group-Project-5/US_economic_releases_events.csv')

# %%
df_es
# Out:
#                Date   Time     Open    Close  Volume
# 0        09/10/1997  00:01     0.00     0.00       0
# 1        09/10/1997  00:02     0.00     0.00       0
# 2        09/10/1997  00:03     0.00     0.00       0
# 3        09/10/1997  00:04     0.00     0.00       0
# 4        09/10/1997  00:05     0.00     0.00       0
# ...             ...    ...      ...      ...     ...
# 9682630  12/19/2024  15:56  5941.75  5941.75     318
# 9682631  12/19/2024  15:57  5941.75  5941.50     386
# 9682632  12/19/2024  15:58  5941.50  5941.00     484
# 9682633  12/19/2024  15:59  5940.75  5941.00    6462
# 9682634  12/19/2024  16:00  5941.00  5941.25    8864
#
# [9682635 rows x 5 columns]

# %%
"""
df_surprise = pd.read_csv('US_economic_releases_events.csv')
"""
# Out:
# "\ndf_surprise = pd.read_csv('US_economic_releases_events.csv')\n"

# %%
df_surprise
# Out:
#        Unnamed: 0 Period                             Event          Ticker  \
# 0      1997-01-02    Dec                 ISM Manufacturing   NAPMPMI Index
# 1      1997-01-03    Nov             Construction Spending   VNCCTOT Index
# 2      1997-01-06    Dec               Housing Completions  PHUCCHNG Index
# 3      1997-01-07    Nov                    Factory Orders  TMNOCHNG Index
# 4      1997-01-08    Dec                   Consumer Credit   CICRTOT Index
# ...           ...    ...                               ...             ...
# 36053  2024-12-31    Oct        FHFA House Price Index MoM  HPIMMOM% Index
# 36054  2024-12-31    Oct   S&P CoreLogic CS 20-City MoM SA  SPCS20SM Index
# 36055  2024-12-31    Oct  S&P CoreLogic CS 20-City YoY NSA  SPCS20Y% Index
# 36056  2024-12-31    Oct   S&P CoreLogic CS US HPI YoY NSA  SPCSUSAY Index
# 36057  2024-12-31    Dec      Dallas Fed Services Activity  DSERGBCC Index
#
#         Actual    Prior Revised         S Freq. First Rev.  ... Month Surv(A)  \
# 0         55.2       53      --  94.81480     M         --  ...   Jan      --
# 1         1.9$     1.8$    1.5$   0.00000     M       1.5$  ...   Jan  -0.40$
# 2           2k      -1k      --   0.00000     M         --  ...   Jan      --
# 3       -0.004    0.009   0.011  84.44440     M      0.011  ...   Jan  -0.007
# 4      $7.400b  $2.200b      --  42.96300     M         --  ...   Jan  $3.60b
# ...        ...      ...     ...       ...   ...        ...  ...   ...     ...
# 36053       --    0.007      --  68.88890     M         --  ...   Dec      --
# 36054       --   0.0018      --  30.37040     M         --  ...   Dec      --
# 36055       --   0.0457      --  40.74070     M         --  ...   Dec      --
# 36056       --   0.0389      --  35.55560     M         --  ...   Dec      --
# 36057       --      9.8      --   5.92593     M         --  ...   Dec      --
#
#       Surv(H) Surv(L) Surv(M) # Ests.  Std Dev Surprise Country/Region  \
# 0          --      --      --     0.0       --       --  United States
# 1          --      --  -0.40$     0.0       --       --  United States
# 2          --      --      --     0.0       --       --  United States
# 3          --      --  -0.007     0.0       --       --  United States
# 4          --      --  $3.60b     0.0       --       --  United States
# ...       ...     ...     ...     ...      ...      ...            ...
# 36053      --      --      --     0.0       --       --  United States
# 36054      --      --      --     1.0       --       --  United States
# 36055      --      --      --     1.0       --       --  United States
# 36056      --      --      --     0.0       --       --  United States
# 36057      --      --      --     0.0       --       --  United States
#
#                 Flag
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...
# 36053  United States
# 36054  United States
# 36055  United States
# 36056  United States
# 36057  United States
#
# [36058 rows x 28 columns]

# %%
df_surprise.drop(columns=['S', 'Month', 'Surv(A)', 'Surv(H)', 'Surv(L)',], inplace=True)

# %%
df_surprise.columns
# Out:
# Index(['Unnamed: 0', 'Period', 'Event', 'Ticker', 'Actual', 'Prior', 'Revised',
#        'Freq.', 'First Rev.', 'Last Rev.', 'Date', 'Time', 'C', 'Category',
#        'Subcategory', 'R', 'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise',
#        'Country/Region', 'Flag'],
#       dtype='object')

# %%
df_surprise.drop(columns=['Flag', 'Country/Region', 'Day', 'C', 'Category','Subcategory', 'Std Dev', 'Period', 'Actual'])
# Out:
#        Unnamed: 0                             Event          Ticker    Prior  \
# 0      1997-01-02                 ISM Manufacturing   NAPMPMI Index       53
# 1      1997-01-03             Construction Spending   VNCCTOT Index     1.8$
# 2      1997-01-06               Housing Completions  PHUCCHNG Index      -1k
# 3      1997-01-07                    Factory Orders  TMNOCHNG Index    0.009
# 4      1997-01-08                   Consumer Credit   CICRTOT Index  $2.200b
# ...           ...                               ...             ...      ...
# 36053  2024-12-31        FHFA House Price Index MoM  HPIMMOM% Index    0.007
# 36054  2024-12-31   S&P CoreLogic CS 20-City MoM SA  SPCS20SM Index   0.0018
# 36055  2024-12-31  S&P CoreLogic CS 20-City YoY NSA  SPCS20Y% Index   0.0457
# 36056  2024-12-31   S&P CoreLogic CS US HPI YoY NSA  SPCSUSAY Index   0.0389
# 36057  2024-12-31      Dallas Fed Services Activity  DSERGBCC Index      9.8
#
#       Revised Freq. First Rev. Last Rev.                 Date      Time  \
# 0          --     M         --        --  1997-01-02 00:00:00  09:00:00
# 1        1.5$     M       1.5$        --  1997-01-03 00:00:00  09:00:00
# 2          --     M         --        --  1997-01-06 00:00:00  09:00:00
# 3       0.011     M      0.011    -0.001  1997-01-07 00:00:00  09:00:00
# 4          --     M         --   $6.064b  1997-01-08 00:00:00  14:00:00
# ...       ...   ...        ...       ...                  ...       ...
# 36053      --     M         --        --  2024-12-31 00:00:00  08:00:00
# 36054      --     M         --        --  2024-12-31 00:00:00  08:00:00
# 36055      --     M         --        --  2024-12-31 00:00:00  08:00:00
# 36056      --     M         --        --  2024-12-31 00:00:00  08:00:00
# 36057      --     M         --        --  2024-12-31 00:00:00  09:30:00
#
#               R Surv(M)  # Ests. Surprise
# 0      94.81480      --      0.0       --
# 1       0.00000  -0.40$      0.0       --
# 2       0.00000      --      0.0       --
# 3      84.44440  -0.007      0.0       --
# 4      42.96300  $3.60b      0.0       --
# ...         ...     ...      ...      ...
# 36053  68.88890      --      0.0       --
# 36054  30.37040      --      1.0       --
# 36055  40.74070      --      1.0       --
# 36056  35.55560      --      0.0       --
# 36057   5.92593      --      0.0       --
#
# [36058 rows x 14 columns]

# %%
# Dropping all rows for which surprise column has NaN or 0 value
df_surprise.dropna(subset=['Surprise'], inplace=True)
df_surprise = df_surprise[df_surprise['Surprise'] != 0]

# %%
nan_count = df_surprise['Surprise'].isnull().sum()
print(f"Number of NaN values in 'Surprise' column: {nan_count}")
# Out:
# Number of NaN values in 'Surprise' column: 0

# %%
print(df_surprise.isna().sum())
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                 0
# Revised               0
# Freq.                 0
# First Rev.            0
# Last Rev.             0
# Date                  0
# Time                325
# C                     0
# Category              0
# Subcategory       35186
# R                     0
# Day                  25
# Surv(M)               0
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
df_surprise.replace("--", pd.NA, inplace=True)


print(df_surprise.isna().sum())
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual              987
# Prior               980
# Revised           17228
# Freq.                 0
# First Rev.        17228
# Last Rev.         10752
# Date                  0
# Time                325
# C                     0
# Category              0
# Subcategory       35186
# R                     0
# Day                  25
# Surv(M)            6942
# # Ests.               0
# Std Dev            7539
# Surprise           8564
# Country/Region        0
# Flag                  0
# dtype: int64
# <ipython-input-15-e7436ed75a58>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_surprise.replace("--", pd.NA, inplace=True)

# %%
# Redoing dropping all rows for which surprise column has NaN or 0 value
df_surprise.dropna(subset=['Surprise'], inplace=True)
df_surprise = df_surprise[df_surprise['Surprise'] != 0]

# %%
df_surprise
# Out:
#        Unnamed: 0               Period                                  Event  \
# 8      1997-01-10                  Dec                      Unemployment Rate
# 153    1997-06-25                 1Q F                     GDP Annualized QoQ
# 198    1997-08-01                  Jul             Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                     GDP Annualized QoQ
# 523    1998-03-26                 4Q F                     GDP Annualized QoQ
# ...           ...                  ...                                    ...
# 35998  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Current Yr
# 35999  2024-12-18  2024-12-18 00:00:00     FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00      FOMC Median Rate Forecast: +2 Yrs
# 36001  2024-12-18  2024-12-18 00:00:00      FOMC Median Rate Forecast: +3 Yrs
# 36002  2024-12-18  2024-12-18 00:00:00    FOMC Median Rate Forecast: Long-Run
#
#                Ticker   Actual    Prior Revised Freq. First Rev. Last Rev.  \
# 8       USURTOT Index    0.053    0.054   0.053     M      0.053      <NA>
# 153    GDP CQOQ Index    0.059    0.058    <NA>     Q       <NA>      <NA>
# 198     NFP TCH Index     316k     217k    228k     M       228k      265k
# 394    GDP CQOQ Index    0.031    0.033    <NA>     Q       <NA>     0.051
# 523    GDP CQOQ Index    0.037    0.039    <NA>     Q       <NA>      <NA>
# ...               ...      ...      ...     ...   ...        ...       ...
# 35998  DOTDY0MD Index  0.04375  0.04375    <NA>     D       <NA>      <NA>
# 35999  DOTDY1MD Index  0.03875  0.03375    <NA>     D       <NA>      <NA>
# 36000  DOTDY2MD Index  0.03375  0.02875    <NA>     D       <NA>      <NA>
# 36001  DOTDY3MD Index  0.03125  0.02875    <NA>     D       <NA>      <NA>
# 36002  DOTDLTMD Index     0.03  0.02875    <NA>     D       <NA>      <NA>
#
#        ...           Category Subcategory          R  Day  Surv(M)  # Ests.  \
# 8      ...  Economic Releases         NaN  89.333300  Fri    0.053     10.0
# 153    ...  Economic Releases         NaN  96.296300  Wed    0.058     13.0
# 198    ...  Economic Releases         NaN  99.259300  Fri      70k     20.0
# 394    ...  Economic Releases         NaN  96.296300  Tue    0.033     11.0
# 523    ...  Economic Releases         NaN  96.296300  Thu    0.039     22.0
# ...    ...                ...         ...        ...  ...      ...      ...
# 35998  ...  Economic Releases         NaN   2.962960  Wed  0.04375      9.0
# 35999  ...  Economic Releases         NaN   2.222220  Wed  0.03625     12.0
# 36000  ...  Economic Releases         NaN   0.740741  Wed  0.03125     11.0
# 36001  ...  Economic Releases         NaN   0.000000  Wed  0.03125     11.0
# 36002  ...  Economic Releases         NaN   1.481480  Wed     0.03     11.0
#
#       Std Dev Surprise  Country/Region           Flag
# 8        0.07        0   United States  United States
# 153      0.22     0.45   United States  United States
# 198     33.84     7.27   United States  United States
# 394      0.07    -2.98   United States  United States
# 523      0.08    -2.52   United States  United States
# ...       ...      ...             ...            ...
# 35998       0        0   United States  United States
# 35999    0.12     2.03   United States  United States
# 36000    0.11     2.35   United States  United States
# 36001    0.08        0   United States  United States
# 36002    0.06        0   United States  United States
#
# [26622 rows x 23 columns]

# %%
# We suspected that 0s were not being filtered out because the data type of the surprise column was an object and thus converting it to float and then redoing
# the filtering should help and it did

# Convert 'Surprise' column to float
df_surprise['Surprise'] = pd.to_numeric(df_surprise['Surprise'], errors='coerce')

# Again filtering out rows where 'Surprise' is 0 or NaN
df_surprise = df_surprise[df_surprise['Surprise'] != 0].dropna(subset=['Surprise'])

df_surprise
# Out:
#        Unnamed: 0               Period                               Event  \
# 153    1997-06-25                 1Q F                  GDP Annualized QoQ
# 198    1997-08-01                  Jul          Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                  GDP Annualized QoQ
# 523    1998-03-26                 4Q F                  GDP Annualized QoQ
# 569    1998-04-30                 1Q A                  GDP Annualized QoQ
# ...           ...                  ...                                 ...
# 35992  2024-12-18                Nov P                    Building Permits
# 35993  2024-12-18                Nov P                Building Permits MoM
# 35994  2024-12-18                   3Q             Current Account Balance
# 35999  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00   FOMC Median Rate Forecast: +2 Yrs
#
#                Ticker    Actual     Prior   Revised Freq. First Rev.  \
# 153    GDP CQOQ Index     0.059     0.058      <NA>     Q       <NA>
# 198     NFP TCH Index      316k      217k      228k     M       228k
# 394    GDP CQOQ Index     0.031     0.033      <NA>     Q       <NA>
# 523    GDP CQOQ Index     0.037     0.039      <NA>     Q       <NA>
# 569    GDP CQOQ Index     0.042     0.037      <NA>     Q       <NA>
# ...               ...       ...       ...       ...   ...        ...
# 35992  NHSPATOT Index     1505k     1416k     1419k     M      1419k
# 35993  NHCHATCH Index     0.061    -0.006    -0.004     M     -0.004
# 35994   USCABAL Index  -$310.9b  -$266.8b  -$275.0b     Q   -$275.0b
# 35999  DOTDY1MD Index   0.03875   0.03375      <NA>     D       <NA>
# 36000  DOTDY2MD Index   0.03375   0.02875      <NA>     D       <NA>
#
#       Last Rev.  ...           Category Subcategory          R  Day   Surv(M)  \
# 153        <NA>  ...  Economic Releases         NaN  96.296300  Wed     0.058
# 198        265k  ...  Economic Releases         NaN  99.259300  Fri       70k
# 394       0.051  ...  Economic Releases         NaN  96.296300  Tue     0.033
# 523        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.039
# 569        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.034
# ...         ...  ...                ...         ...        ...  ...       ...
# 35992     1419k  ...  Economic Releases         NaN  61.185200  Wed     1430k
# 35993    -0.004  ...  Economic Releases         NaN  31.851900  Wed      0.01
# 35994  -$275.0b  ...  Economic Releases         NaN  71.111100  Wed  -$287.1b
# 35999      <NA>  ...  Economic Releases         NaN   2.222220  Wed   0.03625
# 36000      <NA>  ...  Economic Releases         NaN   0.740741  Wed   0.03125
#
#        # Ests. Std Dev Surprise  Country/Region           Flag
# 153       13.0    0.22     0.45   United States  United States
# 198       20.0   33.84     7.27   United States  United States
# 394       11.0    0.07    -2.98   United States  United States
# 523       22.0    0.08    -2.52   United States  United States
# 569       19.0    0.36     2.22   United States  United States
# ...        ...     ...      ...             ...            ...
# 35992     46.0   22.21     3.38   United States  United States
# 35993     46.0    1.78     2.87   United States  United States
# 35994     18.0    6.22    -3.84   United States  United States
# 35999     12.0    0.12     2.03   United States  United States
# 36000     11.0    0.11     2.35   United States  United States
#
# [23715 rows x 23 columns]

# %%
# Seeing if anything looks weird to see what else to filter out eg. Time having missing values despite surprises being non missing values is now problematic for
# our analysis so we should get rid of it and number of subcategory missings are equal to total number of current observations so can also get rid of that column
print(df_surprise.isna().sum())
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            9125
# Freq.                 0
# First Rev.         9125
# Last Rev.          4439
# Date                  0
# Time                310
# C                     0
# Category              0
# Subcategory       23715
# R                     0
# Day                  23
# Surv(M)               2
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
df_surprise.dropna(subset=['Time'], inplace=True)

df_surprise
# Out:
#        Unnamed: 0               Period                               Event  \
# 153    1997-06-25                 1Q F                  GDP Annualized QoQ
# 198    1997-08-01                  Jul          Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                  GDP Annualized QoQ
# 523    1998-03-26                 4Q F                  GDP Annualized QoQ
# 569    1998-04-30                 1Q A                  GDP Annualized QoQ
# ...           ...                  ...                                 ...
# 35992  2024-12-18                Nov P                    Building Permits
# 35993  2024-12-18                Nov P                Building Permits MoM
# 35994  2024-12-18                   3Q             Current Account Balance
# 35999  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00   FOMC Median Rate Forecast: +2 Yrs
#
#                Ticker    Actual     Prior   Revised Freq. First Rev.  \
# 153    GDP CQOQ Index     0.059     0.058      <NA>     Q       <NA>
# 198     NFP TCH Index      316k      217k      228k     M       228k
# 394    GDP CQOQ Index     0.031     0.033      <NA>     Q       <NA>
# 523    GDP CQOQ Index     0.037     0.039      <NA>     Q       <NA>
# 569    GDP CQOQ Index     0.042     0.037      <NA>     Q       <NA>
# ...               ...       ...       ...       ...   ...        ...
# 35992  NHSPATOT Index     1505k     1416k     1419k     M      1419k
# 35993  NHCHATCH Index     0.061    -0.006    -0.004     M     -0.004
# 35994   USCABAL Index  -$310.9b  -$266.8b  -$275.0b     Q   -$275.0b
# 35999  DOTDY1MD Index   0.03875   0.03375      <NA>     D       <NA>
# 36000  DOTDY2MD Index   0.03375   0.02875      <NA>     D       <NA>
#
#       Last Rev.  ...           Category Subcategory          R  Day   Surv(M)  \
# 153        <NA>  ...  Economic Releases         NaN  96.296300  Wed     0.058
# 198        265k  ...  Economic Releases         NaN  99.259300  Fri       70k
# 394       0.051  ...  Economic Releases         NaN  96.296300  Tue     0.033
# 523        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.039
# 569        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.034
# ...         ...  ...                ...         ...        ...  ...       ...
# 35992     1419k  ...  Economic Releases         NaN  61.185200  Wed     1430k
# 35993    -0.004  ...  Economic Releases         NaN  31.851900  Wed      0.01
# 35994  -$275.0b  ...  Economic Releases         NaN  71.111100  Wed  -$287.1b
# 35999      <NA>  ...  Economic Releases         NaN   2.222220  Wed   0.03625
# 36000      <NA>  ...  Economic Releases         NaN   0.740741  Wed   0.03125
#
#        # Ests. Std Dev Surprise  Country/Region           Flag
# 153       13.0    0.22     0.45   United States  United States
# 198       20.0   33.84     7.27   United States  United States
# 394       11.0    0.07    -2.98   United States  United States
# 523       22.0    0.08    -2.52   United States  United States
# 569       19.0    0.36     2.22   United States  United States
# ...        ...     ...      ...             ...            ...
# 35992     46.0   22.21     3.38   United States  United States
# 35993     46.0    1.78     2.87   United States  United States
# 35994     18.0    6.22    -3.84   United States  United States
# 35999     12.0    0.12     2.03   United States  United States
# 36000     11.0    0.11     2.35   United States  United States
#
# [23405 rows x 23 columns]

# %%
print(df_surprise.isna().sum())

# Based on the output below let's next observe the two missing values for Surv(M), specifically looking at their Surprise column values to see if anything is striking, if it is
# then we'll drop those two rows. This is because in principle Surv(M) should not have missing values given that Surprise has none and is a function of Surv(M)
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            8820
# Freq.                 0
# First Rev.         8820
# Last Rev.          4265
# Date                  0
# Time                  0
# C                     0
# Category              0
# Subcategory       23405
# R                     0
# Day                   0
# Surv(M)               2
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
rows_with_missing_survm = df_surprise[df_surprise['Surv(M)'].isnull()]
rows_with_missing_survm
# Out:
#      Unnamed: 0 Period                       Event          Ticker Actual  \
# 816  1998-10-15    Sep                     PPI MoM  PPI CHNG Index  0.003
# 817  1998-10-15    Sep  PPI Ex Food and Energy MoM  PXFECHNG Index  0.004
#
#       Prior Revised Freq. First Rev. Last Rev.  ...           Category  \
# 816  -0.004    <NA>     M       <NA>    -0.002  ...  Economic Releases
# 817  -0.001    <NA>     M       <NA>         0  ...  Economic Releases
#
#     Subcategory    R  Day  Surv(M)  # Ests. Std Dev     Surprise  \
# 816         NaN  0.0  Thu     <NA>     36.0    0.05  21213370.81
# 817         NaN  0.0  Thu     <NA>     34.0    0.05  21213372.93
#
#      Country/Region           Flag
# 816   United States  United States
# 817   United States  United States
#
# [2 rows x 23 columns]

# %%
# Based on the output above let's see what the average, IQR and max is for the surprise column to see if surprise values of 21213370.81 and 21213372.93 are troubling
# and should thus be removed

df_surprise['Surprise'].describe()
# Out:
# count    2.340500e+04
# mean     4.521226e+03
# std      2.374934e+05
# min     -8.167000e+01
# 25%     -1.520000e+00
# 50%     -1.000000e-02
# 75%      1.550000e+00
# max      2.121337e+07
# Name: Surprise, dtype: float64

# %%
# Let's actually plot a histogram of those values to identify if the values above are outliers

plt.hist(df_surprise['Surprise'], bins=20)
plt.xlabel('Surprise')
plt.ylabel('Frequency')
plt.title('Histogram of Surprise Values')
plt.ticklabel_format(axis='x', style='sci', scilimits=(1,1))
plt.show()

# by using ticklabel_format and scilimits here we can see (although not obvious from the graph) that there are outliers as the scale of the x-axis hasn't automatically adjusted to be being around -10 to 10

# %%
# Wincorsizing to get results between 0.5% and 99.5% percentile for Surprise values

lower_bound = df_surprise['Surprise'].quantile(0.005)
upper_bound = df_surprise['Surprise'].quantile(0.995)

df_surprise = df_surprise[(df_surprise['Surprise'] >= lower_bound) & (df_surprise['Surprise'] <= upper_bound)]

# %%
plt.hist(df_surprise['Surprise'], bins=20)
plt.xlabel('Surprise')
plt.ylabel('Frequency')
plt.title('Histogram of Surprise Values')
plt.ticklabel_format(axis='x', style='sci', scilimits=(1,1))
plt.show()

# Now the scale has automatically adjusted to being between -10 and 10 so outliers are removed, also we notice that surprises are quite normally distributed

# %%
# Let's now print the 10 rows with the largest Surprise values to see if anything looks abnormal - and it doesn't, as expected max values are around 10

df_surprise.nlargest(10, 'Surprise')
# Out:
#        Unnamed: 0               Period                           Event  \
# 2456   2001-04-18                  Feb                   Trade Balance
# 32474  2023-01-13                Jan P  U. of Mich. Current Conditions
# 14287  2012-05-31                  May                   ISM Milwaukee
# 26021  2019-05-17                May P        U. of Mich. Expectations
# 4815   2004-06-25                 1Q F              GDP Price Deflator
# 22353  2017-05-11                  Apr  PPI Ex Food, Energy, Trade MoM
# 12370  2011-01-05                  Dec           ADP Employment Change
# 34665  2024-03-28                Mar F  U. of Mich. Current Conditions
# 7542   2007-02-15  2024-02-10 00:00:00          Initial Jobless Claims
# 34457  2024-02-16                  Jan  PPI Ex Food, Energy, Trade MoM
#
#                Ticker   Actual    Prior Revised Freq. First Rev. Last Rev.  \
# 2456    USTBTOT Index  -$27.0b  -$33.3b    <NA>     M       <NA>   -$35.2b
# 32474  CONSCURR Index     68.6     59.4    <NA>     M       <NA>      <NA>
# 14287  MAPMINDX Index     57.7     52.9    <NA>     M       <NA>      <NA>
# 26021   CONSEXP Index       96     87.4    <NA>     M       <NA>      <NA>
# 4815   GDP DCHG Index    0.029    0.026    <NA>     Q       <NA>      <NA>
# 22353  FDIDSGUM Index    0.007    0.001    <NA>     M       <NA>     0.001
# 12370  ADP CHNG Index     297k      93k     92k     M        92k      240k
# 34665  CONSCURR Index     82.5     79.4    <NA>     M       <NA>      <NA>
# 7542     INJCJC Index     357k     311k    313k     W       313k      310k
# 34457  FDIDSGUM Index    0.006    0.002   0.003     M      0.003     0.003
#
#        ...           Category Subcategory        R  Day  Surv(M)  # Ests.  \
# 2456   ...  Economic Releases         NaN  82.9630  Wed  -$33.0b     40.0
# 32474  ...  Economic Releases         NaN  21.4815  Fri       60      5.0
# 14287  ...  Economic Releases         NaN   0.0000  Thu     53.4      3.0
# 26021  ...  Economic Releases         NaN  23.7037  Fri     86.8      3.0
# 4815   ...  Economic Releases         NaN   0.0000  Fri    0.026     47.0
# 22353  ...  Economic Releases         NaN  22.9630  Thu    0.002      8.0
# 12370  ...  Economic Releases         NaN  90.3704  Wed     100k     33.0
# 34665  ...  Economic Releases         NaN  21.4815  Thu     79.6      3.0
# 7542   ...  Economic Releases         NaN  98.5185  Thu     314k     39.0
# 34457  ...  Economic Releases         NaN  22.9630  Fri    0.001      9.0
#
#       Std Dev Surprise  Country/Region           Flag
# 2456     0.57    10.58   United States  United States
# 32474    0.82    10.54   United States  United States
# 14287    0.41    10.46   United States  United States
# 26021    0.88    10.45   United States  United States
# 4815     0.03    10.39   United States  United States
# 22353    0.05    10.33   United States  United States
# 12370   19.15    10.29   United States  United States
# 34665    0.28    10.25   United States  United States
# 7542      4.2    10.23   United States  United States
# 34457    0.05    10.06   United States  United States
#
# [10 rows x 23 columns]

# %%
df_surprise.columns
# Out:
# Index(['Unnamed: 0', 'Period', 'Event', 'Ticker', 'Actual', 'Prior', 'Revised',
#        'Freq.', 'First Rev.', 'Last Rev.', 'Date', 'Time', 'C', 'Category',
#        'Subcategory', 'R', 'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise',
#        'Country/Region', 'Flag'],
#       dtype='object')

# %%
df_surprise[['Date','Time']]
# Out:
#                       Date      Time
# 153    1997-06-25 00:00:00  07:30:00
# 198    1997-08-01 00:00:00  07:30:00
# 394    1997-12-23 00:00:00  07:30:00
# 523    1998-03-26 00:00:00  07:30:00
# 569    1998-04-30 00:00:00  07:30:00
# ...                    ...       ...
# 35992  2024-12-18 00:00:00  07:30:00
# 35993  2024-12-18 00:00:00  07:30:00
# 35994  2024-12-18 00:00:00  07:30:00
# 35999  2024-12-18 00:00:00  13:00:00
# 36000  2024-12-18 00:00:00  13:00:00
#
# [23169 rows x 2 columns]

# %%
# Step 1: Ensure columns are strings
df_surprise['Date'] = df_surprise['Date'].astype(str)
df_surprise['Time'] = df_surprise['Time'].astype(str)

# Step 2: Handle missing times (if any)
df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')

# Step 3: Combine Date and Time into DateTime
df_surprise['DateTime'] = pd.to_datetime(
    df_surprise['Date'].str[:10] + ' ' + df_surprise['Time'],
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'  # Converts invalid parsing to NaT instead of raising error
)

# Step 4: Verify the new column
print("\nFirst 5 rows of DateTime column:")
print(df_surprise['DateTime'].head())

# Step 5: Check for any parsing errors (NaT values)
print("\nNumber of invalid DateTime entries:")
print(df_surprise['DateTime'].isna().sum())
# Out:
# First 5 rows of DateTime column:
# 153   1997-06-25 07:30:00
# 198   1997-08-01 07:30:00
# 394   1997-12-23 07:30:00
# 523   1998-03-26 07:30:00
# 569   1998-04-30 07:30:00
# Name: DateTime, dtype: datetime64[ns]
#
# Number of invalid DateTime entries:
# 464
# <ipython-input-30-4ffcbc2525d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Date'] = df_surprise['Date'].astype(str)
# <ipython-input-30-4ffcbc2525d6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].astype(str)
# <ipython-input-30-4ffcbc2525d6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')
# <ipython-input-30-4ffcbc2525d6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['DateTime'] = pd.to_datetime(

# %%
# Strangely we get NaN values for DateTime so we next look into why that is
df_surprise.isna().sum()
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            8690
# Freq.                 0
# First Rev.         8690
# Last Rev.          4186
# Date                  0
# Time                  0
# C                     0
# Category              0
# Subcategory       23169
# R                     0
# Day                   0
# Surv(M)               0
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# DateTime            464
# dtype: int64

# %%
# To do so we print the rows for which DateTime was NaN and we see the Date variable is weirdly formatted
nan_rows = df_surprise[df_surprise['DateTime'].isna()]
nan_rows[['Date','Time']]
# Out:
#            Date      Time
# 1583  01/03/000  09:00:00
# 1585  01/04/000  09:00:00
# 1587  01/05/000  09:00:00
# 1588  01/05/000  09:00:00
# 1590  01/06/000  07:30:00
# ...         ...       ...
# 2245  12/22/000  09:00:00
# 2248  12/28/000  07:30:00
# 2249  12/28/000  09:00:00
# 2250  12/28/000  09:00:00
# 2251  12/29/000  09:00:00
#
# [464 rows x 2 columns]

# %%
# The first column is also a Date column and looks more appropriate from the output below so let's use that instead to create our DateTime variable
nan_rows[['Date','Unnamed: 0']]
# Out:
#            Date  Unnamed: 0
# 1583  01/03/000  2000-01-03
# 1585  01/04/000  2000-01-04
# 1587  01/05/000  2000-01-05
# 1588  01/05/000  2000-01-05
# 1590  01/06/000  2000-01-06
# ...         ...         ...
# 2245  12/22/000  2000-12-22
# 2248  12/28/000  2000-12-28
# 2249  12/28/000  2000-12-28
# 2250  12/28/000  2000-12-28
# 2251  12/29/000  2000-12-29
#
# [464 rows x 2 columns]

# %%
# First we drop Date and DateTime and change the column name for Unnamed: 0 to Date

df_surprise.drop(columns=['Date', 'DateTime'], inplace=True)
df_surprise.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
df_surprise.columns
# Out:
# <ipython-input-34-d4942771fab2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise.drop(columns=['Date', 'DateTime'], inplace=True)
# <ipython-input-34-d4942771fab2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
# Index(['Date', 'Period', 'Event', 'Ticker', 'Actual', 'Prior', 'Revised',
#        'Freq.', 'First Rev.', 'Last Rev.', 'Time', 'C', 'Category',
#        'Subcategory', 'R', 'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise',
#        'Country/Region', 'Flag'],
#       dtype='object')

# %%
# Now let's again create a DateTime column with the new Date column and check for number of NaN values
# Step 1: Ensure columns are strings
df_surprise['Date'] = df_surprise['Date'].astype(str)
df_surprise['Time'] = df_surprise['Time'].astype(str)

# Step 2: Handle missing times (if any)
df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')

# Step 3: Combine Date and Time into DateTime
df_surprise['DateTime'] = pd.to_datetime(
    df_surprise['Date'].str[:10] + ' ' + df_surprise['Time'],
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'  # Converts invalid parsing to NaT instead of raising error
)

df_surprise.isna().sum()

# Our new variable has no NaN values and is thus appropriate for the next part of our analysis
# Out:
# <ipython-input-35-e668f83518d7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Date'] = df_surprise['Date'].astype(str)
# <ipython-input-35-e668f83518d7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].astype(str)
# <ipython-input-35-e668f83518d7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')
# <ipython-input-35-e668f83518d7>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['DateTime'] = pd.to_datetime(
# Date                  0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            8690
# Freq.                 0
# First Rev.         8690
# Last Rev.          4186
# Time                  0
# C                     0
# Category              0
# Subcategory       23169
# R                     0
# Day                   0
# Surv(M)               0
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# DateTime              0
# dtype: int64

# %%
df_surprise
# Out:
#              Date               Period                               Event  \
# 153    1997-06-25                 1Q F                  GDP Annualized QoQ
# 198    1997-08-01                  Jul          Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                  GDP Annualized QoQ
# 523    1998-03-26                 4Q F                  GDP Annualized QoQ
# 569    1998-04-30                 1Q A                  GDP Annualized QoQ
# ...           ...                  ...                                 ...
# 35992  2024-12-18                Nov P                    Building Permits
# 35993  2024-12-18                Nov P                Building Permits MoM
# 35994  2024-12-18                   3Q             Current Account Balance
# 35999  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00   FOMC Median Rate Forecast: +2 Yrs
#
#                Ticker    Actual     Prior   Revised Freq. First Rev.  \
# 153    GDP CQOQ Index     0.059     0.058      <NA>     Q       <NA>
# 198     NFP TCH Index      316k      217k      228k     M       228k
# 394    GDP CQOQ Index     0.031     0.033      <NA>     Q       <NA>
# 523    GDP CQOQ Index     0.037     0.039      <NA>     Q       <NA>
# 569    GDP CQOQ Index     0.042     0.037      <NA>     Q       <NA>
# ...               ...       ...       ...       ...   ...        ...
# 35992  NHSPATOT Index     1505k     1416k     1419k     M      1419k
# 35993  NHCHATCH Index     0.061    -0.006    -0.004     M     -0.004
# 35994   USCABAL Index  -$310.9b  -$266.8b  -$275.0b     Q   -$275.0b
# 35999  DOTDY1MD Index   0.03875   0.03375      <NA>     D       <NA>
# 36000  DOTDY2MD Index   0.03375   0.02875      <NA>     D       <NA>
#
#       Last Rev.  ... Subcategory          R  Day   Surv(M)  # Ests. Std Dev  \
# 153        <NA>  ...         NaN  96.296300  Wed     0.058     13.0    0.22
# 198        265k  ...         NaN  99.259300  Fri       70k     20.0   33.84
# 394       0.051  ...         NaN  96.296300  Tue     0.033     11.0    0.07
# 523        <NA>  ...         NaN  96.296300  Thu     0.039     22.0    0.08
# 569        <NA>  ...         NaN  96.296300  Thu     0.034     19.0    0.36
# ...         ...  ...         ...        ...  ...       ...      ...     ...
# 35992     1419k  ...         NaN  61.185200  Wed     1430k     46.0   22.21
# 35993    -0.004  ...         NaN  31.851900  Wed      0.01     46.0    1.78
# 35994  -$275.0b  ...         NaN  71.111100  Wed  -$287.1b     18.0    6.22
# 35999      <NA>  ...         NaN   2.222220  Wed   0.03625     12.0    0.12
# 36000      <NA>  ...         NaN   0.740741  Wed   0.03125     11.0    0.11
#
#       Surprise  Country/Region           Flag            DateTime
# 153       0.45   United States  United States 1997-06-25 07:30:00
# 198       7.27   United States  United States 1997-08-01 07:30:00
# 394      -2.98   United States  United States 1997-12-23 07:30:00
# 523      -2.52   United States  United States 1998-03-26 07:30:00
# 569       2.22   United States  United States 1998-04-30 07:30:00
# ...        ...             ...            ...                 ...
# 35992     3.38   United States  United States 2024-12-18 07:30:00
# 35993     2.87   United States  United States 2024-12-18 07:30:00
# 35994    -3.84   United States  United States 2024-12-18 07:30:00
# 35999     2.03   United States  United States 2024-12-18 13:00:00
# 36000     2.35   United States  United States 2024-12-18 13:00:00
#
# [23169 rows x 23 columns]

# %%
# Now let's do the same for df_es

df_es
# Out:
#                Date   Time     Open    Close  Volume
# 0        09/10/1997  00:01     0.00     0.00       0
# 1        09/10/1997  00:02     0.00     0.00       0
# 2        09/10/1997  00:03     0.00     0.00       0
# 3        09/10/1997  00:04     0.00     0.00       0
# 4        09/10/1997  00:05     0.00     0.00       0
# ...             ...    ...      ...      ...     ...
# 9682630  12/19/2024  15:56  5941.75  5941.75     318
# 9682631  12/19/2024  15:57  5941.75  5941.50     386
# 9682632  12/19/2024  15:58  5941.50  5941.00     484
# 9682633  12/19/2024  15:59  5940.75  5941.00    6462
# 9682634  12/19/2024  16:00  5941.00  5941.25    8864
#
# [9682635 rows x 5 columns]

# %%
df_es.isna().sum()
# Out:
# Date      0
# Time      0
# Open      0
# Close     0
# Volume    0
# dtype: int64

# %%
# Step 1: Ensure columns are strings
df_es['Date'] = df_es['Date'].astype(str)
df_es['Time'] = df_es['Time'].astype(str)

# Step 2: Handle missing times (if any) and pad with seconds
df_es['Time'] = df_es['Time'].fillna('00:00')  # Fill missing times
df_es['Time'] = df_es['Time'] + ':00'  # Add seconds to make HH:MM:SS format

# Step 3: Combine Date and Time into DateTime with correct format
df_es['DateTime'] = pd.to_datetime(
    df_es['Date'] + ' ' + df_es['Time'],
    format='%m/%d/%Y %H:%M:%S',  # Matches MM/DD/YYYY date and HH:MM:SS time
    errors='coerce'
)

# Count NaN values in each column
print(df_es.isna().sum())
# Out:
# Date        0
# Time        0
# Open        0
# Close       0
# Volume      0
# DateTime    0
# dtype: int64

# %%
df_es
# Out:
#                Date      Time     Open    Close  Volume            DateTime
# 0        09/10/1997  00:01:00     0.00     0.00       0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00     0.00     0.00       0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00     0.00     0.00       0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00     0.00     0.00       0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00     0.00     0.00       0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9682630  12/19/2024  15:56:00  5941.75  5941.75     318 2024-12-19 15:56:00
# 9682631  12/19/2024  15:57:00  5941.75  5941.50     386 2024-12-19 15:57:00
# 9682632  12/19/2024  15:58:00  5941.50  5941.00     484 2024-12-19 15:58:00
# 9682633  12/19/2024  15:59:00  5940.75  5941.00    6462 2024-12-19 15:59:00
# 9682634  12/19/2024  16:00:00  5941.00  5941.25    8864 2024-12-19 16:00:00
#
# [9682635 rows x 6 columns]

# %%
# Now we create the merged dataframe for our analysis - to allow us to match times of surprise with the price of the future at the time
df_combined = pd.merge(
    df_es,
    df_surprise,
    on='DateTime',
    how='outer',
    suffixes=('_es', '_surprise'),
    indicator=True  # this shows the source of each using suffix
)

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 0               NaN       NaN      NaN      NaN     NaN 1997-06-25 07:30:00
# 1               NaN       NaN      NaN      NaN     NaN 1997-08-01 07:30:00
# 2        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 3        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 4        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695761  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695762  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695763  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695764  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695765  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period                       Event          Ticker  ...  \
# 0          1997-06-25   1Q F          GDP Annualized QoQ  GDP CQOQ Index  ...
# 1          1997-08-01    Jul  Change in Nonfarm Payrolls   NFP TCH Index  ...
# 2                 NaN    NaN                         NaN             NaN  ...
# 3                 NaN    NaN                         NaN             NaN  ...
# 4                 NaN    NaN                         NaN             NaN  ...
# ...               ...    ...                         ...             ...  ...
# 9695761           NaN    NaN                         NaN             NaN  ...
# 9695762           NaN    NaN                         NaN             NaN  ...
# 9695763           NaN    NaN                         NaN             NaN  ...
# 9695764           NaN    NaN                         NaN             NaN  ...
# 9695765           NaN    NaN                         NaN             NaN  ...
#
#         Subcategory        R  Day Surv(M) # Ests. Std Dev Surprise  \
# 0               NaN  96.2963  Wed   0.058    13.0    0.22     0.45
# 1               NaN  99.2593  Fri     70k    20.0   33.84     7.27
# 2               NaN      NaN  NaN     NaN     NaN     NaN      NaN
# 3               NaN      NaN  NaN     NaN     NaN     NaN      NaN
# 4               NaN      NaN  NaN     NaN     NaN     NaN      NaN
# ...             ...      ...  ...     ...     ...     ...      ...
# 9695761         NaN      NaN  NaN     NaN     NaN     NaN      NaN
# 9695762         NaN      NaN  NaN     NaN     NaN     NaN      NaN
# 9695763         NaN      NaN  NaN     NaN     NaN     NaN      NaN
# 9695764         NaN      NaN  NaN     NaN     NaN     NaN      NaN
# 9695765         NaN      NaN  NaN     NaN     NaN     NaN      NaN
#
#         Country/Region           Flag      _merge
# 0        United States  United States  right_only
# 1        United States  United States  right_only
# 2                  NaN            NaN   left_only
# 3                  NaN            NaN   left_only
# 4                  NaN            NaN   left_only
# ...                ...            ...         ...
# 9695761            NaN            NaN   left_only
# 9695762            NaN            NaN   left_only
# 9695763            NaN            NaN   left_only
# 9695764            NaN            NaN   left_only
# 9695765            NaN            NaN   left_only
#
# [9695766 rows x 29 columns]

# %%
df_combined.isna().sum()
# Out:
# Date_es               101
# Time_es               101
# Open                  101
# Close                 101
# Volume                101
# DateTime                0
# Date_surprise     9672597
# Period            9672597
# Event             9672597
# Ticker            9672597
# Actual            9672597
# Prior             9672616
# Revised           9681287
# Freq.             9672597
# First Rev.        9681287
# Last Rev.         9676783
# Time_surprise     9672597
# C                 9672597
# Category          9672597
# Subcategory       9695766
# R                 9672597
# Day               9672597
# Surv(M)           9672597
# # Ests.           9672597
# Std Dev           9672597
# Surprise          9672597
# Country/Region    9672597
# Flag              9672597
# _merge                  0
# dtype: int64

# %%
# Some surprise announcements might have come before the starting point for the data on the futures, these would be meaningless for our analysis and should thus
# be removed by removing all rows with NaN values for Open

df_combined.dropna(subset=['Open'], inplace=True)

df_combined.isna().sum()
# Out:
# Date_es                 0
# Time_es                 0
# Open                    0
# Close                   0
# Volume                  0
# DateTime                0
# Date_surprise     9672597
# Period            9672597
# Event             9672597
# Ticker            9672597
# Actual            9672597
# Prior             9672616
# Revised           9681231
# Freq.             9672597
# First Rev.        9681231
# Last Rev.         9676757
# Time_surprise     9672597
# C                 9672597
# Category          9672597
# Subcategory       9695665
# R                 9672597
# Day               9672597
# Surv(M)           9672597
# # Ests.           9672597
# Std Dev           9672597
# Surprise          9672597
# Country/Region    9672597
# Flag              9672597
# _merge                  0
# dtype: int64

# %%
# Upon analysing our combined dataframe again we now see that it all looks good

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 2        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 3        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 4        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 5        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 6        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695761  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695762  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695763  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695764  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695765  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ... Subcategory   R  Day Surv(M)  \
# 2                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 3                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 4                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 5                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 6                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# ...               ...    ...   ...    ...  ...         ...  ..  ...     ...
# 9695761           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695762           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695763           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695764           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695765           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
#
#         # Ests. Std Dev Surprise Country/Region Flag     _merge
# 2           NaN     NaN      NaN            NaN  NaN  left_only
# 3           NaN     NaN      NaN            NaN  NaN  left_only
# 4           NaN     NaN      NaN            NaN  NaN  left_only
# 5           NaN     NaN      NaN            NaN  NaN  left_only
# 6           NaN     NaN      NaN            NaN  NaN  left_only
# ...         ...     ...      ...            ...  ...        ...
# 9695761     NaN     NaN      NaN            NaN  NaN  left_only
# 9695762     NaN     NaN      NaN            NaN  NaN  left_only
# 9695763     NaN     NaN      NaN            NaN  NaN  left_only
# 9695764     NaN     NaN      NaN            NaN  NaN  left_only
# 9695765     NaN     NaN      NaN            NaN  NaN  left_only
#
# [9695665 rows x 29 columns]

# %% [markdown]
# # **Creating a naive benchmark strategy that trades whenever a surprise occurs - comparing this with our more sophisticated strategies should show the importance of only trading on surprises in significant determinants of asset returns**

# %%
# First we create an indicator variable with a value True if the column for Surprise is non-missing for that row

df_combined['Surprise Occurred'] = df_combined['Surprise'].notna()

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 2        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 3        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 4        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 5        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 6        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695761  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695762  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695763  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695764  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695765  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ...   R  Day Surv(M) # Ests.  \
# 2                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 3                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 4                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 5                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 6                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# ...               ...    ...   ...    ...  ...  ..  ...     ...     ...
# 9695761           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695762           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695763           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695764           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695765           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
#
#         Std Dev Surprise Country/Region Flag     _merge  Surprise Occurred
# 2           NaN      NaN            NaN  NaN  left_only              False
# 3           NaN      NaN            NaN  NaN  left_only              False
# 4           NaN      NaN            NaN  NaN  left_only              False
# 5           NaN      NaN            NaN  NaN  left_only              False
# 6           NaN      NaN            NaN  NaN  left_only              False
# ...         ...      ...            ...  ...        ...                ...
# 9695761     NaN      NaN            NaN  NaN  left_only              False
# 9695762     NaN      NaN            NaN  NaN  left_only              False
# 9695763     NaN      NaN            NaN  NaN  left_only              False
# 9695764     NaN      NaN            NaN  NaN  left_only              False
# 9695765     NaN      NaN            NaN  NaN  left_only              False
#
# [9695665 rows x 30 columns]

# %%
df_combined.isna().sum()
# Out:
# Date_es                    0
# Time_es                    0
# Open                       0
# Close                      0
# Volume                     0
# DateTime                   0
# Date_surprise        9672597
# Period               9672597
# Event                9672597
# Ticker               9672597
# Actual               9672597
# Prior                9672616
# Revised              9681231
# Freq.                9672597
# First Rev.           9681231
# Last Rev.            9676757
# Time_surprise        9672597
# C                    9672597
# Category             9672597
# Subcategory          9695665
# R                    9672597
# Day                  9672597
# Surv(M)              9672597
# # Ests.              9672597
# Std Dev              9672597
# Surprise             9672597
# Country/Region       9672597
# Flag                 9672597
# _merge                     0
# Surprise Occurred          0
# dtype: int64

# %%
# count the number of times the Surprise Occurred variable is True and False
df_combined['Surprise Occurred'].value_counts()
# Out:
# Surprise Occurred
# False    9672597
# True       23068
# Name: count, dtype: int64

# %%
# Same number of False values for the new surprise variables as original surprise variable
# so the new variables were correctly created
df_combined[df_combined['Surprise Occurred'] == False].count()
# Out:
# Date_es              9672597
# Time_es              9672597
# Open                 9672597
# Close                9672597
# Volume               9672597
# DateTime             9672597
# Date_surprise              0
# Period                     0
# Event                      0
# Ticker                     0
# Actual                     0
# Prior                      0
# Revised                    0
# Freq.                      0
# First Rev.                 0
# Last Rev.                  0
# Time_surprise              0
# C                          0
# Category                   0
# Subcategory                0
# R                          0
# Day                        0
# Surv(M)                    0
# # Ests.                    0
# Std Dev                    0
# Surprise                   0
# Country/Region             0
# Flag                       0
# _merge               9672597
# Surprise Occurred    9672597
# dtype: int64

# %%
# Lets now create a new indicator called First Post Surprise which takes a value or true for being the first minute level observation after a surprise occurs
# i.e. right after the Surprise Occurred variable take a value of True this should take a value of True



df_combined['First Post Surprise'] = df_combined['Surprise Occurred'].shift(1)
df_combined['First Post Surprise'].iloc[0] = False

df_combined
# Out:
# <ipython-input-49-b73d1a85a455>:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_combined['First Post Surprise'].iloc[0] = False
# <ipython-input-49-b73d1a85a455>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined['First Post Surprise'].iloc[0] = False
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 2        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 3        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 4        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 5        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 6        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695761  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695762  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695763  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695764  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695765  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ...  Day Surv(M) # Ests. Std Dev  \
# 2                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 3                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 4                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 5                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 6                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# ...               ...    ...   ...    ...  ...  ...     ...     ...     ...
# 9695761           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695762           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695763           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695764           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695765           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
#
#         Surprise Country/Region Flag     _merge Surprise Occurred  \
# 2            NaN            NaN  NaN  left_only             False
# 3            NaN            NaN  NaN  left_only             False
# 4            NaN            NaN  NaN  left_only             False
# 5            NaN            NaN  NaN  left_only             False
# 6            NaN            NaN  NaN  left_only             False
# ...          ...            ...  ...        ...               ...
# 9695761      NaN            NaN  NaN  left_only             False
# 9695762      NaN            NaN  NaN  left_only             False
# 9695763      NaN            NaN  NaN  left_only             False
# 9695764      NaN            NaN  NaN  left_only             False
# 9695765      NaN            NaN  NaN  left_only             False
#
#          First Post Surprise
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# ...                      ...
# 9695761                False
# 9695762                False
# 9695763                False
# 9695764                False
# 9695765                False
#
# [9695665 rows x 31 columns]

# %%
# print df combined where columsn surprise occurred and first post surprise are true, 1 of them true is enough to show row
df_combined[(df_combined['Surprise Occurred'] == True) | (df_combined['First Post Surprise'] == True)]
# Out:
#             Date_es   Time_es     Open    Close   Volume            DateTime  \
# 102676   12/23/1997  07:30:00  1189.71  1189.71      0.0 1997-12-23 07:30:00
# 102677   12/23/1997  07:31:00  1189.40  1189.09      0.0 1997-12-23 07:31:00
# 191131   03/26/1998  07:30:00  1355.65  1355.96      0.0 1998-03-26 07:30:00
# 191132   03/26/1998  07:31:00  1355.96  1355.04      0.0 1998-03-26 07:31:00
# 224731   04/30/1998  07:30:00  1338.85  1338.85      0.0 1998-04-30 07:30:00
# ...             ...       ...      ...      ...      ...                 ...
# 9693874  12/18/2024  07:30:00  6145.50  6145.75    131.0 2024-12-18 07:30:00
# 9693875  12/18/2024  07:31:00  6145.50  6145.25    305.0 2024-12-18 07:31:00
# 9694204  12/18/2024  13:00:00  6135.75  6136.00    801.0 2024-12-18 13:00:00
# 9694205  12/18/2024  13:00:00  6135.75  6136.00    801.0 2024-12-18 13:00:00
# 9694206  12/18/2024  13:01:00  6136.25  6120.50  13401.0 2024-12-18 13:01:00
#
#         Date_surprise               Period  \
# 102676     1997-12-23                 3Q F
# 102677            NaN                  NaN
# 191131     1998-03-26                 4Q F
# 191132            NaN                  NaN
# 224731     1998-04-30                 1Q A
# ...               ...                  ...
# 9693874    2024-12-18                   3Q
# 9693875           NaN                  NaN
# 9694204    2024-12-18  2024-12-18 00:00:00
# 9694205    2024-12-18  2024-12-18 00:00:00
# 9694206           NaN                  NaN
#
#                                       Event          Ticker  ...  Day  \
# 102676                   GDP Annualized QoQ  GDP CQOQ Index  ...  Tue
# 102677                                  NaN             NaN  ...  NaN
# 191131                   GDP Annualized QoQ  GDP CQOQ Index  ...  Thu
# 191132                                  NaN             NaN  ...  NaN
# 224731                   GDP Annualized QoQ  GDP CQOQ Index  ...  Thu
# ...                                     ...             ...  ...  ...
# 9693874             Current Account Balance   USCABAL Index  ...  Wed
# 9693875                                 NaN             NaN  ...  NaN
# 9694204  FOMC Median Rate Forecast: Next Yr  DOTDY1MD Index  ...  Wed
# 9694205   FOMC Median Rate Forecast: +2 Yrs  DOTDY2MD Index  ...  Wed
# 9694206                                 NaN             NaN  ...  NaN
#
#           Surv(M) # Ests. Std Dev Surprise Country/Region           Flag  \
# 102676      0.033    11.0    0.07    -2.98  United States  United States
# 102677        NaN     NaN     NaN      NaN            NaN            NaN
# 191131      0.039    22.0    0.08    -2.52  United States  United States
# 191132        NaN     NaN     NaN      NaN            NaN            NaN
# 224731      0.034    19.0    0.36     2.22  United States  United States
# ...           ...     ...     ...      ...            ...            ...
# 9693874  -$287.1b    18.0    6.22    -3.84  United States  United States
# 9693875       NaN     NaN     NaN      NaN            NaN            NaN
# 9694204   0.03625    12.0    0.12     2.03  United States  United States
# 9694205   0.03125    11.0    0.11     2.35  United States  United States
# 9694206       NaN     NaN     NaN      NaN            NaN            NaN
#
#             _merge Surprise Occurred  First Post Surprise
# 102676        both              True                False
# 102677   left_only             False                 True
# 191131        both              True                False
# 191132   left_only             False                 True
# 224731        both              True                False
# ...            ...               ...                  ...
# 9693874       both              True                 True
# 9693875  left_only             False                 True
# 9694204       both              True                False
# 9694205       both              True                 True
# 9694206  left_only             False                 True
#
# [33096 rows x 31 columns]

# %% [markdown]
# **Defining key hyperparameter of holding period (based on literature but also varied up and down slightly) and transaction cost based on research into US futures market transaction cost**

# %%
holding_period = 20
transaction_cost = 0.000025

# %%
df_combined[df_combined['First Post Surprise'] == True]
# Out:
#             Date_es   Time_es     Open    Close   Volume            DateTime  \
# 102677   12/23/1997  07:31:00  1189.40  1189.09      0.0 1997-12-23 07:31:00
# 191132   03/26/1998  07:31:00  1355.96  1355.04      0.0 1998-03-26 07:31:00
# 224732   04/30/1998  07:31:00  1339.15  1345.26      0.0 1998-04-30 07:31:00
# 254267   06/01/1998  09:01:00  1334.87  1335.18      0.0 1998-06-01 09:01:00
# 255692   06/02/1998  09:00:00  1343.12  1342.51      0.0 1998-06-02 09:00:00
# ...             ...       ...      ...      ...      ...                 ...
# 9693873  12/18/2024  07:30:00  6145.50  6145.75    131.0 2024-12-18 07:30:00
# 9693874  12/18/2024  07:30:00  6145.50  6145.75    131.0 2024-12-18 07:30:00
# 9693875  12/18/2024  07:31:00  6145.50  6145.25    305.0 2024-12-18 07:31:00
# 9694205  12/18/2024  13:00:00  6135.75  6136.00    801.0 2024-12-18 13:00:00
# 9694206  12/18/2024  13:01:00  6136.25  6120.50  13401.0 2024-12-18 13:01:00
#
#         Date_surprise               Period                              Event  \
# 102677            NaN                  NaN                                NaN
# 191132            NaN                  NaN                                NaN
# 224732            NaN                  NaN                                NaN
# 254267            NaN                  NaN                                NaN
# 255692     1998-06-02                  Apr                      Leading Index
# ...               ...                  ...                                ...
# 9693873    2024-12-18                Nov P               Building Permits MoM
# 9693874    2024-12-18                   3Q            Current Account Balance
# 9693875           NaN                  NaN                                NaN
# 9694205    2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: +2 Yrs
# 9694206           NaN                  NaN                                NaN
#
#                  Ticker  ...  Day   Surv(M) # Ests. Std Dev Surprise  \
# 102677              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 191132              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 224732              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 254267              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 255692   LEI CHNG Index  ...  Tue    -0.002     6.0    0.21     1.41
# ...                 ...  ...  ...       ...     ...     ...      ...
# 9693873  NHCHATCH Index  ...  Wed      0.01    46.0    1.78     2.87
# 9693874   USCABAL Index  ...  Wed  -$287.1b    18.0    6.22    -3.84
# 9693875             NaN  ...  NaN       NaN     NaN     NaN      NaN
# 9694205  DOTDY2MD Index  ...  Wed   0.03125    11.0    0.11     2.35
# 9694206             NaN  ...  NaN       NaN     NaN     NaN      NaN
#
#         Country/Region           Flag     _merge Surprise Occurred  \
# 102677             NaN            NaN  left_only             False
# 191132             NaN            NaN  left_only             False
# 224732             NaN            NaN  left_only             False
# 254267             NaN            NaN  left_only             False
# 255692   United States  United States       both              True
# ...                ...            ...        ...               ...
# 9693873  United States  United States       both              True
# 9693874  United States  United States       both              True
# 9693875            NaN            NaN  left_only             False
# 9694205  United States  United States       both              True
# 9694206            NaN            NaN  left_only             False
#
#          First Post Surprise
# 102677                  True
# 191132                  True
# 224732                  True
# 254267                  True
# 255692                  True
# ...                      ...
# 9693873                 True
# 9693874                 True
# 9693875                 True
# 9694205                 True
# 9694206                 True
#
# [23068 rows x 31 columns]

# %%
# As can be seen there as instances where we have multiple returns on the same day but this
# is not an issue - we take positions independent of other surprises in all 3 models i.e.
# a position that is held due to one suprise is not impacted by a different variable's surprise

df_combined.iloc[255689:255691, 8:29]
# Out:
#                  Event          Ticker Actual  Prior Revised Freq. First Rev.  \
# 255691  New Home Sales   NHSLTOT Index   888k   828k    844k     M       844k
# 255692   Leading Index  LEI CHNG Index  0.001  0.002    <NA>     M       <NA>
#
#        Last Rev. Time_surprise   C  ... Subcategory        R  Day Surv(M)  \
# 255691      836k      09:00:00  US  ...         NaN  88.1481  Tue    840k
# 255692     0.001      09:00:00  US  ...         NaN  82.2222  Tue  -0.002
#
#        # Ests.  Std Dev Surprise  Country/Region           Flag _merge
# 255691    14.0    13.02     3.69   United States  United States   both
# 255692     6.0     0.21     1.41   United States  United States   both
#
# [2 rows x 21 columns]

# %%
"""
 Now we create general returns for our 3 variants of holding periods (to be optimized on
 validation set for statistical and ML models) and returns for our naive model which goes
 long when there's a positive surprise and short when there's a negative surprise (the returns
 with a prefix of N_)
"""

df_combined['N_Return'] = np.nan
df_combined['N_Return_half'] = np.nan
df_combined['N_Return_double'] = np.nan
df_combined['Return'] = np.nan
df_combined['Return_half'] = np.nan
df_combined['Return_double'] = np.nan

surprise_rows = df_combined[df_combined['First Post Surprise'] == True]

for index, row in surprise_rows.iterrows():
    row_position = df_combined.index.get_loc(index)

    # Get the Surprise value from the previous row
    if index > df_combined.index[0]:
        prev_surprise = df_combined.at[df_combined.index[df_combined.index.get_loc(index)-1], 'Surprise']
    else:
        prev_surprise = 0  # Default if no previous row exists

    if row_position + holding_period < len(df_combined):
        current_price = row['Open']
        future_row = df_combined.iloc[row_position + holding_period]
        future_price = future_row['Open']

        if current_price != 0:
            percentage_increase = (future_price - current_price) / current_price
        else:
            percentage_increase = np.nan

        df_combined.at[index, 'Return'] = percentage_increase
        if prev_surprise < 0:
            df_combined.at[index, 'N_Return'] = -percentage_increase
        else:
            df_combined.at[index, 'N_Return'] = percentage_increase

    if row_position + int(holding_period*0.5) < len(df_combined): # int converts to whole number to avoid that potential error
        current_price = row['Open']
        future_row = df_combined.iloc[row_position + int(holding_period*0.5)]
        future_price = future_row['Open']

        if current_price != 0:
            percentage_increase = (future_price - current_price) / current_price
        else:
            percentage_increase = np.nan

        df_combined.at[index, 'Return_half'] = percentage_increase
        if prev_surprise < 0:
            df_combined.at[index, 'N_Return_half'] = -percentage_increase
        else:
            df_combined.at[index, 'N_Return_half'] = percentage_increase

    if row_position + int(holding_period*2) < len(df_combined):
        current_price = row['Open']
        future_row = df_combined.iloc[row_position + int(holding_period*2)]
        future_price = future_row['Open']

        if current_price != 0:
            percentage_increase = (future_price - current_price) / current_price
        else:
            percentage_increase = np.nan

        df_combined.at[index, 'Return_double'] = percentage_increase
        if prev_surprise < 0:
            df_combined.at[index, 'N_Return_double'] = -percentage_increase
        else:
            df_combined.at[index, 'N_Return_double'] = percentage_increase

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 2        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 3        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 4        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 5        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 6        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695761  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695762  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695763  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695764  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695765  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ... Flag     _merge  \
# 2                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 3                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 4                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 5                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 6                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# ...               ...    ...   ...    ...  ...  ...        ...
# 9695761           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695762           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695763           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695764           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695765           NaN    NaN   NaN    NaN  ...  NaN  left_only
#
#         Surprise Occurred First Post Surprise N_Return N_Return_half  \
# 2                   False               False      NaN           NaN
# 3                   False               False      NaN           NaN
# 4                   False               False      NaN           NaN
# 5                   False               False      NaN           NaN
# 6                   False               False      NaN           NaN
# ...                   ...                 ...      ...           ...
# 9695761             False               False      NaN           NaN
# 9695762             False               False      NaN           NaN
# 9695763             False               False      NaN           NaN
# 9695764             False               False      NaN           NaN
# 9695765             False               False      NaN           NaN
#
#         N_Return_double Return Return_half  Return_double
# 2                   NaN    NaN         NaN            NaN
# 3                   NaN    NaN         NaN            NaN
# 4                   NaN    NaN         NaN            NaN
# 5                   NaN    NaN         NaN            NaN
# 6                   NaN    NaN         NaN            NaN
# ...                 ...    ...         ...            ...
# 9695761             NaN    NaN         NaN            NaN
# 9695762             NaN    NaN         NaN            NaN
# 9695763             NaN    NaN         NaN            NaN
# 9695764             NaN    NaN         NaN            NaN
# 9695765             NaN    NaN         NaN            NaN
#
# [9695665 rows x 37 columns]

# %%
zero_count = (df_combined['Surprise'] == 0).sum()

print(zero_count)
# Out:
# 0

# %%
# The number of NaN values for this new column make sense - same as the number of NaNs for the Surprise column
df_combined.isna().sum()
# Out:
# Date_es                      0
# Time_es                      0
# Open                         0
# Close                        0
# Volume                       0
# DateTime                     0
# Date_surprise          9672597
# Period                 9672597
# Event                  9672597
# Ticker                 9672597
# Actual                 9672597
# Prior                  9672616
# Revised                9681231
# Freq.                  9672597
# First Rev.             9681231
# Last Rev.              9676757
# Time_surprise          9672597
# C                      9672597
# Category               9672597
# Subcategory            9695665
# R                      9672597
# Day                    9672597
# Surv(M)                9672597
# # Ests.                9672597
# Std Dev                9672597
# Surprise               9672597
# Country/Region         9672597
# Flag                   9672597
# _merge                       0
# Surprise Occurred            0
# First Post Surprise          0
# N_Return               9672597
# N_Return_half          9672597
# N_Return_double        9672597
# Return                 9672597
# Return_half            9672597
# Return_double          9672597
# dtype: int64

# %%
df_combined.describe()
# Out:
#                Open         Close        Volume  \
# count  9.695665e+06  9.695665e+06  9.695665e+06
# mean   2.157033e+03  2.157033e+03  8.646174e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.239050e+03  1.239050e+03  0.000000e+00
# 50%    1.501040e+03  1.501040e+03  9.100000e+01
# 75%    2.860620e+03  2.860620e+03  6.390000e+02
# max    6.181130e+03  6.181130e+03  2.149820e+05
# std    1.314762e+03  1.314761e+03  2.242572e+03
#
#                             DateTime  Subcategory             R       # Ests.  \
# count                        9695665          0.0  23068.000000  23068.000000
# mean   2011-04-26 02:54:35.758778112          NaN     63.220673     37.124155
# min              1997-09-10 00:01:00          NaN      0.000000      3.000000
# 25%              2004-07-22 03:37:00          NaN     42.963000     14.000000
# 50%              2011-04-08 00:31:00          NaN     69.481500     37.000000
# 75%              2018-02-11 18:52:00          NaN     86.666700     57.000000
# max              2024-12-19 16:00:00          NaN     99.259300    139.000000
# std                              NaN          NaN     28.822984     24.044298
#
#            Surprise      N_Return  N_Return_half  N_Return_double  \
# count  23068.000000  23068.000000   23068.000000     23068.000000
# mean       0.028913      0.000012       0.000016        -0.000005
# min       -9.580000     -0.036467      -0.032139        -0.034818
# 25%       -1.510000     -0.000981      -0.000749        -0.001324
# 50%       -0.010000      0.000000       0.000000         0.000000
# 75%        1.530000      0.001062       0.000848         0.001363
# max       10.580000      0.032054       0.023758         0.036751
# std        2.551234      0.002987       0.002555         0.003553
#
#              Return   Return_half  Return_double
# count  23068.000000  23068.000000   23068.000000
# mean       0.000003     -0.000012      -0.000008
# min       -0.036467     -0.032139      -0.036751
# 25%       -0.000990     -0.000784      -0.001328
# 50%        0.000000      0.000000       0.000000
# 75%        0.001047      0.000822       0.001357
# max        0.029750      0.027740       0.033010
# std        0.002987      0.002555       0.003553

# %% [markdown]
# **Now we get Returns & Standard Deviation**

# %%
# Just checking how long futures market is typically open for (some surprises on same day might bias this value a bit but not by muchh)
date_counts = df_combined['DateTime'].dt.floor('D').value_counts()

# Calculate statistics
avg_minutes_per_day = date_counts.mean()
avg_holding_period_intervals = avg_minutes_per_day / holding_period

print(f"Average market open minutes per day: {avg_minutes_per_day:.1f}")
print(f"Average holding-period intervals per day: {holding_period:.1f}")
# Out:
# Average market open minutes per day: 1147.8
# Average holding-period intervals per day: 20.0

# %%
average_return = df_combined['Return'].dropna().mean()
print(average_return)
# Out:
# 3.253384860842976e-06

# %%
train_end = int(0.3 * len(df_combined))
validation_end = int(0.5 * len(df_combined))
print(train_end)
print(validation_end)
# Out:
# 2908699
# 4847832

# %%
"""Computing average annual returns for all of the years in the dataframe using the naive strategy as follows:
   Validation set used to determine which of the 3 holding periods performed best and then the following year is used as the test set with that specific holding period and then
   this process is repeated
"""

# Group by year and compute compounded returns
annual_returns = {}
for year, group in df_combined[df_combined['Return'].notna()].groupby(df_combined['DateTime'].dt.year):
    compounded_return = (1 + group['Return']).prod() - 1
    annual_returns[year] = compounded_return

# Convert to percentage and display
annual_returns_pct = {year: f"{ret*100:.2f}%" for year, ret in annual_returns.items()}
print("Annual Compounded Returns:")
print(annual_returns_pct)
# Out:
# Annual Compounded Returns:
# {1997: '0.03%', 1998: '-3.79%', 1999: '23.17%', 2000: '12.73%', 2001: '-23.17%', 2002: '-11.97%', 2003: '-3.47%', 2004: '-6.25%', 2005: '12.02%', 2006: '4.17%', 2007: '23.11%', 2008: '12.10%', 2009: '-15.67%', 2010: '-4.45%', 2011: '-3.59%', 2012: '-18.80%', 2013: '6.40%', 2014: '2.24%', 2015: '-18.95%', 2016: '-5.29%', 2017: '9.22%', 2018: '-6.42%', 2019: '-2.83%', 2020: '75.86%', 2021: '28.83%', 2022: '-51.30%', 2023: '17.57%', 2024: '8.81%'}

# %%
# Vas

# This strategy: 1) Uses validation period to pick best return horizon (half/normal/double),
# 2) Tests it on next 252 days, 3) Rolls forward annually, keeping window sizes constant

import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Configuration ---
total_cost = 2 * transaction_cost
horizons = ['_half', '', '_double']  # Matching N_Return_half, N_Return, N_Return_double

# --- Data Preparation ---
# Create filtered dataframe (non-zero/non-NaN surprises)
df_naive = df_combined[(df_combined['Surprise'] != 0) &
                       (df_combined['Surprise'].notna())].copy()
df_naive['DateTime'] = pd.to_datetime(df_naive['DateTime'])
df_naive = df_naive.sort_values('DateTime').reset_index(drop=True)

min_date = df_naive['DateTime'].min()
max_date = df_naive['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
results = []
all_test_returns = []
all_dates = []
fold_mean_returns = []
best_horizons_list = []

def calculate_grouped_returns(df_group, horizon):
    """Calculate returns with naive position sizing rules"""
    positives = df_group[df_group['Surprise'] > 0]
    negatives = df_group[df_group['Surprise'] < 0]

    # Handle positive surprises with equal weighting
    pos_count = len(positives)
    pos_weight = 1/pos_count if pos_count > 0 else 0

    # Calculate returns components (N_Return already contains signed returns)
    long_returns = (positives[f'N_Return{horizon}'] - total_cost) * pos_weight
    short_returns = (negatives[f'N_Return{horizon}'] - total_cost)  # No sign flip needed

    return long_returns.sum() + short_returns.sum()

# --- Main Loop ---
while True:
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    if val_end_date > max_date or test_end_date > max_date:
        break

    # Create masks using DateTime comparisons
    train_mask = df_naive['DateTime'] <= train_end_date
    val_mask = (df_naive['DateTime'] >= val_start_date) & (df_naive['DateTime'] <= val_end_date)
    test_mask = (df_naive['DateTime'] >= test_start_date) & (df_naive['DateTime'] <= test_end_date)

    train_data = df_naive[train_mask]
    val_data = df_naive[val_mask]
    test_data = df_naive[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon = None
    best_val_return = -np.inf

    for horizon in horizons:
        # Prepare validation returns with cost subtraction
        val_trade_df = pd.DataFrame({
            'DateTime': val_data['DateTime'],
            'Surprise': val_data['Surprise'],
            f'N_Return{horizon}': val_data[f'N_Return{horizon}'] - total_cost
        }).dropna()

        # Calculate grouped returns
        val_returns = val_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, horizon)
        ).values

        if len(val_returns) > 0:
            total_val_return = (1 + val_returns).prod() - 1
            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon = horizon

    # --- Test Best Horizon ---
    if best_horizon:
        # Prepare test returns with cost subtraction
        test_trade_df = pd.DataFrame({
            'DateTime': test_data['DateTime'],
            'Surprise': test_data['Surprise'],
            f'N_Return{best_horizon}': test_data[f'N_Return{best_horizon}'] - total_cost
        }).dropna()

        grouped_returns = test_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, best_horizon)
        ).values

        if len(grouped_returns) > 0:
            all_test_returns.extend(grouped_returns)
            all_dates.extend(test_trade_df['DateTime'].unique().tolist())
            fold_mean_returns.append(np.mean(grouped_returns))
            best_horizons_list.append(best_horizon)

    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Naive Strategy Cumulative Returns (DateTime-Based Rolling Windows)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")
    print(f"\nAverage Fold Test Return : {np.mean(fold_mean_returns)*100:.5f}%")
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:87: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-62-7b1e2bbf8fc9>:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# Final Cumulative Compounded Return: -12.30%
#
# Average Fold Test Return : -0.00133%
#
# Optimal Horizon Counts:
# _half      9
# _double    5
# Name: count, dtype: int64

# %% [markdown]
# # **Statistical Model**

# %%
# !pip install pandas_datareader
# !pip install yfinance
# !pip install statsmodels
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting lxml (from pandas_datareader)
#   Downloading lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.11/dist-packages (from pandas_datareader) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pandas_datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_datareader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas_datareader) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas_datareader) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas_datareader) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.17.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 2.5 MB/s eta 0:00:00
# Downloading lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 56.1 MB/s eta 0:00:00
# Installing collected packages: lxml, pandas_datareader
# Successfully installed lxml-5.4.0 pandas_datareader-0.10.0
# Collecting yfinance
#   Downloading yfinance-0.2.55-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.9.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 33.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Downloading yfinance-0.2.55-py2.py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 7.2 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.9-cp311-cp311-linux_x86_64.whl size=886634 sha256=03e953e1f4a617aac1c7a584950931aaffff83cf13f26b6b5ab9763b1022f619
#   Stored in directory: /root/.cache/pip/wheels/f4/14/e4/50c88c865833085aeb91e2bd40e3a683ff434806386b8ee7bc
# Successfully built peewee
# Installing collected packages: peewee, multitasking, frozendict, yfinance
# Successfully installed frozendict-2.4.6 multitasking-0.0.11 peewee-3.17.9 yfinance-0.2.55
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 110.5 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 19.1 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4

# %%
import pandas as pd
from pandas_datareader import data as pdr
import datetime
import numpy as np
import yfinance as yf
import statsmodels.api as sm

# %% [markdown]
# **The code below downloads US economic indicators (GDP, unemployment, CPI,
# etc.) and S&P 500 returns, then aligns all data to the exact quarterly dates when GDP is released. It ensures no future data leaks by using only values available on or before each GDP release date.t**

# %%
import datetime
import pandas as pd
import pandas_datareader as pdr
import yfinance as yf

# --- 1. Get GDP Release Dates (Quarterly) ---
start = datetime.datetime(1997, 1, 1)
end = datetime.datetime.today()
gdp_releases = pdr.DataReader('A191RL1Q225SBEA', 'fred', start, end).index

# --- 2. Download All Economic Data ---
raw_data = {
    # Quarterly
    'gdp_gr': pdr.DataReader('A191RL1Q225SBEA', 'fred', start, end),

    # Monthly
    'NFP': pdr.DataReader('PAYEMS', 'fred', start, end),
    'un_rate': pdr.DataReader('UNRATE', 'fred', start, end),
    'cci': pdr.DataReader('UMCSENT', 'fred', start, end),
    'ret_sales': pdr.DataReader('RSAFS', 'fred', start, end),
    'IPTI': pdr.DataReader('INDPRO', 'fred', start, end),
    'cpi': pdr.DataReader('CPIAUCSL', 'fred', start, end),
    'TXBPPRIVSA': pdr.DataReader('TXBPPRIVSA', 'fred', start, end),  # Added this line

    # Daily
    'ffr': pdr.DataReader('DFF', 'fred', start, end),

    # S&P 500 (via yfinance)
    'sp500': yf.download('^GSPC', start=start, end=end)['Close']
}

# --- 3. Align ALL Variables to GDP Release Dates ---
economic_data = pd.DataFrame(index=gdp_releases)

for name, series in raw_data.items():
    if name == 'gdp_gr':
        economic_data[name] = series  # Already aligned
    elif name == 'sp500':
        # Calculate quarterly returns between GDP releases
        prices_on_releases = series.reindex(gdp_releases, method='bfill')
        economic_data['SP500'] = prices_on_releases.pct_change()
    elif name == 'ffr':
        # Take FFR value ON the GDP release day
        economic_data[name] = series.reindex(gdp_releases, method='bfill')
    else:
        # Monthly series: last release BEFORE GDP date
        economic_data[name] = series.reindex(gdp_releases, method='ffill')

# --- 4. Clean and Verify ---
economic_data = economic_data.dropna(subset=['gdp_gr'])  # Remove quarters without GDP
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-01-01     2.6  121357      5.3   97.4     223481   77.5135  159.400
# 1997-04-01     6.8  122288      5.1  101.4     224615   78.9848  159.900
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2138  315.564
#
#               TXBPPRIVSA   ffr     SP500
# DATE
# 1997-01-01   8989.727265  6.26       NaN
# 1997-04-01  10529.485939  6.18  0.030705
# 1997-07-01  10146.266776  6.24  0.172964
# 1997-10-01  10852.416694  5.65  0.072253
# 1998-01-01   9455.132516  5.84  0.020546
# ...                  ...   ...       ...
# 2023-10-01  19500.544159  5.33 -0.037526
# 2024-01-01  19795.233356  5.33  0.105970
# 2024-04-01  19904.874909  5.33  0.105620
# 2024-07-01  18899.758428  5.33  0.044113
# 2024-10-01  19370.476111  4.83  0.042677
#
# [112 rows x 10 columns]

# %%
economic_data = economic_data.dropna()
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-04-01     6.8  122288      5.1  101.4     224615   78.9848  159.900
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# 1998-04-01     3.8  125446      4.3  108.7     235986   84.6339  162.200
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2138  315.564
#
#               TXBPPRIVSA   ffr     SP500
# DATE
# 1997-04-01  10529.485939  6.18  0.030705
# 1997-07-01  10146.266776  6.24  0.172964
# 1997-10-01  10852.416694  5.65  0.072253
# 1998-01-01   9455.132516  5.84  0.020546
# 1998-04-01  12178.889660  5.72  0.136518
# ...                  ...   ...       ...
# 2023-10-01  19500.544159  5.33 -0.037526
# 2024-01-01  19795.233356  5.33  0.105970
# 2024-04-01  19904.874909  5.33  0.105620
# 2024-07-01  18899.758428  5.33  0.044113
# 2024-10-01  19370.476111  4.83  0.042677
#
# [111 rows x 10 columns]

# %% [markdown]
# **Now we do Lasso penalization to see which of the macro variables are useful**

# %%
# !pip install ISLP
# Out:
# Collecting ISLP
#   Downloading ISLP-0.4.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from ISLP) (2.0.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.11/dist-packages (from ISLP) (1.14.1)
# Requirement already satisfied: pandas>=0.20 in /usr/local/lib/python3.11/dist-packages (from ISLP) (2.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from ISLP) (5.4.0)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.11/dist-packages (from ISLP) (1.6.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from ISLP) (1.4.2)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.11/dist-packages (from ISLP) (0.14.4)
# Collecting lifelines (from ISLP)
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting pygam (from ISLP)
#   Downloading pygam-0.9.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from ISLP) (2.6.0+cpu)
# Collecting pytorch-lightning (from ISLP)
#   Downloading pytorch_lightning-2.5.1-py3-none-any.whl.metadata (20 kB)
# Collecting torchmetrics (from ISLP)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.20->ISLP) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.20->ISLP) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.20->ISLP) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2->ISLP) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13->ISLP) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13->ISLP) (24.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from lifelines->ISLP) (3.10.0)
# Collecting autograd>=1.5 (from lifelines->ISLP)
#   Downloading autograd-1.7.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting autograd-gamma>=0.3 (from lifelines->ISLP)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting formulaic>=0.2.2 (from lifelines->ISLP)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting progressbar2<5.0.0,>=4.2.0 (from pygam->ISLP)
#   Downloading progressbar2-4.5.0-py3-none-any.whl.metadata (16 kB)
# Collecting scipy>=0.9 (from ISLP)
#   Downloading scipy-1.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 984.7 kB/s eta 0:00:00
# Collecting numpy>=1.7.1 (from ISLP)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->ISLP) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->ISLP) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->ISLP) (4.13.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning->ISLP)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->ISLP) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->ISLP) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->ISLP) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->ISLP) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->ISLP) (1.3.0)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines->ISLP)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines->ISLP) (1.17.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning->ISLP) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (3.2.3)
# Collecting python-utils>=3.8.1 (from progressbar2<5.0.0,>=4.2.0->pygam->ISLP)
#   Downloading python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.20->ISLP) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->ISLP) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (1.19.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->ISLP) (3.10)
# Downloading ISLP-0.4.0-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 16.4 MB/s eta 0:00:00
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 25.1 MB/s eta 0:00:00
# Downloading pygam-0.9.1-py3-none-any.whl (522 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.0/522.0 kB 34.7 MB/s eta 0:00:00
# Downloading scipy-1.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 32.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 57.9 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1-py3-none-any.whl (822 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 37.2 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 54.9 MB/s eta 0:00:00
# Downloading autograd-1.7.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.5 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 9.4 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading progressbar2-4.5.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 4.4 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (pyproject.toml) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4119 sha256=53ce8e21441709571782c6fb9259201eb8058b56758d7b9506e067491279050d
#   Stored in directory: /root/.cache/pip/wheels/8b/67/f4/2caaae2146198dcb824f31a303833b07b14a5ec863fb3acd7b
# Successfully built autograd-gamma
# Installing collected packages: python-utils, numpy, lightning-utilities, interface-meta, scipy, progressbar2, autograd, torchmetrics, pygam, formulaic, autograd-gamma, pytorch-lightning, lifelines, ISLP
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed ISLP-0.4.0 autograd-1.7.0 autograd-gamma-0.5.0 formulaic-1.1.1 interface-meta-1.3.0 lifelines-0.30.0 lightning-utilities-0.14.3 numpy-1.26.4 progressbar2-4.5.0 pygam-0.9.1 python-utils-3.9.1 pytorch-lightning-2.5.1 scipy-1.11.4 torchmetrics-1.7.1

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
from statsmodels.api import OLS
import sklearn.model_selection as skm
import sklearn.linear_model as skl
from sklearn.preprocessing import StandardScaler
from ISLP import load_data
from ISLP.models import ModelSpec as MS
from functools import partial
from ISLP.models import \
(Stepwise,
sklearn_selected,
sklearn_selection_path)
# !pip install l0bnb
from l0bnb import fit_path
# Out:
# Collecting l0bnb
#   Downloading l0bnb-1.0.0.tar.gz (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 2.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from l0bnb) (1.26.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from l0bnb) (1.11.4)
# Requirement already satisfied: numba>=0.53.1 in /usr/local/lib/python3.11/dist-packages (from l0bnb) (0.61.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.53.1->l0bnb) (0.44.0)
# Building wheels for collected packages: l0bnb
#   Building wheel for l0bnb (pyproject.toml) ... done
#   Created wheel for l0bnb: filename=l0bnb-1.0.0-py3-none-any.whl size=22380 sha256=1c5a89b8a7689ddacf5180ae915f526305e6e928e3a713e6222a2740ef9f2cf0
#   Stored in directory: /root/.cache/pip/wheels/56/b6/7a/2a78772d92aa67f0d038759a09c7e950b5a708d5ecd5c0e38d
# Successfully built l0bnb
# Installing collected packages: l0bnb
# Successfully installed l0bnb-1.0.0

# %%
economic_data.columns
# Out:
# Index(['gdp_gr', 'NFP', 'un_rate', 'cci', 'ret_sales', 'IPTI', 'cpi',
#        'TXBPPRIVSA', 'ffr', 'SP500'],
#       dtype='object')

# %%
economic_data['gdp_gr_L1'] = economic_data['gdp_gr'].shift(1)
economic_data['ffr_L1'] = economic_data['ffr'].shift(1)
economic_data['NFP_L1'] = economic_data['NFP'].shift(1)
economic_data['un_rate_L1'] = economic_data['un_rate'].shift(1)
economic_data['cci_L1'] = economic_data['cci'].shift(1)
economic_data['ret_sales_L1'] = economic_data['ret_sales'].shift(1)
economic_data['IPTI_L1'] = economic_data['IPTI'].shift(1)
economic_data['cpi_L1'] = economic_data['cpi'].shift(1)
economic_data['TXBPPRIVSA_L1'] = economic_data['TXBPPRIVSA'].shift(1)
# Out:
# <ipython-input-71-61a7e8bf9c0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['gdp_gr_L1'] = economic_data['gdp_gr'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['ffr_L1'] = economic_data['ffr'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['NFP_L1'] = economic_data['NFP'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['un_rate_L1'] = economic_data['un_rate'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['cci_L1'] = economic_data['cci'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['ret_sales_L1'] = economic_data['ret_sales'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['IPTI_L1'] = economic_data['IPTI'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['cpi_L1'] = economic_data['cpi'].shift(1)
# <ipython-input-71-61a7e8bf9c0e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['TXBPPRIVSA_L1'] = economic_data['TXBPPRIVSA'].shift(1)

# %%
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-04-01     6.8  122288      5.1  101.4     224615   78.9848  159.900
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# 1998-04-01     3.8  125446      4.3  108.7     235986   84.6339  162.200
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2138  315.564
#
#               TXBPPRIVSA   ffr     SP500  gdp_gr_L1  ffr_L1    NFP_L1  \
# DATE
# 1997-04-01  10529.485939  6.18  0.030705        NaN     NaN       NaN
# 1997-07-01  10146.266776  6.24  0.172964        6.8    6.18  122288.0
# 1997-10-01  10852.416694  5.65  0.072253        5.1    6.24  123114.0
# 1998-01-01   9455.132516  5.84  0.020546        3.5    5.65  123924.0
# 1998-04-01  12178.889660  5.72  0.136518        4.1    5.84  124806.0
# ...                  ...   ...       ...        ...     ...       ...
# 2023-10-01  19500.544159  5.33 -0.037526        4.4    5.08  156019.0
# 2024-01-01  19795.233356  5.33  0.105970        3.2    5.33  156520.0
# 2024-04-01  19904.874909  5.33  0.105620        1.6    5.33  157049.0
# 2024-07-01  18899.758428  5.33  0.044113        3.0    5.33  157635.0
# 2024-10-01  19370.476111  4.83  0.042677        3.1    5.33  158003.0
#
#             un_rate_L1  cci_L1  ret_sales_L1   IPTI_L1   cpi_L1  TXBPPRIVSA_L1
# DATE
# 1997-04-01         NaN     NaN           NaN       NaN      NaN            NaN
# 1997-07-01         5.1   101.4      224615.0   78.9848  159.900   10529.485939
# 1997-10-01         4.9   107.1      228703.0   80.4666  160.400   10146.266776
# 1998-01-01         4.7   105.6      229836.0   82.7656  161.500   10852.416694
# 1998-04-01         4.6   106.6      231587.0   84.1564  162.000    9455.132516
# ...                ...     ...           ...       ...      ...            ...
# 2023-10-01         3.5    71.5      690641.0  103.0722  304.615   17947.555738
# 2024-01-01         3.9    63.8      699365.0  102.5781  307.653   19500.544159
# 2024-04-01         3.7    79.0      694131.0  101.4830  309.794   19795.233356
# 2024-07-01         3.9    77.2      702681.0  102.3568  313.016   19904.874909
# 2024-10-01         4.2    66.4      710851.0  102.5192  313.566   18899.758428
#
# [111 rows x 19 columns]

# %%
economic_data = economic_data.dropna()
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# 1998-04-01     3.8  125446      4.3  108.7     235986   84.6339  162.200
# 1998-07-01     5.1  126211      4.5  105.2     237411   84.3445  163.200
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2138  315.564
#
#               TXBPPRIVSA   ffr     SP500  gdp_gr_L1  ffr_L1    NFP_L1  \
# DATE
# 1997-07-01  10146.266776  6.24  0.172964        6.8    6.18  122288.0
# 1997-10-01  10852.416694  5.65  0.072253        5.1    6.24  123114.0
# 1998-01-01   9455.132516  5.84  0.020546        3.5    5.65  123924.0
# 1998-04-01  12178.889660  5.72  0.136518        4.1    5.84  124806.0
# 1998-07-01  13256.650856  6.35  0.036466        3.8    5.72  125446.0
# ...                  ...   ...       ...        ...     ...       ...
# 2023-10-01  19500.544159  5.33 -0.037526        4.4    5.08  156019.0
# 2024-01-01  19795.233356  5.33  0.105970        3.2    5.33  156520.0
# 2024-04-01  19904.874909  5.33  0.105620        1.6    5.33  157049.0
# 2024-07-01  18899.758428  5.33  0.044113        3.0    5.33  157635.0
# 2024-10-01  19370.476111  4.83  0.042677        3.1    5.33  158003.0
#
#             un_rate_L1  cci_L1  ret_sales_L1   IPTI_L1   cpi_L1  TXBPPRIVSA_L1
# DATE
# 1997-07-01         5.1   101.4      224615.0   78.9848  159.900   10529.485939
# 1997-10-01         4.9   107.1      228703.0   80.4666  160.400   10146.266776
# 1998-01-01         4.7   105.6      229836.0   82.7656  161.500   10852.416694
# 1998-04-01         4.6   106.6      231587.0   84.1564  162.000    9455.132516
# 1998-07-01         4.3   108.7      235986.0   84.6339  162.200   12178.889660
# ...                ...     ...           ...       ...      ...            ...
# 2023-10-01         3.5    71.5      690641.0  103.0722  304.615   17947.555738
# 2024-01-01         3.9    63.8      699365.0  102.5781  307.653   19500.544159
# 2024-04-01         3.7    79.0      694131.0  101.4830  309.794   19795.233356
# 2024-07-01         3.9    77.2      702681.0  102.3568  313.016   19904.874909
# 2024-10-01         4.2    66.4      710851.0  102.5192  313.566   18899.758428
#
# [110 rows x 19 columns]

# %%
economic_data.index = pd.to_datetime(economic_data.index)

# %%
economic_data.index
# Out:
# DatetimeIndex(['1997-07-01', '1997-10-01', '1998-01-01', '1998-04-01',
#                '1998-07-01', '1998-10-01', '1999-01-01', '1999-04-01',
#                '1999-07-01', '1999-10-01',
#                ...
#                '2022-07-01', '2022-10-01', '2023-01-01', '2023-04-01',
#                '2023-07-01', '2023-10-01', '2024-01-01', '2024-04-01',
#                '2024-07-01', '2024-10-01'],
#               dtype='datetime64[ns]', name='DATE', length=110, freq=None)

# %%
train_splitpoint = round(111*0.5)
train = economic_data.iloc[:train_splitpoint]
test = economic_data.iloc[train_splitpoint:]

# %%
# I first run Lasso on this dataset to see if it works etc.
from sklearn.pipeline import Pipeline
scaler = StandardScaler(with_mean=True, with_std=True)

lambdas = np.linspace(0.001, 0.2, 20)

y = train['SP500']
model = MS(train.columns.drop(['gdp_gr', 'NFP', 'un_rate', 'cci', 'ret_sales', 'IPTI', 'cpi', 'ffr','TXBPPRIVSA',
       'SP500']), intercept=False)
D = model.fit_transform(train)
feature_names = list(D.columns)
X = np.asarray(D)

validation = skm.ShuffleSplit(n_splits=1,
test_size=0.2,
random_state=0)

K=5
kfold = skm.KFold(K,
random_state=0,
shuffle=True)


lasso = skl.ElasticNet(alpha=lambdas[0], l1_ratio=1)
pipe = Pipeline(steps=[('scaler', scaler), ('lasso', lasso)])
pipe.fit(X, y)

param_grid = {'lasso__alpha': lambdas}
grid = skm.GridSearchCV(pipe,
param_grid,
cv=validation,
scoring='neg_mean_squared_error')
grid.fit(X, y)
grid.best_params_['lasso__alpha']
grid.best_estimator_

lassoCV = skl.ElasticNetCV(alphas=lambdas,
l1_ratio=1,
cv=kfold)
pipeCV = Pipeline(steps=[('scaler', scaler),
('lasso', lassoCV)])

pipeCV.fit(X, y)

tuned_lasso = pipeCV.named_steps['lasso']
tuned_lasso.coef_
# Out:
# array([ 0.03040955, -0.        , -0.00566775,  0.00520073, -0.        ,
#         0.        , -0.        ,  0.        , -0.        ])

# %%
nonzero_mask = tuned_lasso.coef_ != 0
nonzero_coefs = tuned_lasso.coef_[nonzero_mask]
nonzero_features = [feature_names[i] for i in np.where(nonzero_mask)[0]]

# Create a DataFrame of results
coef_results = pd.DataFrame({
    'Feature': nonzero_features,
    'Coefficient': nonzero_coefs
}).sort_values('Coefficient', key=abs, ascending=False)

print("Nonzero coefficients:")
print(coef_results)
# Out:
# Nonzero coefficients:
#       Feature  Coefficient
# 0   gdp_gr_L1     0.030410
# 1      NFP_L1    -0.005668
# 2  un_rate_L1     0.005201

# %% [markdown]
# **Now we run standard OLS with all non-zero coefficient variables as explanatory variables to see which are significant**

# %%
X = sm.add_constant(train[['gdp_gr_L1','NFP_L1','un_rate_L1']])

model = sm.OLS(y, X).fit(cov_type = 'HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  SP500   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     5.961
# Date:                Wed, 23 Apr 2025   Prob (F-statistic):            0.00143
# Time:                        20:36:46   Log-Likelihood:                 62.568
# No. Observations:                  56   AIC:                            -117.1
# Df Residuals:                      52   BIC:                            -109.0
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2694      0.400      0.674      0.500      -0.514       1.053
# gdp_gr_L1      0.0151      0.004      3.416      0.001       0.006       0.024
# NFP_L1     -2.684e-06   2.84e-06     -0.945      0.345   -8.25e-06    2.88e-06
# un_rate_L1     0.0108      0.009      1.233      0.218      -0.006       0.028
# ==============================================================================
# Omnibus:                        4.396   Durbin-Watson:                   2.321
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.511
# Skew:                          -0.591   Prob(JB):                        0.173
# Kurtosis:                       3.326   Cond. No.                     5.42e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 5.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Now we do standard OLS with all variables to see differences**

# %%
economic_data.columns
# Out:
# Index(['gdp_gr', 'NFP', 'un_rate', 'cci', 'ret_sales', 'IPTI', 'cpi',
#        'TXBPPRIVSA', 'ffr', 'SP500', 'gdp_gr_L1', 'ffr_L1', 'NFP_L1',
#        'un_rate_L1', 'cci_L1', 'ret_sales_L1', 'IPTI_L1', 'cpi_L1',
#        'TXBPPRIVSA_L1'],
#       dtype='object')

# %%
X = sm.add_constant(train[['gdp_gr_L1', 'ffr_L1', 'NFP_L1', 'un_rate_L1', 'cci_L1', 'ret_sales_L1', 'IPTI_L1', 'cpi_L1','TXBPPRIVSA_L1']])

model = sm.OLS(y, X).fit(cov_type = 'HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  SP500   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     4.012
# Date:                Wed, 23 Apr 2025   Prob (F-statistic):           0.000773
# Time:                        20:36:46   Log-Likelihood:                 65.149
# No. Observations:                  56   AIC:                            -110.3
# Df Residuals:                      46   BIC:                            -90.04
# Df Model:                           9
# Covariance Type:                  HC3
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             2.8358      1.582      1.793      0.073      -0.264       5.936
# gdp_gr_L1         0.0156      0.007      2.271      0.023       0.002       0.029
# ffr_L1            0.0059      0.014      0.421      0.674      -0.022       0.033
# NFP_L1        -1.385e-05   1.25e-05     -1.105      0.269   -3.84e-05    1.07e-05
# un_rate_L1       -0.0165      0.047     -0.348      0.728      -0.109       0.076
# cci_L1           -0.0022      0.002     -0.944      0.345      -0.007       0.002
# ret_sales_L1   4.088e-06   3.33e-06      1.229      0.219   -2.43e-06    1.06e-05
# IPTI_L1          -0.0095      0.012     -0.774      0.439      -0.033       0.015
# cpi_L1           -0.0057      0.008     -0.706      0.480      -0.022       0.010
# TXBPPRIVSA_L1 -6.727e-06   9.26e-06     -0.727      0.467   -2.49e-05    1.14e-05
# ==============================================================================
# Omnibus:                        4.662   Durbin-Watson:                   2.426
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                3.614
# Skew:                          -0.542   Prob(JB):                        0.164
# Kurtosis:                       3.611   Cond. No.                     4.88e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 4.88e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_surprise = pd.read_csv('US_economic_releases_events.csv')
# Out:
# <ipython-input-82-6471b8335397>:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_surprise = pd.read_csv('US_economic_releases_events.csv')

# %%
pip install openpyxl xlrd
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 3.8 MB/s eta 0:00:00
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 6.7 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: xlrd, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5 xlrd-2.0.1

# %%
"""
df_mapping = pd.read_excel('US Variable mapping.xlsx')
"""
df_mapping = pd.read_excel('/content/US Variable mapping.xlsx')

# %%
df_mapping
# Out:
#     All Blomberg indicators  \
# 0             VNCCTOT Index
# 1            PHUCCHNG Index
# 2             CICRTOT Index
# 3            MWINCHNG Index
# 4             NFP TCH Index
# ..                      ...
# 156          NYCNM1IR Index
# 157          DOTDY0MD Index
# 158          DOTDY1MD Index
# 159          DOTDY2MD Index
# 160          DOTDLTMD Index
#
#                                            Description  \
# 0                                  Vehicle Sales Total
# 1                            Pending Home Sales Change
# 2                          Construction Spending Total
# 3                     MBA Mortgage Applications Change
# 4                        Nonfarm Payrolls Total Change
# ..                                                 ...
# 156           NY Fed: Empire State Manufacturing Index
# 157  Department of Transportation: Domestic Air Rev...
# 158  Department of Transportation: International Ai...
# 159  Department of Transportation: Systemwide Air R...
# 160          Department of Transportation: Load Factor
#
#                                        Broad indicator
# 0                                         Retail sales
# 1    Building permits - new private housing units a...
# 2                                      GDP growth rate
# 3    Building permits - new private housing units a...
# 4                                    Non-farm payrolls
# ..                                                 ...
# 156                              Industrial production
# 157                                    GDP growth rate
# 158                                    GDP growth rate
# 159                                    GDP growth rate
# 160                                    GDP growth rate
#
# [161 rows x 3 columns]

# %% [markdown]
# **Changed Blomberg indicators to > All Blomberg indicators**
#
# > Add blockquote

# %%
df_mapping = df_mapping.rename(columns={'All Blomberg indicators': 'Ticker'})

# %%
df_combined = pd.merge(df_mapping, df_combined, on='Ticker', how='outer')
df_combined
# Out:
#                  Ticker                       Description  \
# 0        ACNFCOMF Index  Bloomberg Consumer Comfort Index
# 1        ACNFCOMF Index  Bloomberg Consumer Comfort Index
# 2        ACNFCOMF Index  Bloomberg Consumer Comfort Index
# 3        ACNFCOMF Index  Bloomberg Consumer Comfort Index
# 4        ACNFCOMF Index  Bloomberg Consumer Comfort Index
# ...                 ...                               ...
# 9695680             NaN                               NaN
# 9695681             NaN                               NaN
# 9695682             NaN                               NaN
# 9695683             NaN                               NaN
# 9695684             NaN                               NaN
#
#                    Broad indicator     Date_es   Time_es     Open    Close  \
# 0        Consumer confidence index  04/13/2004  17:30:00  1185.41  1185.41
# 1        Consumer confidence index  06/08/2004  17:30:00  1202.25  1202.25
# 2        Consumer confidence index  07/20/2004  17:30:00  1172.25  1172.78
# 3        Consumer confidence index  08/24/2004  17:30:00  1154.88  1154.88
# 4        Consumer confidence index  10/12/2004  17:30:00  1183.83  1183.83
# ...                            ...         ...       ...      ...      ...
# 9695680                        NaN  12/19/2024  15:56:00  5941.75  5941.75
# 9695681                        NaN  12/19/2024  15:57:00  5941.75  5941.50
# 9695682                        NaN  12/19/2024  15:58:00  5941.50  5941.00
# 9695683                        NaN  12/19/2024  15:59:00  5940.75  5941.00
# 9695684                        NaN  12/19/2024  16:00:00  5941.00  5941.25
#
#          Volume            DateTime Date_surprise  ...           Flag  \
# 0           0.0 2004-04-13 17:30:00    2004-04-13  ...  United States
# 1           4.0 2004-06-08 17:30:00    2004-06-08  ...  United States
# 2          71.0 2004-07-20 17:30:00    2004-07-20  ...  United States
# 3           0.0 2004-08-24 17:30:00    2004-08-24  ...  United States
# 4           0.0 2004-10-12 17:30:00    2004-10-12  ...  United States
# ...         ...                 ...           ...  ...            ...
# 9695680   318.0 2024-12-19 15:56:00           NaN  ...            NaN
# 9695681   386.0 2024-12-19 15:57:00           NaN  ...            NaN
# 9695682   484.0 2024-12-19 15:58:00           NaN  ...            NaN
# 9695683  6462.0 2024-12-19 15:59:00           NaN  ...            NaN
# 9695684  8864.0 2024-12-19 16:00:00           NaN  ...            NaN
#
#             _merge Surprise Occurred First Post Surprise N_Return  \
# 0             both              True               False      NaN
# 1             both              True               False      NaN
# 2             both              True               False      NaN
# 3             both              True               False      NaN
# 4             both              True               False      NaN
# ...            ...               ...                 ...      ...
# 9695680  left_only             False               False      NaN
# 9695681  left_only             False               False      NaN
# 9695682  left_only             False               False      NaN
# 9695683  left_only             False               False      NaN
# 9695684  left_only             False               False      NaN
#
#         N_Return_half N_Return_double Return Return_half Return_double
# 0                 NaN             NaN    NaN         NaN           NaN
# 1                 NaN             NaN    NaN         NaN           NaN
# 2                 NaN             NaN    NaN         NaN           NaN
# 3                 NaN             NaN    NaN         NaN           NaN
# 4                 NaN             NaN    NaN         NaN           NaN
# ...               ...             ...    ...         ...           ...
# 9695680           NaN             NaN    NaN         NaN           NaN
# 9695681           NaN             NaN    NaN         NaN           NaN
# 9695682           NaN             NaN    NaN         NaN           NaN
# 9695683           NaN             NaN    NaN         NaN           NaN
# 9695684           NaN             NaN    NaN         NaN           NaN
#
# [9695685 rows x 39 columns]

# %%
df_combined = df_combined.sort_values(by='DateTime', ascending=True)
df_combined
# Out:
#                Ticker                              Description  \
# 23088             NaN                                      NaN
# 23089             NaN                                      NaN
# 23090             NaN                                      NaN
# 23091             NaN                                      NaN
# 23092             NaN                                      NaN
# ...               ...                                      ...
# 17882  PHUCCHNG Index                Pending Home Sales Change
# 19078  RCSSCLBC Index               Retail Sales Control Group
# 19096  REALYRAW Index   Real Personal Consumption Expenditures
# 19097  REDSMMOM Index  Redbook Same-Store Sales Monthly Change
# 23087   VNCCTOT Index                      Vehicle Sales Total
#
#                                          Broad indicator     Date_es  \
# 23088                                                NaN  09/10/1997
# 23089                                                NaN  09/10/1997
# 23090                                                NaN  09/10/1997
# 23091                                                NaN  09/10/1997
# 23092                                                NaN  09/10/1997
# ...                                                  ...         ...
# 17882  Building permits - new private housing units a...         NaN
# 19078                                       Retail sales         NaN
# 19096                                    GDP growth rate         NaN
# 19097                                       Retail sales         NaN
# 23087                                       Retail sales         NaN
#
#         Time_es  Open  Close  Volume            DateTime Date_surprise  ...  \
# 23088  00:01:00   0.0    0.0     0.0 1997-09-10 00:01:00           NaN  ...
# 23089  00:02:00   0.0    0.0     0.0 1997-09-10 00:02:00           NaN  ...
# 23090  00:03:00   0.0    0.0     0.0 1997-09-10 00:03:00           NaN  ...
# 23091  00:04:00   0.0    0.0     0.0 1997-09-10 00:04:00           NaN  ...
# 23092  00:05:00   0.0    0.0     0.0 1997-09-10 00:05:00           NaN  ...
# ...         ...   ...    ...     ...                 ...           ...  ...
# 17882       NaN   NaN    NaN     NaN                 NaT           NaN  ...
# 19078       NaN   NaN    NaN     NaN                 NaT           NaN  ...
# 19096       NaN   NaN    NaN     NaN                 NaT           NaN  ...
# 19097       NaN   NaN    NaN     NaN                 NaT           NaN  ...
# 23087       NaN   NaN    NaN     NaN                 NaT           NaN  ...
#
#       Flag     _merge Surprise Occurred First Post Surprise N_Return  \
# 23088  NaN  left_only             False               False      NaN
# 23089  NaN  left_only             False               False      NaN
# 23090  NaN  left_only             False               False      NaN
# 23091  NaN  left_only             False               False      NaN
# 23092  NaN  left_only             False               False      NaN
# ...    ...        ...               ...                 ...      ...
# 17882  NaN        NaN               NaN                 NaN      NaN
# 19078  NaN        NaN               NaN                 NaN      NaN
# 19096  NaN        NaN               NaN                 NaN      NaN
# 19097  NaN        NaN               NaN                 NaN      NaN
# 23087  NaN        NaN               NaN                 NaN      NaN
#
#       N_Return_half N_Return_double Return Return_half Return_double
# 23088           NaN             NaN    NaN         NaN           NaN
# 23089           NaN             NaN    NaN         NaN           NaN
# 23090           NaN             NaN    NaN         NaN           NaN
# 23091           NaN             NaN    NaN         NaN           NaN
# 23092           NaN             NaN    NaN         NaN           NaN
# ...             ...             ...    ...         ...           ...
# 17882           NaN             NaN    NaN         NaN           NaN
# 19078           NaN             NaN    NaN         NaN           NaN
# 19096           NaN             NaN    NaN         NaN           NaN
# 19097           NaN             NaN    NaN         NaN           NaN
# 23087           NaN             NaN    NaN         NaN           NaN
#
# [9695685 rows x 39 columns]

# %%
df_combined.columns
# Out:
# Index(['Ticker', 'Description', 'Broad indicator', 'Date_es', 'Time_es',
#        'Open', 'Close', 'Volume', 'DateTime', 'Date_surprise', 'Period',
#        'Event', 'Actual', 'Prior', 'Revised', 'Freq.', 'First Rev.',
#        'Last Rev.', 'Time_surprise', 'C', 'Category', 'Subcategory', 'R',
#        'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise', 'Country/Region',
#        'Flag', '_merge', 'Surprise Occurred', 'First Post Surprise',
#        'N_Return', 'N_Return_half', 'N_Return_double', 'Return', 'Return_half',
#        'Return_double'],
#       dtype='object')

# %%
economic_data = economic_data.copy()
economic_data['DateTime'] = pd.to_datetime(economic_data.index).floor('D')

# %% [markdown]
# **The final statistical model**

# %%
# Vas

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model as skl
from sklearn.model_selection import KFold
import statsmodels.api as sm
from sklearn.pipeline import Pipeline

total_cost = 2 * transaction_cost
horizons = ['_half', '', '_double']
lambdas = np.linspace(0.001, 0.2, 20)

# --- Data Preparation ---
df_combined['DateTime'] = pd.to_datetime(df_combined['DateTime'])
df_combined = df_combined.sort_values('DateTime').reset_index(drop=True)
min_date = df_combined['DateTime'].min()
max_date = df_combined['DateTime'].max()

# --- Initial Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking Containers ---
all_test_returns = []
all_dates = []
best_horizons_list = []

def identify_broad_indicators(train_data, economic_data):
    """Identify significant economic indicators using Lasso->OLS pipeline"""
    try:
        print("\n=== Identifying Indicators ===")

        # 1. Get date range from training data
        train_dates = train_data['DateTime']
        start_date = train_dates.min()
        end_date = train_dates.max()
        print(f"Training period: {start_date} to {end_date}")

        # 2. Prepare economic data
        economic_data.index = pd.to_datetime(economic_data.index)

        # 3. Filter economic data to training period
        mask = (economic_data.index >= start_date) & (economic_data.index <= end_date)
        econ_subset = economic_data.loc[mask].copy()

        if len(econ_subset) == 0:
            return {}

        # 4. Prepare features and target
        y = econ_subset['SP500']
        X = econ_subset.filter(like='_L1')

        if X.empty:
            return {}

        # 5. LassoCV pipeline
        scaler = StandardScaler(with_mean=True, with_std=True)
        kfold = KFold(n_splits=5, random_state=0, shuffle=True)

        lassoCV = skl.ElasticNetCV(
            alphas=lambdas,
            l1_ratio=1,
            cv=kfold,
            max_iter=10000,
            random_state=0
        )

        pipeCV = Pipeline(steps=[('scaler', scaler), ('lasso', lassoCV)])
        pipeCV.fit(X, y)

        tuned_lasso = pipeCV.named_steps['lasso']
        selected = X.columns[tuned_lasso.coef_ != 0]

        # 6. OLS stage
        significant_vars = {}
        if len(selected) > 0:
            X_selected = sm.add_constant(X[selected])
            ols = sm.OLS(y, X_selected).fit(cov_type='HC3')

            significant_vars = {
                var: ols.params[var]
                for var in selected
                if ols.pvalues[var] < 0.05
            }

        return significant_vars or {}

    except Exception as e:
        print(f"Indicator identification error: {str(e)}")
        return {}

def calculate_grouped_returns(group, coef, horizon):
    """Calculate returns with proper per-trade position sizing"""
    if group.empty:
        return 0.0

    long_returns = []
    short_returns = []

    # Process each trade individually
    for _, row in group.iterrows():
        surprise = row['Surprise']
        ret = row[f'N_Return{horizon}']

        if coef * surprise > 0:  # Long condition
            net_return = ret - total_cost
            long_returns.append(net_return)
        else:  # Short condition
            net_return = -ret - total_cost
            short_returns.append(net_return)

    # Calculate weighted returns
    long_weight = 1/len(long_returns) if long_returns else 0
    total_long = sum(long_returns) * long_weight
    total_short = sum(short_returns)  # Full weight per short

    return total_long + total_short

# --- Main Backtest Loop ---
while True:
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    if val_end_date > max_date or test_end_date > max_date:
        break

    # Create masks
    train_mask = df_combined['DateTime'] <= train_end_date
    val_mask = (df_combined['DateTime'] >= val_start_date) & (df_combined['DateTime'] <= val_end_date)
    test_mask = (df_combined['DateTime'] >= test_start_date) & (df_combined['DateTime'] <= test_end_date)

    train_data = df_combined[train_mask]
    val_data = df_combined[val_mask]
    test_data = df_combined[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Economic Indicator Identification ---
    sig_coefs = identify_broad_indicators(train_data, economic_data)

    if not sig_coefs:
        print(f"No significant indicators found for period ending {train_end_date.date()}")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Process Each Indicator ---
    current_returns = []
    current_dates = []
    for l1_var, coef in sig_coefs.items():
        indicator = {
            'gdp_gr_L1': 'GDP growth rate',
            'ffr_L1': 'Interest rate',
            'NFP_L1': 'Non-farm payrolls',
            'un_rate_L1': 'Unemployment rate',
            'cci_L1': 'Consumer confidence index',
            'ret_sales_L1': 'Retail sales',
            'IPTI_L1': 'Industrial production',
            'cpi_L1': 'Inflation rate',
            'TXBPPRIVSA_L1': 'Building permits'
        }.get(l1_var)

        if not indicator:
            continue

        # --- Validation Phase ---
        val_events = val_data[val_data['Broad indicator'] == indicator]
        horizon_perf = {}

        for horizon in horizons:
            val_trades = val_events[['DateTime', 'Surprise', f'N_Return{horizon}']].copy()

            if not val_trades.empty:
                grouped_returns = val_trades.groupby('DateTime').apply(
                    lambda x: calculate_grouped_returns(x, coef, horizon)
                )
                horizon_perf[horizon] = (1 + grouped_returns).prod() - 1

        if horizon_perf:
            optimal_horizon = max(horizon_perf, key=horizon_perf.get)

            # --- Test Phase ---
            test_events = test_data[test_data['Broad indicator'] == indicator]
            if not test_events.empty:
                test_trades = test_events[['DateTime', 'Surprise', f'N_Return{optimal_horizon}']].copy()

                test_grouped = test_trades.groupby('DateTime').apply(
                    lambda x: calculate_grouped_returns(x, coef, optimal_horizon)
                )

                if not test_grouped.empty:
                    current_returns.extend(test_grouped.values)
                    current_dates.extend(test_grouped.index.tolist())
                    best_horizons_list.append(optimal_horizon)

    # Store results with date cleaning
    if current_returns:
        # Aggregate same-date returns
        date_df = pd.DataFrame({'date': current_dates, 'return': current_returns})
        daily_returns = date_df.groupby('date')['return'].sum().reset_index()

        all_test_returns.extend(daily_returns['return'].tolist())
        all_dates.extend(daily_returns['date'].tolist())

    train_end_date += pd.DateOffset(years=1)

# --- Results & Plotting ---
if all_test_returns:
    # Create clean chronological series
    returns_df = pd.DataFrame({'date': all_dates, 'return': all_test_returns})
    returns_df = returns_df.sort_values('date').drop_duplicates('date')
    returns_df = returns_df.set_index('date').resample('D').ffill()  # Fill gaps

    cumulative_returns = (1 + returns_df['return']).cumprod() - 1

    plt.figure(figsize=(12, 6))
    plt.plot(cumulative_returns.index, cumulative_returns * 100)
    plt.title('Economic Indicator Strategy Cumulative Returns')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    # Performance statistics
    total_return = cumulative_returns.iloc[-1] * 100
    max_drawdown = (cumulative_returns.expanding().max() - cumulative_returns).max() * 100

    print(f"Final Cumulative Return: {total_return:.2f}%")
    print(f"Maximum Drawdown: {max_drawdown:.2f}%")
    print("\nOptimal Horizon Distribution:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2005-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2006-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2007-11-15 19:12:00
# No significant indicators found for period ending 2007-11-15
#
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2008-11-14 15:15:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2009-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2010-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2011-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2012-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2013-11-15 16:15:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2014-11-14 16:15:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2015-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2016-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2017-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2018-11-15 19:12:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2019-11-15 16:00:00
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:180: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = val_trades.groupby('DateTime').apply(
# <ipython-input-91-2ad2303b7329>:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_grouped = test_trades.groupby('DateTime').apply(
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2020-11-15 19:12:00
# No significant indicators found for period ending 2020-11-15
#
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2021-11-15 19:12:00
# No significant indicators found for period ending 2021-11-15
#
# === Identifying Indicators ===
# Training period: 1997-09-10 00:01:00 to 2022-11-15 19:12:00
# No significant indicators found for period ending 2022-11-15
# Final Cumulative Return: 12.88%
# Maximum Drawdown: 26.66%
#
# Optimal Horizon Distribution:
# _double    7
#            5
# _half      4
# Name: count, dtype: int64

# %% [markdown]
# # **Theoretical Maximum Returns from our data**

# %% [markdown]
# **Using all surprises**

# %%
# prompt: split df_combined into two halfs called first and second and then split second into 14 equal parts and compute the cumulative compounded return from the absolute value of Return, Return_half and Return_double and then store only the highest of the 3 to a list called optimal_compounded_return and then at the end print the cumulative compounded return of all 14 of this list's values

first_half, second_half = np.array_split(df_combined, 2)

second_half_parts = np.array_split(second_half, 14)

optimal_compounded_returns = []

# Process each of the 14 parts
for part in second_half_parts:
    # Calculate cumulative compounded returns for each return type
    returns = {
        'Return': (1 + abs(part['Return'])).prod() - 1,
        'Return_half': (1 + abs(part['Return_half'])).prod() - 1,
        'Return_double': (1 + abs(part['Return_double'])).prod() - 1
    }

    # Store the highest return
    optimal_return = max(returns.values())
    optimal_compounded_returns.append(optimal_return)

    # Print details for this part
    print(f"Period: {part['DateTime'].iloc[0].date()} to {part['DateTime'].iloc[-1].date()}")
    print(f"Returns - Full: {returns['Return']*100:.2f}%, Half: {returns['Return_half']*100:.2f}%, Double: {returns['Return_double']*100:.2f}%")
    print(f"Selected optimal return: {optimal_return*100:.2f}%\n")

# Calculate and print final cumulative return
cumulative_return = (1 + pd.Series(optimal_compounded_returns)).prod() - 1
print(f"\nCumulative compounded return across all 14 periods: {cumulative_return*100:.2f}%")
print(f"\nAverage Annual Compounded Return (positive trades only): {((cumulative_return+1)**(1/14)-1)*100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
# Period: 2011-04-08 to 2012-03-26
# Returns - Full: 660.18%, Half: 564.26%, Double: 1151.24%
# Selected optimal return: 1151.24%
#
# Period: 2012-03-26 to 2013-03-14
# Returns - Full: 341.26%, Half: 226.55%, Double: 448.73%
# Selected optimal return: 448.73%
#
# Period: 2013-03-14 to 2014-03-07
# Returns - Full: 252.57%, Half: 178.46%, Double: 353.38%
# Selected optimal return: 353.38%
#
# Period: 2014-03-07 to 2015-03-01
# Returns - Full: 215.62%, Half: 168.13%, Double: 305.83%
# Selected optimal return: 305.83%
#
# Period: 2015-03-01 to 2016-02-22
# Returns - Full: 300.39%, Half: 205.02%, Double: 529.52%
# Selected optimal return: 529.52%
#
# Period: 2016-02-22 to 2017-02-15
# Returns - Full: 149.62%, Half: 105.83%, Double: 213.09%
# Selected optimal return: 213.09%
#
# Period: 2017-02-15 to 2018-02-11
# Returns - Full: 80.89%, Half: 56.27%, Double: 104.47%
# Selected optimal return: 104.47%
#
# Period: 2018-02-11 to 2019-02-06
# Returns - Full: 239.22%, Half: 175.81%, Double: 377.41%
# Selected optimal return: 377.41%
#
# Period: 2019-02-06 to 2020-02-03
# Returns - Full: 171.51%, Half: 119.31%, Double: 287.79%
# Selected optimal return: 287.79%
#
# Period: 2020-02-03 to 2021-01-27
# Returns - Full: 871.47%, Half: 456.58%, Double: 2584.44%
# Selected optimal return: 2584.44%
#
# Period: 2021-01-27 to 2022-01-18
# Returns - Full: 275.58%, Half: 169.36%, Double: 436.72%
# Selected optimal return: 436.72%
#
# Period: 2022-01-18 to 2023-01-10
# Returns - Full: 5367.04%, Half: 2726.38%, Double: 16833.02%
# Selected optimal return: 16833.02%
#
# Period: 2023-01-10 to 2024-01-01
# Returns - Full: 538.63%, Half: 320.77%, Double: 897.94%
# Selected optimal return: 897.94%
#
# Period: 2024-01-01 to NaT
# Returns - Full: 599.81%, Half: 419.78%, Double: 878.99%
# Selected optimal return: 878.99%
#
#
# Cumulative compounded return across all 14 periods: 224670593563021.09%
#
# Average Annual Compounded Return (positive trades only): 662.52%

# %% [markdown]
# **Using all surprise with transaction costs**

# %%
first_half, second_half = np.array_split(df_combined, 2)

# Split the second half into 14 equal parts
second_half_parts = np.array_split(second_half, 14)

optimal_compounded_returns = []

total_cost = 2*transaction_cost

# Process each of the 14 parts
for part in second_half_parts:
    # Calculate net returns after transaction costs
    net_returns = {
        'Return': abs(part['Return']) - total_cost,  # total_cost = 2*transaction_cost
        'Return_half': abs(part['Return_half']) - total_cost,
        'Return_double': abs(part['Return_double']) - total_cost
    }

    # Calculate cumulative compounded returns
    compounded_returns = {
        'Return': (1 + net_returns['Return']).prod() - 1,
        'Return_half': (1 + net_returns['Return_half']).prod() - 1,
        'Return_double': (1 + net_returns['Return_double']).prod() - 1
    }

    # Store the highest return
    optimal_return = max(compounded_returns.values())
    optimal_compounded_returns.append(optimal_return)

    # Print details for this part
    print(f"Period: {part['DateTime'].iloc[0].date()} to {part['DateTime'].iloc[-1].date()}")
    print(f"Compounded Returns (after costs):")
    print(f"Full: {compounded_returns['Return']*100:.2f}%")
    print(f"Half: {compounded_returns['Return_half']*100:.2f}%")
    print(f"Double: {compounded_returns['Return_double']*100:.2f}%")
    print(f"Selected optimal return: {optimal_return*100:.2f}%\n")

# Calculate and print final cumulative return
cumulative_return = (1 + pd.Series(optimal_compounded_returns)).prod() - 1
print(f"\nFinal Cumulative Compounded Return (after costs): {cumulative_return*100:.2f}%")
print(f"\nAverage Annual Compounded Return (positive trades only): {((cumulative_return+1)**(1/14)-1)*100:.2f}%")
# Out:
# Period: 2011-04-08 to 2012-03-26
# Compounded Returns (after costs):
# Full: 625.24%
# Half: 533.73%
# Double: 1093.76%
# Selected optimal return: 1093.76%
#
# Period: 2012-03-26 to 2013-03-14
# Compounded Returns (after costs):
# Full: 320.84%
# Half: 211.43%
# Double: 423.35%
# Selected optimal return: 423.35%
#
# Period: 2013-03-14 to 2014-03-07
# Compounded Returns (after costs):
# Full: 235.36%
# Half: 164.86%
# Double: 331.26%
# Selected optimal return: 331.26%
#
# Period: 2014-03-07 to 2015-03-01
# Compounded Returns (after costs):
# Full: 200.23%
# Half: 155.05%
# Double: 286.04%
# Selected optimal return: 286.04%
#
# Period: 2015-03-01 to 2016-02-22
# Compounded Returns (after costs):
# Full: 280.47%
# Half: 189.84%
# Double: 498.22%
# Selected optimal return: 498.22%
#
# Period: 2016-02-22 to 2017-02-15
# Compounded Returns (after costs):
# Full: 137.31%
# Half: 95.68%
# Double: 197.66%
# Selected optimal return: 197.66%
#
# Period: 2017-02-15 to 2018-02-11
# Compounded Returns (after costs):
# Full: 72.14%
# Half: 48.71%
# Double: 94.59%
# Selected optimal return: 94.59%
#
# Period: 2018-02-11 to 2019-02-06
# Compounded Returns (after costs):
# Full: 223.59%
# Half: 163.10%
# Double: 355.41%
# Selected optimal return: 355.41%
#
# Period: 2019-02-06 to 2020-02-03
# Compounded Returns (after costs):
# Full: 157.22%
# Half: 107.76%
# Double: 267.39%
# Selected optimal return: 267.39%
#
# Period: 2020-02-03 to 2021-01-27
# Compounded Returns (after costs):
# Full: 818.48%
# Half: 426.20%
# Double: 2438.15%
# Selected optimal return: 2438.15%
#
# Period: 2021-01-27 to 2022-01-18
# Compounded Returns (after costs):
# Full: 255.11%
# Half: 154.68%
# Double: 407.49%
# Selected optimal return: 407.49%
#
# Period: 2022-01-18 to 2023-01-10
# Compounded Returns (after costs):
# Full: 5057.16%
# Half: 2566.09%
# Double: 15874.11%
# Selected optimal return: 15874.11%
#
# Period: 2023-01-10 to 2024-01-01
# Compounded Returns (after costs):
# Full: 503.39%
# Half: 297.54%
# Double: 842.90%
# Selected optimal return: 842.90%
#
# Period: 2024-01-01 to NaT
# Compounded Returns (after costs):
# Full: 560.07%
# Half: 390.26%
# Double: 823.42%
# Selected optimal return: 823.42%
#
#
# Final Cumulative Compounded Return (after costs): 108027432606909.41%
#
# Average Annual Compounded Return (positive trades only): 623.67%

# %% [markdown]
# **Theoretical maximum for ML model with transaction costs** - this represents post transaction cost returns for an ML model that always predicts when you should short or long the futures to make a profit after transaction costs or simply not trade as neither makes a profit and picks the correct optimal holding period everytime

# %%
first_half, second_half = np.array_split(df_combined, 2)

# Split the second half into 14 equal parts
second_half_parts = np.array_split(second_half, 14)

optimal_compounded_returns = []
total_cost = 2 * transaction_cost

# Process each of the 14 parts
for part in second_half_parts:
    # Calculate net returns after transaction costs and filter positive ones
    positive_net_returns = {
        'Return': abs(part['Return']) - total_cost,
        'Return_half': abs(part['Return_half']) - total_cost,
        'Return_double': abs(part['Return_double']) - total_cost
    }

    # Filter to keep only positive net returns for each horizon
    positive_net_returns = {
        k: v[v > 0] for k, v in positive_net_returns.items()
    }

    # Calculate cumulative compounded returns using only positive net returns
    compounded_returns = {}
    for horizon in ['Return', 'Return_half', 'Return_double']:
        if len(positive_net_returns[horizon]) > 0:
            compounded_returns[horizon] = (1 + positive_net_returns[horizon]).prod() - 1
        else:
            compounded_returns[horizon] = 0  # No positive returns case

        # Print debug info
        print(f"{horizon}: {len(positive_net_returns[horizon])} positive trades")

    # Store the highest return
    optimal_return = max(compounded_returns.values())
    optimal_compounded_returns.append(optimal_return)

    # Print details for this part
    print(f"\nPeriod: {part['DateTime'].iloc[0].date()} to {part['DateTime'].iloc[-1].date()}")
    print(f"Compounded Returns (positive trades only):")
    print(f"Full: {compounded_returns['Return']*100:.2f}% (n={len(positive_net_returns['Return'])})")
    print(f"Half: {compounded_returns['Return_half']*100:.2f}% (n={len(positive_net_returns['Return_half'])})")
    print(f"Double: {compounded_returns['Return_double']*100:.2f}% (n={len(positive_net_returns['Return_double'])})")
    print(f"Selected optimal return: {optimal_return*100:.2f}%\n")

# Calculate and print final cumulative return
cumulative_return = (1 + pd.Series(optimal_compounded_returns)).prod() - 1
print(f"\nFinal Cumulative Compounded Return (positive trades only): {cumulative_return*100:.2f}%")
print(f"\nAverage Annual Compounded Return (positive trades only): {((cumulative_return+1)**(1/14)-1)*100:.2f}%")
# Out:
# Return: 900 positive trades
# Return_half: 901 positive trades
# Return_double: 924 positive trades
#
# Period: 2011-04-08 to 2012-03-26
# Compounded Returns (positive trades only):
# Full: 626.80% (n=900)
# Half: 535.06% (n=901)
# Double: 1094.89% (n=924)
# Selected optimal return: 1094.89%
#
# Return: 919 positive trades
# Return_half: 876 positive trades
# Return_double: 908 positive trades
#
# Period: 2012-03-26 to 2013-03-14
# Compounded Returns (positive trades only):
# Full: 321.48% (n=919)
# Half: 212.57% (n=876)
# Double: 424.42% (n=908)
# Selected optimal return: 424.42%
#
# Return: 945 positive trades
# Return_half: 931 positive trades
# Return_double: 954 positive trades
#
# Period: 2013-03-14 to 2014-03-07
# Compounded Returns (positive trades only):
# Full: 236.32% (n=945)
# Half: 165.80% (n=931)
# Double: 332.29% (n=954)
# Selected optimal return: 332.29%
#
# Return: 936 positive trades
# Return_half: 940 positive trades
# Return_double: 961 positive trades
#
# Period: 2014-03-07 to 2015-03-01
# Compounded Returns (positive trades only):
# Full: 201.20% (n=936)
# Half: 155.83% (n=940)
# Double: 286.82% (n=961)
# Selected optimal return: 286.82%
#
# Return: 988 positive trades
# Return_half: 973 positive trades
# Return_double: 983 positive trades
#
# Period: 2015-03-01 to 2016-02-22
# Compounded Returns (positive trades only):
# Full: 281.12% (n=988)
# Half: 190.55% (n=973)
# Double: 499.38% (n=983)
# Selected optimal return: 499.38%
#
# Return: 953 positive trades
# Return_half: 945 positive trades
# Return_double: 979 positive trades
#
# Period: 2016-02-22 to 2017-02-15
# Compounded Returns (positive trades only):
# Full: 138.02% (n=953)
# Half: 96.34% (n=945)
# Double: 198.15% (n=979)
# Selected optimal return: 198.15%
#
# Return: 944 positive trades
# Return_half: 896 positive trades
# Return_double: 938 positive trades
#
# Period: 2017-02-15 to 2018-02-11
# Compounded Returns (positive trades only):
# Full: 72.56% (n=944)
# Half: 49.43% (n=896)
# Double: 95.11% (n=938)
# Selected optimal return: 95.11%
#
# Return: 915 positive trades
# Return_half: 890 positive trades
# Return_double: 922 positive trades
#
# Period: 2018-02-11 to 2019-02-06
# Compounded Returns (positive trades only):
# Full: 224.07% (n=915)
# Half: 163.82% (n=890)
# Double: 355.94% (n=922)
# Selected optimal return: 355.94%
#
# Return: 1046 positive trades
# Return_half: 1029 positive trades
# Return_double: 1050 positive trades
#
# Period: 2019-02-06 to 2020-02-03
# Compounded Returns (positive trades only):
# Full: 157.68% (n=1046)
# Half: 108.32% (n=1029)
# Double: 267.98% (n=1050)
# Selected optimal return: 267.98%
#
# Return: 1095 positive trades
# Return_half: 1085 positive trades
# Return_double: 1094 positive trades
#
# Period: 2020-02-03 to 2021-01-27
# Compounded Returns (positive trades only):
# Full: 819.81% (n=1095)
# Half: 427.23% (n=1085)
# Double: 2441.96% (n=1094)
# Selected optimal return: 2441.96%
#
# Return: 1093 positive trades
# Return_half: 1089 positive trades
# Return_double: 1101 positive trades
#
# Period: 2021-01-27 to 2022-01-18
# Compounded Returns (positive trades only):
# Full: 255.62% (n=1093)
# Half: 155.10% (n=1089)
# Double: 408.02% (n=1101)
# Selected optimal return: 408.02%
#
# Return: 1163 positive trades
# Return_half: 1148 positive trades
# Return_double: 1164 positive trades
#
# Period: 2022-01-18 to 2023-01-10
# Compounded Returns (positive trades only):
# Full: 5059.22% (n=1163)
# Half: 2569.15% (n=1148)
# Double: 15879.70% (n=1164)
# Selected optimal return: 15879.70%
#
# Return: 1117 positive trades
# Return_half: 1110 positive trades
# Return_double: 1129 positive trades
#
# Period: 2023-01-10 to 2024-01-01
# Compounded Returns (positive trades only):
# Full: 503.99% (n=1117)
# Half: 298.08% (n=1110)
# Double: 843.28% (n=1129)
# Selected optimal return: 843.28%
#
# Return: 1135 positive trades
# Return_half: 1109 positive trades
# Return_double: 1143 positive trades
#
# Period: 2024-01-01 to NaT
# Compounded Returns (positive trades only):
# Full: 560.54% (n=1135)
# Half: 391.13% (n=1109)
# Double: 824.01% (n=1143)
# Selected optimal return: 824.01%
#
#
# Final Cumulative Compounded Return (positive trades only): 110252504131502.81%
#
# Average Annual Compounded Return (positive trades only): 624.72%

# %% [markdown]
# **Results above shows the problem of overtrading with our problem at hand - so want to also give the option to not trade especially if not going to make a profit on the trade**

# %% [markdown]
# # **ML model**

# %% [markdown]
# **First creating classification variables using transaction cost of 0.0025bps and explanatory variables to use in models**

# %%
# For Profit measure
df_combined['Profit'] = np.where(
    np.isnan(df_combined['Return']),
    np.nan,  # If Return is NaN, set Profit to NaN
    np.where(
        df_combined['Return'] > 2 * transaction_cost,
        1,  # Profitable long
        np.where(
            -df_combined['Return'] > 2 * transaction_cost,
            2,  # Profitable short
            0    # Neutral (within cost bounds)
        )
    )
)

# For Profit_half measure
df_combined['Profit_half'] = np.where(
    np.isnan(df_combined['Return_half']),
    np.nan,
    np.where(
        df_combined['Return_half'] > 2 * transaction_cost,
        1,
        np.where(
            -df_combined['Return_half'] > 2 * transaction_cost,
            2,
            0
        )
    )
)

# For Profit_double measure
df_combined['Profit_double'] = np.where(
    np.isnan(df_combined['Return_double']),
    np.nan,
    np.where(
        df_combined['Return_double'] > 2 * transaction_cost,
        1,
        np.where(
            -df_combined['Return_double'] > 2 * transaction_cost,
            2,
            0
        )
    )
)

# %%
df_intm = df_combined[df_combined['Surprise Occurred'] == True]

# %%
df_intm['Return'].isna().sum()

"""
This confirms that we need to properly line up our new Profit variables first as they correspond to the observation after
their CORRESPONDING surprise occurs so they would be using the wrong Surprise value and ticker in our ML model, not a problem
for the previous models as they didn't use these variables.

Also have to shift Return values up one row for the same reason
"""
# Out:
# "\nThis confirms that we need to properly line up our new Profit variables first as they correspond to the observation after\ntheir CORRESPONDING surprise occurs so they would be using the wrong Surprise value and ticker in our ML model, not a problem\nfor the previous models as they didn't use these variables.\n\nAlso have to shift Return values up one row for the same reason\n"

# %%
df_combined['Return'] = df_combined['Return'].shift(-1)
df_combined['Return_half'] = df_combined['Return_half'].shift(-1)
df_combined['Return_double'] = df_combined['Return_double'].shift(-1)

df_combined['Profit'] = df_combined['Profit'].shift(-1)
df_combined['Profit_half'] = df_combined['Profit_half'].shift(-1)
df_combined['Profit_double'] = df_combined['Profit_double'].shift(-1)

# %%
df_combined.columns
# Out:
# Index(['Ticker', 'Description', 'Broad indicator', 'Date_es', 'Time_es',
#        'Open', 'Close', 'Volume', 'DateTime', 'Date_surprise', 'Period',
#        'Event', 'Actual', 'Prior', 'Revised', 'Freq.', 'First Rev.',
#        'Last Rev.', 'Time_surprise', 'C', 'Category', 'Subcategory', 'R',
#        'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise', 'Country/Region',
#        'Flag', '_merge', 'Surprise Occurred', 'First Post Surprise',
#        'N_Return', 'N_Return_half', 'N_Return_double', 'Return', 'Return_half',
#        'Return_double', 'Profit', 'Profit_half', 'Profit_double'],
#       dtype='object')

# %%
# Seeing if the profit classifier was correctly created by looking at some rows for when classification variable = 0,1 & 2
df_combined[df_combined['Profit'] == 1].head()
# Out:
#                 Ticker                             Description  \
# 102674  GDP CQOQ Index                GDP Quarterly Change QoQ
# 224729  GDP CQOQ Index                GDP Quarterly Change QoQ
# 254264   NAPMPMI Index                                     NaN
# 255690   NHSLTOT Index                    New Home Sales Total
# 258540  PRODNFR% Index  Nonfarm Productivity Percentage Change
#
#                                           Broad indicator     Date_es  \
# 102674                                    GDP growth rate  12/23/1997
# 224729                                    GDP growth rate  04/30/1998
# 254264                                                NaN  06/01/1998
# 255690  Building permits - new private housing units a...  06/02/1998
# 258540                                    GDP growth rate  06/04/1998
#
#          Time_es     Open    Close  Volume            DateTime Date_surprise  \
# 102674  07:30:00  1189.71  1189.71     0.0 1997-12-23 07:30:00    1997-12-23
# 224729  07:30:00  1338.85  1338.85     0.0 1998-04-30 07:30:00    1998-04-30
# 254264  09:00:00  1335.49  1334.87     0.0 1998-06-01 09:00:00    1998-06-01
# 255690  09:00:00  1343.12  1342.51     0.0 1998-06-02 09:00:00    1998-06-02
# 258540  09:00:00  1320.21  1321.13     0.0 1998-06-04 09:00:00    1998-06-04
#
#         ... First Post Surprise N_Return N_Return_half N_Return_double  \
# 102674  ...               False      NaN           NaN             NaN
# 224729  ...               False      NaN           NaN             NaN
# 254264  ...               False      NaN           NaN             NaN
# 255690  ...               False      NaN           NaN             NaN
# 258540  ...               False      NaN           NaN             NaN
#
#           Return Return_half Return_double Profit Profit_half Profit_double
# 102674  0.000261    0.000261      0.000000    1.0         1.0           0.0
# 224729  0.012553    0.010044      0.013008    1.0         1.0           1.0
# 254264  0.003439    0.003206      0.003206    1.0         1.0           1.0
# 255690  0.000909    0.000685     -0.001594    1.0         1.0           2.0
# 258540  0.003242    0.004166      0.002545    1.0         1.0           1.0
#
# [5 rows x 42 columns]

# %%
# Seeing if the profit classifier was correctly created by looking at some rows for when classification variable = 0,1 & 2

df_combined[df_combined['Profit'] == 2].head()
# Out:
#                 Ticker                                Description  \
# 191129  GDP CQOQ Index                   GDP Quarterly Change QoQ
# 258450    INJCJC Index                     Initial Jobless Claims
# 266881  PPI CHNG Index  Producer Price Index (PPI) Monthly Change
# 266882  PXFECHNG Index                                        NaN
# 269611             NaN                                        NaN
#
#           Broad indicator     Date_es   Time_es     Open    Close  Volume  \
# 191129    GDP growth rate  03/26/1998  07:30:00  1355.65  1355.96     0.0
# 258450  Unemployment rate  06/04/1998  07:30:00  1322.96  1323.57     0.0
# 266881     Inflation rate  06/12/1998  07:30:00  1337.57  1337.57     0.0
# 266882                NaN  06/12/1998  07:30:00  1337.57  1337.57     0.0
# 269611                NaN  06/16/1998  07:29:00  1321.86  1321.86     0.0
#
#                   DateTime Date_surprise  ... First Post Surprise  N_Return  \
# 191129 1998-03-26 07:30:00    1998-03-26  ...               False       NaN
# 258450 1998-06-04 07:30:00    1998-06-04  ...               False       NaN
# 266881 1998-06-12 07:30:00    1998-06-12  ...               False       NaN
# 266882 1998-06-12 07:30:00    1998-06-12  ...                True -0.001129
# 269611 1998-06-16 07:29:00           NaN  ...               False       NaN
#
#        N_Return_half N_Return_double    Return Return_half Return_double  \
# 191129           NaN             NaN -0.000229    0.001350      0.000000
# 258450           NaN             NaN -0.000461    0.000227     -0.000461
# 266881           NaN             NaN -0.001129   -0.001129      0.000680
# 266882     -0.001129         0.00068 -0.001353   -0.001129      0.000224
# 269611           NaN             NaN -0.000461    0.000000      0.000227
#
#        Profit Profit_half Profit_double
# 191129    2.0         1.0           0.0
# 258450    2.0         1.0           2.0
# 266881    2.0         2.0           1.0
# 266882    2.0         2.0           1.0
# 269611    2.0         0.0           1.0
#
# [5 rows x 42 columns]

# %%
df_combined['Profit'].value_counts()
# Out:
# Profit
# 1.0    11292
# 2.0    10834
# 0.0      942
# Name: count, dtype: int64

# %%
# Now we create the technical explanatory variables based on literature

def create_technical_features(df):
    """
    Creates all technical features for a dataframe containing price/volume data
    and three return columns (Return, Return_half, Return_double)
    """
    # 1. Original Features
    df['Volume'] = df['Volume']
    df['Price'] = df['Open']

    # 2. Simple Moving Averages
    ma_windows = [5, 15, 20, 50, 100, 200]
    for window in ma_windows:
        df[f'SMA{window}'] = df['Open'].rolling(window).mean()

    # 3. Moving Average Crossovers
    for window in [5, 10, 15, 20, 50, 100, 200]:
        # Handle case where SMA might not exist yet (like SMA10 when we only created SMA5,15,20...)
        if f'SMA{window}' in df.columns:
            df[f'SMA{window}Cross'] = (df['Open'] > df[f'SMA{window}']).astype(int)

    # 4. Consecutive Price Trends
    trend_periods = [10, 15, 50]
    for period in trend_periods:
        df[f'UpDown{period}'] = np.sign(df['Open'].pct_change(period))

    # Ensure we keep the original return columns
    return_cols = ['Return', 'Return_half', 'Return_double']
    for col in return_cols:
        if col in df.columns:
            df[col] = df[col]  # Maintain existing returns

    return df

# Example usage:
# df_combined must contain: 'volume', 'close' columns plus the 3 return columns
df_combined = create_technical_features(df_combined)
# Out:
# <ipython-input-103-1d22a18122ca>:26: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df[f'UpDown{period}'] = np.sign(df['Open'].pct_change(period))
# <ipython-input-103-1d22a18122ca>:26: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df[f'UpDown{period}'] = np.sign(df['Open'].pct_change(period))
# <ipython-input-103-1d22a18122ca>:26: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df[f'UpDown{period}'] = np.sign(df['Open'].pct_change(period))

# %%
df_combined.columns
# Out:
# Index(['Ticker', 'Description', 'Broad indicator', 'Date_es', 'Time_es',
#        'Open', 'Close', 'Volume', 'DateTime', 'Date_surprise', 'Period',
#        'Event', 'Actual', 'Prior', 'Revised', 'Freq.', 'First Rev.',
#        'Last Rev.', 'Time_surprise', 'C', 'Category', 'Subcategory', 'R',
#        'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise', 'Country/Region',
#        'Flag', '_merge', 'Surprise Occurred', 'First Post Surprise',
#        'N_Return', 'N_Return_half', 'N_Return_double', 'Return', 'Return_half',
#        'Return_double', 'Profit', 'Profit_half', 'Profit_double', 'Price',
#        'SMA5', 'SMA15', 'SMA20', 'SMA50', 'SMA100', 'SMA200', 'SMA5Cross',
#        'SMA15Cross', 'SMA20Cross', 'SMA50Cross', 'SMA100Cross', 'SMA200Cross',
#        'UpDown10', 'UpDown15', 'UpDown50'],
#       dtype='object')

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 1.5 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.3 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 68.9 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 91.6 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 89.7 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 92.9 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.6 MB/s eta 0:00:00
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorflow-io-gcs-filesystem, tensorboard-data-server, google-pasta, tensorboard, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 google-pasta-0.2.0 libclang-18.1.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 werkzeug-3.1.3 wheel-0.45.1

# %%
# One-hot encode the Ticker column
ticker_dummies = pd.get_dummies(df_combined['Ticker'], prefix='Ticker')

# Create new numerical ticker representation
df_combined = pd.concat([df_combined, ticker_dummies], axis=1)

# Create list of all ticker dummy columns
ticker_cols = [col for col in df_combined.columns if col.startswith('Ticker_')]

# Update feature columns to use dummy variables instead of original Ticker
feature_cols = [
    'Surprise', 'Volume', 'R','SMA5', 'SMA15',
    'SMA20', 'SMA50', 'SMA100', 'SMA200', 'SMA5Cross', 'SMA15Cross',
    'SMA20Cross', 'SMA50Cross', 'SMA100Cross', 'SMA200Cross', 'UpDown10',
    'UpDown15', 'UpDown50'
] + ticker_cols  # Add the one-hot encoded ticker columns

# %%
feature_cols
# Out:
# ['Surprise',
#  'Volume',
#  'R',
#  'SMA5',
#  'SMA15',
#  'SMA20',
#  'SMA50',
#  'SMA100',
#  'SMA200',
#  'SMA5Cross',
#  'SMA15Cross',
#  'SMA20Cross',
#  'SMA50Cross',
#  'SMA100Cross',
#  'SMA200Cross',
#  'UpDown10',
#  'UpDown15',
#  'UpDown50',
#  'Ticker_ACNFCOMF Index',
#  'Ticker_ADP CHNG Index',
#  'Ticker_AHE MOM% Index',
#  'Ticker_AHE YOY% Index',
#  'Ticker_AMSPPACE Index',
#  'Ticker_AWH TOTL Index',
#  'Ticker_BBRSCPYY Index',
#  'Ticker_BPGCGI Index',
#  'Ticker_CFNAI Index',
#  'Ticker_CGNOXAI% Index',
#  'Ticker_CGSHXAI% Index',
#  'Ticker_CHPMINDX Index',
#  'Ticker_CICRTOT Index',
#  'Ticker_CNSTTMOM Index',
#  'Ticker_COMFBTWR Index',
#  'Ticker_COMFCOMF Index',
#  'Ticker_CONCCONF Index',
#  'Ticker_CONCEXP Index',
#  'Ticker_CONCPSIT Index',
#  'Ticker_CONSCURR Index',
#  'Ticker_CONSEXP Index',
#  'Ticker_CONSP5MD Index',
#  'Ticker_CONSPXMD Index',
#  'Ticker_CONSSENT Index',
#  'Ticker_COSTNFR% Index',
#  'Ticker_CPI CHNG Index',
#  'Ticker_CPI XYOY Index',
#  'Ticker_CPI YOY Index',
#  'Ticker_CPTICHNG Index',
#  'Ticker_CPUPAXFE Index',
#  'Ticker_CPUPXCHG Index',
#  'Ticker_CPURNSA Index',
#  'Ticker_DFEDGBA Index',
#  'Ticker_DGNOCHNG Index',
#  'Ticker_DGNOXTCH Index',
#  'Ticker_DLQTDLQT Index',
#  'Ticker_DOTDLTMD Index',
#  'Ticker_DOTDY0MD Index',
#  'Ticker_DOTDY1MD Index',
#  'Ticker_DOTDY2MD Index',
#  'Ticker_DSERGBCC Index',
#  'Ticker_ECI SA% Index',
#  'Ticker_ECONGECC Index',
#  'Ticker_ECONUSIB Index',
#  'Ticker_EHSLMOM Index',
#  'Ticker_EHSLSL Index',
#  'Ticker_EMPRGBCI Index',
#  'Ticker_ETSLMOM Index',
#  'Ticker_ETSLTOTL Index',
#  'Ticker_EXP1CMOM Index',
#  'Ticker_EXP1CYOY Index',
#  'Ticker_FDDSSD Index',
#  'Ticker_FDEBTY Index',
#  'Ticker_FDIDFDMO Index',
#  'Ticker_FDIDSGMO Index',
#  'Ticker_FDIDSGUM Index',
#  'Ticker_FDIUFDYO Index',
#  'Ticker_FDIUSGUY Index',
#  'Ticker_FDIUSGYO Index',
#  'Ticker_FDTR Index',
#  'Ticker_FDTRFTRL Index',
#  'Ticker_FORLTOTL Index',
#  'Ticker_FRNTTNET Index',
#  'Ticker_FRNTTOTL Index',
#  'Ticker_GDP CQOQ Index',
#  'Ticker_GDP DCHG Index',
#  'Ticker_GDP PIQQ Index',
#  'Ticker_GDPCPCEC Index',
#  'Ticker_GDPCTOT% Index',
#  'Ticker_HOMEAFFR Index',
#  'Ticker_HPI PURQ Index',
#  'Ticker_HPI QOQ% Index',
#  'Ticker_HPIMMOM% Index',
#  'Ticker_HVRAHOME Index',
#  'Ticker_ICSHNATL Index',
#  'Ticker_IMP1CHNG Index',
#  'Ticker_IMP1XPM% Index',
#  'Ticker_IMP1YOY% Index',
#  'Ticker_INJCJC Index',
#  'Ticker_INJCSP Index',
#  'Ticker_IP CHNG Index',
#  'Ticker_IPMGCHNG Index',
#  'Ticker_IRRBIOER Index',
#  'Ticker_JOLTTOTL Index',
#  'Ticker_KCLSSACI Index',
#  'Ticker_KCSSMCOM Index',
#  'Ticker_LEI CHNG Index',
#  'Ticker_LHWANWPA Index',
#  'Ticker_LMCILMCC Index',
#  'Ticker_MAPMINDX Index',
#  'Ticker_MBAVCHNG Index',
#  'Ticker_MBRSWTW Index',
#  'Ticker_MBRXYOY Index',
#  'Ticker_MBRXYOYW Index',
#  'Ticker_MPMIUSCA Index',
#  'Ticker_MPMIUSMA Index',
#  'Ticker_MPMIUSSA Index',
#  'Ticker_MTIBCHNG Index',
#  'Ticker_MWINCHNG Index',
#  'Ticker_MWSLCHNG Index',
#  'Ticker_NABEEMPL Index',
#  'Ticker_NAPMEMPL Index',
#  'Ticker_NAPMNEMP Index',
#  'Ticker_NAPMNEWO Index',
#  'Ticker_NAPMNMAN Index',
#  'Ticker_NAPMNMI Index',
#  'Ticker_NAPMNNO Index',
#  'Ticker_NAPMNPRC Index',
#  'Ticker_NAPMPMI Index',
#  'Ticker_NAPMPRIC Index',
#  'Ticker_NFP CPYC Index',
#  'Ticker_NFP PCH Index',
#  'Ticker_NFP TCH Index',
#  'Ticker_NHCHATCH Index',
#  'Ticker_NHCHSTCH Index',
#  'Ticker_NHSLCHNG Index',
#  'Ticker_NHSLTOT Index',
#  'Ticker_NHSPATOT Index',
#  'Ticker_NHSPSTOT Index',
#  'Ticker_NYBLCNBA Index',
#  'Ticker_NYCNM1IR Index',
#  'Ticker_NYPMCURR Index',
#  'Ticker_OUTFGAF Index',
#  'Ticker_PCE CHNC Index',
#  'Ticker_PCE CMOM Index',
#  'Ticker_PCE CRCH Index',
#  'Ticker_PCE CYOY Index',
#  'Ticker_PCE DEFM Index',
#  'Ticker_PCE DEFY Index',
#  'Ticker_PHUCCHNG Index',
#  'Ticker_PHUCTOT Index',
#  'Ticker_PITLCHNG Index',
#  'Ticker_PNMARADI Index',
#  'Ticker_PPI CHNG Index',
#  'Ticker_PPI XYOY Index',
#  'Ticker_PPI YOY Index',
#  'Ticker_PRODNFR% Index',
#  'Ticker_PRUSTOT Index',
#  'Ticker_PXFECHNG Index',
#  'Ticker_RCHSINDX Index',
#  'Ticker_RCSSCLBC Index',
#  'Ticker_REALRAWE Index',
#  'Ticker_REALYRAE Index',
#  'Ticker_REALYRAW Index',
#  'Ticker_REDSMMOM Index',
#  'Ticker_RSRSTMOM Index',
#  'Ticker_RSTAMOM Index',
#  'Ticker_RSTAXAG% Index',
#  'Ticker_RSTAXAGM Index',
#  'Ticker_RSTAXMOM Index',
#  'Ticker_RTSDCHNG Index',
#  'Ticker_RTSDXCHG Index',
#  'Ticker_SAARDTOT Index',
#  'Ticker_SAARTOTL Index',
#  'Ticker_SBOITOTL Index',
#  'Ticker_SPCS20 Index',
#  'Ticker_SPCS20SM Index',
#  'Ticker_SPCS20Y% Index',
#  'Ticker_SPCSUSA Index',
#  'Ticker_SPCSUSAY Index',
#  'Ticker_SPCSUSQS Index',
#  'Ticker_TMNOCHNG Index',
#  'Ticker_TMNOXTM% Index',
#  'Ticker_TREFAMSP Index',
#  'Ticker_TREFPACE Index',
#  'Ticker_USCABAL Index',
#  'Ticker_USEMNCHG Index',
#  'Ticker_USHBMIDX Index',
#  'Ticker_USHETOT% Index',
#  'Ticker_USHEYOY Index',
#  'Ticker_USMMMNCH Index',
#  'Ticker_USPHTMOM Index',
#  'Ticker_USPHTYOY Index',
#  'Ticker_USTBTOT Index',
#  'Ticker_USTGTTCB Index',
#  'Ticker_USUDMAER Index',
#  'Ticker_USURTOT Index',
#  'Ticker_USWHMANS Index',
#  'Ticker_USWHTOT Index',
#  'Ticker_VNCCCMOM Index',
#  'Ticker_VNCCTOT Index']

# %%
""" Took too long to run and computer was crashing:

# Based on methodologies from:
# 1. Takeuchi, Lee, & Giles (2013) - Deep Learning for Predicting Asset Returns
# 2. Fischer & Krauss (2017) - LSTM with Daily Data for S&P 500 Prediction
# 3. Dixon, Klabjan, & Bang (2017) - Classification-based Financial Market Prediction

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

total_cost = 2 * transaction_cost

def create_model(input_dim):
    #Create neural network architecture
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_dim,)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(3, activation='softmax')  # 0: Neutral, 1: Long, 2: Short
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def train_evaluate_model(train_data, val_data, horizon):
    #Train and evaluate model for specific horizon
    # Prepare data
    X_train = train_data[feature_cols]
    y_train = train_data[f'Profit{horizon}']
    X_val = val_data[feature_cols]

    # Preprocessing
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Class weights for imbalance
    class_counts = np.bincount(y_train)
    class_weights = {i: 1./count for i, count in enumerate(class_counts)}

    # Build and train model
    model = create_model(X_train.shape[1])
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    model.fit(X_train_scaled, y_train,
             epochs=100,
             batch_size=64,
             class_weight=class_weights,
             validation_split=0.2,
             callbacks=[early_stop],
             verbose=0)

    # Validate
    val_preds = model.predict(X_val_scaled).argmax(axis=1)
    val_returns = calculate_returns(val_data, val_preds, horizon)

    return model, val_returns

def calculate_returns(data, preds, horizon):
    #Calculate compounded returns for predictions
    returns = data[f'Return{horizon}']
    signed_returns = np.where(preds == 1, returns - total_cost,
                            np.where(preds == 2, -returns - total_cost, 0))
    return (1 + signed_returns).prod() - 1

# Modified main backtest loop
results = []
initial_train_size = int(0.3 * len(df_combined))
current_train_end = initial_train_size

while current_train_end < len(df_combined):
    # Define periods
    current_end_date = df_combined['DateTime'].iloc[current_train_end - 1]
    val_start_date = current_end_date + pd.Timedelta(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)
    test_start_date = val_end_date + pd.Timedelta(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    # Get indices
    val_start = df_combined[df_combined['DateTime'] >= val_start_date].index[0]
    val_end = df_combined[df_combined['DateTime'] <= val_end_date].index[-1] + 1
    test_start = df_combined[df_combined['DateTime'] >= test_start_date].index[0]
    test_end = df_combined[df_combined['DateTime'] <= test_end_date].index[-1] + 1

    # Split data
    train_data = df_combined.iloc[:current_train_end]
    val_data = df_combined.iloc[val_start:val_end]
    test_data = df_combined.iloc[test_start:test_end]

    # Train and validate models
    horizon_performance = {}
    models = {}
    for horizon in ['', '_half', '_double']:
        model, val_return = train_evaluate_model(train_data, val_data, horizon)
        horizon_performance[horizon] = val_return
        models[horizon] = model

    # Select best performing horizon
    best_horizon = max(horizon_performance, key=horizon_performance.get)
    best_model = models[best_horizon]

    # Test selected model
    X_test = test_data[feature_cols]
    X_test_scaled = StandardScaler().fit_transform(X_test)
    test_preds = best_model.predict(X_test_scaled).argmax(axis=1)
    test_return = calculate_returns(test_data, test_preds, best_horizon)

    # Store results
    results.append({
        'train_period': f"{train_data['DateTime'].iloc[0].date()} to {train_data['DateTime'].iloc[-1].date()}",
        'test_period': f"{test_data['DateTime'].iloc[0].date()} to {test_data['DateTime'].iloc[-1].date()}",
        'selected_horizon': best_horizon.replace('_', ' ').strip() or 'standard',
        'compounded_return': test_return * 100
    })

    # Move window
    current_train_end = val_end

# Results analysis
if results:
    results_df = pd.DataFrame(results)
    cumulative_return = (1 + results_df['compounded_return']/100).prod() - 1

    print("\nStrategy Performance:")
    print(f"Cumulative Return: {cumulative_return*100:.2f}%")
    print("\nHorizon Selection Frequency:")
    print(results_df['selected_horizon'].value_counts())
else:
    print("No valid test periods")
"""
# Out:
# ' Took too long to run and computer was crashing:\n\n# Based on methodologies from:\n# 1. Takeuchi, Lee, & Giles (2013) - Deep Learning for Predicting Asset Returns\n# 2. Fischer & Krauss (2017) - LSTM with Daily Data for S&P 500 Prediction\n# 3. Dixon, Klabjan, & Bang (2017) - Classification-based Financial Market Prediction\n\nimport tensorflow as tf\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Dense, Dropout, BatchNormalization\nfrom tensorflow.keras.optimizers import Adam\nfrom sklearn.preprocessing import StandardScaler\n\ntotal_cost = 2 * transaction_cost\n\ndef create_model(input_dim):\n    #Create neural network architecture\n    model = Sequential([\n        Dense(128, activation=\'relu\', input_shape=(input_dim,)),\n        BatchNormalization(),\n        Dropout(0.3),\n        Dense(64, activation=\'relu\'),\n        Dropout(0.2),\n        Dense(3, activation=\'softmax\')  # 0: Neutral, 1: Long, 2: Short\n    ])\n    model.compile(optimizer=Adam(learning_rate=0.001),\n                  loss=\'sparse_categorical_crossentropy\',\n                  metrics=[\'accuracy\'])\n    return model\n\ndef train_evaluate_model(train_data, val_data, horizon):\n    #Train and evaluate model for specific horizon\n    # Prepare data\n    X_train = train_data[feature_cols]\n    y_train = train_data[f\'Profit{horizon}\']\n    X_val = val_data[feature_cols]\n\n    # Preprocessing\n    scaler = StandardScaler()\n    X_train_scaled = scaler.fit_transform(X_train)\n    X_val_scaled = scaler.transform(X_val)\n\n    # Class weights for imbalance\n    class_counts = np.bincount(y_train)\n    class_weights = {i: 1./count for i, count in enumerate(class_counts)}\n\n    # Build and train model\n    model = create_model(X_train.shape[1])\n    early_stop = tf.keras.callbacks.EarlyStopping(monitor=\'val_loss\', patience=5)\n\n    model.fit(X_train_scaled, y_train,\n             epochs=100,\n             batch_size=64,\n             class_weight=class_weights,\n             validation_split=0.2,\n             callbacks=[early_stop],\n             verbose=0)\n\n    # Validate\n    val_preds = model.predict(X_val_scaled).argmax(axis=1)\n    val_returns = calculate_returns(val_data, val_preds, horizon)\n\n    return model, val_returns\n\ndef calculate_returns(data, preds, horizon):\n    #Calculate compounded returns for predictions\n    returns = data[f\'Return{horizon}\']\n    signed_returns = np.where(preds == 1, returns - total_cost,\n                            np.where(preds == 2, -returns - total_cost, 0))\n    return (1 + signed_returns).prod() - 1\n\n# Modified main backtest loop\nresults = []\ninitial_train_size = int(0.3 * len(df_combined))\ncurrent_train_end = initial_train_size\n\nwhile current_train_end < len(df_combined):\n    # Define periods\n    current_end_date = df_combined[\'DateTime\'].iloc[current_train_end - 1]\n    val_start_date = current_end_date + pd.Timedelta(days=1)\n    val_end_date = val_start_date + pd.DateOffset(years=1)\n    test_start_date = val_end_date + pd.Timedelta(days=1)\n    test_end_date = test_start_date + pd.DateOffset(years=1)\n\n    # Get indices\n    val_start = df_combined[df_combined[\'DateTime\'] >= val_start_date].index[0]\n    val_end = df_combined[df_combined[\'DateTime\'] <= val_end_date].index[-1] + 1\n    test_start = df_combined[df_combined[\'DateTime\'] >= test_start_date].index[0]\n    test_end = df_combined[df_combined[\'DateTime\'] <= test_end_date].index[-1] + 1\n\n    # Split data\n    train_data = df_combined.iloc[:current_train_end]\n    val_data = df_combined.iloc[val_start:val_end]\n    test_data = df_combined.iloc[test_start:test_end]\n\n    # Train and validate models\n    horizon_performance = {}\n    models = {}\n    for horizon in [\'\', \'_half\', \'_double\']:\n        model, val_return = train_evaluate_model(train_data, val_data, horizon)\n        horizon_performance[horizon] = val_return\n        models[horizon] = model\n\n    # Select b ...

# %%
df_combined[feature_cols]
# Out:
#          Surprise  Volume   R  SMA5  SMA15  SMA20  SMA50  SMA100  SMA200  \
# 0             NaN     0.0 NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 1             NaN     0.0 NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 2             NaN     0.0 NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 3             NaN     0.0 NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 4             NaN     0.0 NaN   0.0    NaN    NaN    NaN     NaN     NaN
# ...           ...     ...  ..   ...    ...    ...    ...     ...     ...
# 9695680       NaN     NaN NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 9695681       NaN     NaN NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 9695682       NaN     NaN NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 9695683       NaN     NaN NaN   NaN    NaN    NaN    NaN     NaN     NaN
# 9695684       NaN     NaN NaN   NaN    NaN    NaN    NaN     NaN     NaN
#
#          SMA5Cross  ...  Ticker_USPHTMOM Index  Ticker_USPHTYOY Index  \
# 0                0  ...                  False                  False
# 1                0  ...                  False                  False
# 2                0  ...                  False                  False
# 3                0  ...                  False                  False
# 4                0  ...                  False                  False
# ...            ...  ...                    ...                    ...
# 9695680          0  ...                  False                  False
# 9695681          0  ...                  False                  False
# 9695682          0  ...                  False                  False
# 9695683          0  ...                  False                  False
# 9695684          0  ...                  False                  False
#
#          Ticker_USTBTOT Index  Ticker_USTGTTCB Index  Ticker_USUDMAER Index  \
# 0                       False                  False                  False
# 1                       False                  False                  False
# 2                       False                  False                  False
# 3                       False                  False                  False
# 4                       False                  False                  False
# ...                       ...                    ...                    ...
# 9695680                 False                  False                  False
# 9695681                 False                  False                  False
# 9695682                 False                  False                  False
# 9695683                 False                  False                  False
# 9695684                 False                  False                  False
#
#          Ticker_USURTOT Index  Ticker_USWHMANS Index  Ticker_USWHTOT Index  \
# 0                       False                  False                 False
# 1                       False                  False                 False
# 2                       False                  False                 False
# 3                       False                  False                 False
# 4                       False                  False                 False
# ...                       ...                    ...                   ...
# 9695680                 False                  False                 False
# 9695681                 False                  False                 False
# 9695682                 False                  False                 False
# 9695683                 False                  False                 False
# 9695684                 False                  False                 False
#
#          Ticker_VNCCCMOM Index  Ticker_VNCCTOT Index
# 0                        False                 False
# 1                        False                 False
# 2                        False                 False
# 3                        False                 False
# 4                        False                 False
# ...                        ...                   ...
# 9695680                  False                 False
# 9695681                  False                 False
# 9695682                  False                 False
# 9695683                  False                 False
# 9695684                  False                  True
#
# [9695685 rows x 199 columns]

# %%
# Filter only rows where Profit label is available
df_ml = df_combined[df_combined['Profit'].notna()].copy()
df_ml = df_ml.reset_index()

# %%
df_ml[feature_cols].isna().sum()
# Out:
# Surprise                 3411
# Volume                      0
# R                        3411
# SMA5                        0
# SMA15                       0
#                          ...
# Ticker_USURTOT Index        0
# Ticker_USWHMANS Index       0
# Ticker_USWHTOT Index        0
# Ticker_VNCCCMOM Index       0
# Ticker_VNCCTOT Index        0
# Length: 199, dtype: int64

# %%
"""

# Based on methodologies from:
# 1. Takeuchi, Lee, & Giles (2013) - Deep Learning for Predicting Asset Returns
# 2. Fischer & Krauss (2017) - LSTM with Daily Data for S&P 500 Prediction
# 3. Dixon, Klabjan, & Bang (2017) - Classification-based Financial Market Prediction

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# Define total transaction cost
total_cost = 2 * transaction_cost


def create_model(input_dim):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_dim,)),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax')  # 0: Neutral, 1: Long, 2: Short
    ])
    model.compile(optimizer=Adam(learning_rate=0.01),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def train_evaluate_model(train_data, val_data, horizon):
    #Optimized training procedure with faster parameters
    X_train = train_data[feature_cols]
    y_train = train_data[f'Profit{horizon}']
    X_val = val_data[feature_cols]

    # Preprocessing
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Build and train model
    model = create_model(X_train.shape[1])
    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True
    )

    model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=256,
        validation_split=0.2,
        callbacks=[early_stop],
        verbose=0
    )

    print("Model is trained")

    # Validate
    val_preds = model.predict(X_val, batch_size=1024).argmax(axis=1)
    val_returns = calculate_returns(val_data, val_preds, horizon)

    return model, val_returns

def calculate_returns(data, preds, horizon):
    #Calculate compounded returns for predictions
    returns = data[f'Return{horizon}']
    signed_returns = np.where(preds == 1, returns - total_cost,
                            np.where(preds == 2, -returns - total_cost, 0))
    return (1 + signed_returns).prod() - 1

# --- Main Backtest Loop (updated to use df_ml) ---
results = []
initial_train_size = int(0.3 * len(df_ml))
current_train_end = initial_train_size

while current_train_end < len(df_ml):
    current_end_date = df_ml['DateTime'].iloc[current_train_end - 1]
    val_start_date = current_end_date + pd.Timedelta(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)
    test_start_date = val_end_date + pd.Timedelta(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    try:
        val_start = df_ml[df_ml['DateTime'] >= val_start_date].index[0]
        val_end = df_ml[df_ml['DateTime'] <= val_end_date].index[-1] + 1
        test_start = df_ml[df_ml['DateTime'] >= test_start_date].index[0]
        test_end = df_ml[df_ml['DateTime'] <= test_end_date].index[-1] + 1
    except IndexError:
        print("Not enough data left for validation/test split.")
        break

    train_data = df_ml.iloc[:current_train_end]
    val_data = df_ml.iloc[val_start:val_end]
    test_data = df_ml.iloc[test_start:test_end]

    if test_data.empty:
        print("Skipping period — no test data.")
        current_train_end = val_end
        continue

    # Train and validate models
    horizon_performance = {}
    models = {}
    for horizon in ['']:
        model, val_return = train_evaluate_model(train_data, val_data, horizon)
        horizon_performance[horizon] = val_return
        models[horizon] = model


    # Select best horizon
    best_horizon = max(horizon_performance, key=horizon_performance.get)
    print(best_horizon)
    best_model = models[best_horizon]

    # Test
    X_test = test_data[feature_cols]
    X_test_scaled = StandardScaler().fit_transform(X_test)
    test_preds = best_model.predict(X_test, batch_size=1024).argmax(axis=1)
    test_return = calculate_returns(test_data, test_preds, best_horizon)

    unique, counts = np.unique(test_preds, return_counts=True)
    print("Prediction distribution:", dict(zip(unique, counts)))

    results.append({
        'train_period': f"{train_data['DateTime'].iloc[0].date()} to {train_data['DateTime'].iloc[-1].date()}",
        'test_period': f"{test_data['DateTime'].iloc[0].date()} to {test_data['DateTime'].iloc[-1].date()}",
        'selected_horizon': best_horizon.replace('_', ' ').strip() or 'standard',
        'compounded_return': test_return * 100
    })

    print(results[-1])

    # Advance window
    current_train_end = val_end

# --- Results Summary ---
if results:
    results_df = pd.DataFrame(results)
    cumulative_return = (1 + results_df['compounded_return']/100).prod() - 1

    print("\nStrategy Performance:")
    print(f"Cumulative Return: {cumulative_return*100:.2f}%")
    print("\nHorizon Selection Frequency:")
    print(results_df['selected_horizon'].value_counts())
else:
    print("No valid test periods")

"""
# Out:
# '\n\n# Based on methodologies from:\n# 1. Takeuchi, Lee, & Giles (2013) - Deep Learning for Predicting Asset Returns\n# 2. Fischer & Krauss (2017) - LSTM with Daily Data for S&P 500 Prediction\n# 3. Dixon, Klabjan, & Bang (2017) - Classification-based Financial Market Prediction\n\nimport tensorflow as tf\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Dense\nfrom tensorflow.keras.optimizers import Adam\nfrom sklearn.preprocessing import StandardScaler\nimport numpy as np\nimport pandas as pd\n\n# Define total transaction cost\ntotal_cost = 2 * transaction_cost\n\n\ndef create_model(input_dim):\n    model = Sequential([\n        Dense(64, activation=\'relu\', input_shape=(input_dim,)),\n        Dense(32, activation=\'relu\'),\n        Dense(3, activation=\'softmax\')  # 0: Neutral, 1: Long, 2: Short\n    ])\n    model.compile(optimizer=Adam(learning_rate=0.01),\n                  loss=\'sparse_categorical_crossentropy\',\n                  metrics=[\'accuracy\'])\n    return model\n\ndef train_evaluate_model(train_data, val_data, horizon):\n    #Optimized training procedure with faster parameters\n    X_train = train_data[feature_cols]\n    y_train = train_data[f\'Profit{horizon}\']\n    X_val = val_data[feature_cols]\n\n    # Preprocessing\n    scaler = StandardScaler()\n    X_train_scaled = scaler.fit_transform(X_train)\n    X_val_scaled = scaler.transform(X_val)\n\n    # Build and train model\n    model = create_model(X_train.shape[1])\n    early_stop = tf.keras.callbacks.EarlyStopping(\n        monitor=\'val_loss\',\n        patience=3,\n        restore_best_weights=True\n    )\n\n    model.fit(\n        X_train, y_train,\n        epochs=50,\n        batch_size=256,\n        validation_split=0.2,\n        callbacks=[early_stop],\n        verbose=0\n    )\n\n    print("Model is trained")\n\n    # Validate\n    val_preds = model.predict(X_val, batch_size=1024).argmax(axis=1)\n    val_returns = calculate_returns(val_data, val_preds, horizon)\n\n    return model, val_returns\n\ndef calculate_returns(data, preds, horizon):\n    #Calculate compounded returns for predictions\n    returns = data[f\'Return{horizon}\']\n    signed_returns = np.where(preds == 1, returns - total_cost,\n                            np.where(preds == 2, -returns - total_cost, 0))\n    return (1 + signed_returns).prod() - 1\n\n# --- Main Backtest Loop (updated to use df_ml) ---\nresults = []\ninitial_train_size = int(0.3 * len(df_ml))\ncurrent_train_end = initial_train_size\n\nwhile current_train_end < len(df_ml):\n    current_end_date = df_ml[\'DateTime\'].iloc[current_train_end - 1]\n    val_start_date = current_end_date + pd.Timedelta(days=1)\n    val_end_date = val_start_date + pd.DateOffset(years=1)\n    test_start_date = val_end_date + pd.Timedelta(days=1)\n    test_end_date = test_start_date + pd.DateOffset(years=1)\n\n    try:\n        val_start = df_ml[df_ml[\'DateTime\'] >= val_start_date].index[0]\n        val_end = df_ml[df_ml[\'DateTime\'] <= val_end_date].index[-1] + 1\n        test_start = df_ml[df_ml[\'DateTime\'] >= test_start_date].index[0]\n        test_end = df_ml[df_ml[\'DateTime\'] <= test_end_date].index[-1] + 1\n    except IndexError:\n        print("Not enough data left for validation/test split.")\n        break\n\n    train_data = df_ml.iloc[:current_train_end]\n    val_data = df_ml.iloc[val_start:val_end]\n    test_data = df_ml.iloc[test_start:test_end]\n\n    if test_data.empty:\n        print("Skipping period — no test data.")\n        current_train_end = val_end\n        continue\n\n    # Train and validate models\n    horizon_performance = {}\n    models = {}\n    for horizon in [\'\']:\n        model, val_return = train_evaluate_model(train_data, val_data, horizon)\n        horizon_performance[horizon] = val_return\n        models[horizon] = model\n\n\n    # Select best horizon\n    best_horizon = max(horizon_performance, key=horizon_performance.get)\n    print(best_horizon)\n    best_m ...

# %%
"""
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# Define total transaction cost
total_cost = 2 * transaction_cost  # Ensure this is defined elsewhere

def create_model(input_dim):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_dim,)),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax')  # 0: Neutral, 1: Long, 2: Short
    ])
    model.compile(optimizer=Adam(learning_rate=0.01),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def calculate_returns(data, preds):
    #Calculate compounded returns for predictions (no horizon parameter)
    returns = data['Return']  # Assumes a single 'Return' column exists
    signed_returns = np.where(preds == 1, returns - total_cost,
                            np.where(preds == 2, -returns - total_cost, 0))
    return (1 + signed_returns).prod() - 1

# --- Simplified 50/50 Split ---
# Reset index if needed (as per your previous request)
df_ml = df_ml.reset_index(drop=True)

# Split data (50% train, 50% test)
train_data, test_data = train_test_split(df_ml, test_size=0.5, shuffle=False)

# Preprocessing
scaler = StandardScaler()
X_train = scaler.fit_transform(train_data[feature_cols])
X_test = scaler.transform(test_data[feature_cols])
y_train = train_data['Profit']  # Assumes a single 'Profit' target column

# Build and train model
model = create_model(X_train.shape[1])
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=256,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

# Evaluate
test_preds = model.predict(X_test, batch_size=1024).argmax(axis=1)
test_return = calculate_returns(test_data, test_preds)

# Prediction distribution
unique, counts = np.unique(test_preds, return_counts=True)
print("Prediction distribution:", dict(zip(unique, counts)))

# Results
print("\nTest Performance:")
print(f"Compounded Return: {test_return * 100:.2f}%")

"""
# Out:
# '\nimport tensorflow as tf\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Dense\nfrom tensorflow.keras.optimizers import Adam\nfrom sklearn.preprocessing import StandardScaler\nfrom sklearn.model_selection import train_test_split\nimport numpy as np\nimport pandas as pd\n\n# Define total transaction cost\ntotal_cost = 2 * transaction_cost  # Ensure this is defined elsewhere\n\ndef create_model(input_dim):\n    model = Sequential([\n        Dense(64, activation=\'relu\', input_shape=(input_dim,)),\n        Dense(32, activation=\'relu\'),\n        Dense(3, activation=\'softmax\')  # 0: Neutral, 1: Long, 2: Short\n    ])\n    model.compile(optimizer=Adam(learning_rate=0.01),\n                  loss=\'sparse_categorical_crossentropy\',\n                  metrics=[\'accuracy\'])\n    return model\n\ndef calculate_returns(data, preds):\n    #Calculate compounded returns for predictions (no horizon parameter)\n    returns = data[\'Return\']  # Assumes a single \'Return\' column exists\n    signed_returns = np.where(preds == 1, returns - total_cost,\n                            np.where(preds == 2, -returns - total_cost, 0))\n    return (1 + signed_returns).prod() - 1\n\n# --- Simplified 50/50 Split ---\n# Reset index if needed (as per your previous request)\ndf_ml = df_ml.reset_index(drop=True)\n\n# Split data (50% train, 50% test)\ntrain_data, test_data = train_test_split(df_ml, test_size=0.5, shuffle=False)\n\n# Preprocessing\nscaler = StandardScaler()\nX_train = scaler.fit_transform(train_data[feature_cols])\nX_test = scaler.transform(test_data[feature_cols])\ny_train = train_data[\'Profit\']  # Assumes a single \'Profit\' target column\n\n# Build and train model\nmodel = create_model(X_train.shape[1])\nearly_stop = tf.keras.callbacks.EarlyStopping(\n    monitor=\'val_loss\',\n    patience=3,\n    restore_best_weights=True\n)\n\nmodel.fit(\n    X_train, y_train,\n    epochs=50,\n    batch_size=256,\n    validation_split=0.2,\n    callbacks=[early_stop],\n    verbose=1\n)\n\n# Evaluate\ntest_preds = model.predict(X_test, batch_size=1024).argmax(axis=1)\ntest_return = calculate_returns(test_data, test_preds)\n\n# Prediction distribution\nunique, counts = np.unique(test_preds, return_counts=True)\nprint("Prediction distribution:", dict(zip(unique, counts)))\n\n# Results\nprint("\nTest Performance:")\nprint(f"Compounded Return: {test_return * 100:.2f}%")\n\n'

# %% [markdown]
# # **XGBoost Model**

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.26.2.post1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.11.4)
# Downloading xgboost-3.0.0-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 578.5 kB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2.post1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (291.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.7/291.7 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.26.2.post1 xgboost-3.0.0

# %% [markdown]
# **Non-rolling XGBoost (not our final model, just to ensure XGBoost model is first properly coded before adding additional complexity)**

# %%
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost

# --- Data Prep (drop only rows with NaN in 'surprise') ---
df_ml = df_ml.dropna(subset=['Surprise'])

# Split data (50% train, 50% test, no shuffling for time-series)
train_data, test_data = train_test_split(df_ml, test_size=0.1, shuffle=False)

# Feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(train_data[feature_cols])
X_test = scaler.transform(test_data[feature_cols])
y_train = train_data['Profit']  # Target: 0=Neutral, 1=Long, 2=Short

# --- XGBoost Model ---
model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)
model.fit(X_train, y_train)

# --- Predictions ---
test_preds = model.predict(X_test)

# --- Calculate Returns ---
def calculate_returns(data, preds):
    """Returns individual period returns for plotting"""
    returns = data['Return'].values
    signed_returns = np.where(
        preds == 1, returns - total_cost,  # Long
        np.where(preds == 2, -returns - total_cost, 0)  # Short
    )
    return signed_returns

test_returns = calculate_returns(test_data, test_preds)
cumulative_returns = np.cumprod(1 + test_returns) - 1  # Compound returns

# --- Plotting ---
plt.figure(figsize=(12, 6))
plt.plot(test_data['DateTime'], (cumulative_returns)*100, label='Model Cumulative Return')
plt.axhline(y=0, color='gray', linestyle='--', linewidth=1)
plt.title('Test Set Cumulative Returns')
plt.xlabel('Date')
plt.ylabel('Cumulative Return (%)')
plt.legend()
plt.grid(True)
plt.show()

# --- Metrics ---
final_return = cumulative_returns[-1]
print(f"Final Cumulative Return: {final_return*100:.2f}%")
print("Prediction Distribution:", dict(zip(*np.unique(test_preds, return_counts=True))))
# Out:
# Final Cumulative Return: 37.13%
# Prediction Distribution: {np.int32(1): np.int64(1214), np.int32(2): np.int64(752)}

# %%
df_combined['Profit'].value_counts()
# Out:
# Profit
# 1.0    11292
# 2.0    10834
# 0.0      942
# Name: count, dtype: int64

# %% [markdown]
# # **Note: Still have to add bid-ask spread considerations (or list as limitation) and account for surprises occuring at same time/ not entering with entire position for overlapping positions**

# %% [markdown]
# **Rolling XGBoost model**

# %%
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import os, random

# So that results stay constant
random.seed(42)
np.random.seed(42)

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Main Loop ---
results = []
all_test_returns = []
all_dates = []
all_test_preds = []  # NEW: Track all predictions
test_accuracies = []  # NEW: Track accuracies

while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    # Check if remaining data is sufficient
    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data using datetime masks
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data = df_ml[val_mask]
    test_data = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        try:
            # Feature scaling
            scaler = StandardScaler()
            X_train = scaler.fit_transform(train_data[feature_cols])
            X_val = scaler.transform(val_data[feature_cols])
            y_train = train_data[f'Profit{horizon}']
            y_val = val_data[f'Profit{horizon}']

            # Train model
            xgb_params = {
              'num_class':         3,
              'n_estimators':     60,
              'max_depth':         7,
            }
            model = xgb.XGBClassifier(**xgb_params)

            model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)

            # Validate
            val_preds = model.predict(X_val)
            val_returns = np.where(
                val_preds == 1, val_data[f'Return{horizon}'] - total_cost,
                np.where(val_preds == 2, -val_data[f'Return{horizon}'] - total_cost, 0))
            total_val_return = (1 + val_returns).prod() - 1

            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon = horizon
                best_model = model

        except KeyError as e:
            print(f"Missing column {e} - skipping horizon {horizon}")
            continue

    # --- Test Best Model ---
    if best_model:
        X_test = scaler.transform(test_data[feature_cols])
        test_preds = best_model.predict(X_test)

        # NEW: Track predictions and accuracy
        all_test_preds.extend(test_preds)
        y_test = test_data[f'Profit{best_horizon}'].values
        test_accuracies.append(np.mean(test_preds == y_test))  # Accuracy calculation

        test_returns = np.where(
            test_preds == 1, test_data[f'Return{best_horizon}'] - total_cost,
            np.where(test_preds == 2, -test_data[f'Return{best_horizon}'] - total_cost, 0))

        all_test_returns.extend(test_returns)
        all_dates.extend(test_data['DateTime'].tolist())

    # Advance training window by 1 year
    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    # Plotting remains the same
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (DateTime-Based Rolling Windows)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()
    print(f"Final return: {cumulative_returns[-1]*100:.2f}%")

    # NEW: Prediction distribution and accuracy
    print("\nTest Predictions Distribution:")
    print(pd.Series(all_test_preds).value_counts().sort_index())

    if test_accuracies:
        print(f"\nAverage Test Accuracy: {np.mean(test_accuracies):.2%}")
    else:
        print("\nNo accuracy metrics calculated")
else:
    print("No valid test periods found")
# Out:
# Final return: 345.14%
#
# Test Predictions Distribution:
# 0     108
# 1    7831
# 2    6729
# Name: count, dtype: int64
#
# Average Test Accuracy: 49.08%

# %%
# Now we get the first and last observation in the test set so we can compute compounded return (comes out to almost exactly 17 years)

if 'all_dates' in globals() and len(all_dates) > 0:  # Check if all_dates exists
    first_test_date = pd.to_datetime(min(all_dates)).strftime('%Y-%m-%d %H:%M')
    last_test_date = pd.to_datetime(max(all_dates)).strftime('%Y-%m-%d %H:%M')
    print(f"Test Period: {first_test_date} to {last_test_date}")
else:
    print("No test dates found. Run backtest first.")
# Out:
# Test Period: 2007-01-30 09:00 to 2024-01-29 09:30

# %%
# Count the number of duplicate DateTime instances
duplicate_count = df_ml['DateTime'].duplicated(keep=False).sum()

# Breakdown explanation
total_rows = len(df_ml)
unique_datetimes = df_ml['DateTime'].nunique()
duplicate_instances = total_rows - unique_datetimes

print(f"Total duplicate DateTime instances: {duplicate_count}")
print(f"Breakdown: {duplicate_instances} redundant timestamps (i.e., {unique_datetimes} unique dates vs. {total_rows} total rows)")
# Out:
# Total duplicate DateTime instances: 13810
# Breakdown: 9619 redundant timestamps (i.e., 10038 unique dates vs. 19657 total rows)

# %% [markdown]
# **Rolling Random Forest model**

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import os, random

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Main Loop ---
results = []
all_test_returns = []
all_dates = []
all_test_preds = []
test_accuracies = []

while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    # Check if remaining data is sufficient
    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data = df_ml[val_mask]
    test_data = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        try:
            # Feature scaling
            scaler = StandardScaler()
            X_train = scaler.fit_transform(train_data[feature_cols])
            X_val = scaler.transform(val_data[feature_cols])
            y_train = train_data[f'Profit{horizon}']
            y_val = val_data[f'Profit{horizon}']

            # Train Random Forest
            model = RandomForestClassifier(
                n_estimators=100,
                criterion='gini',
                min_samples_leaf=4,
                random_state=42  # For reproducibility
            )
            model.fit(X_train, y_train)

            # Validate
            val_preds = model.predict(X_val)
            val_returns = np.where(
                val_preds == 1, val_data[f'Return{horizon}'] - total_cost,
                np.where(val_preds == 2, -val_data[f'Return{horizon}'] - total_cost, 0))
            total_val_return = (1 + val_returns).prod() - 1

            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon = horizon
                best_model = model

        except KeyError as e:
            print(f"Missing column {e} - skipping horizon {horizon}")
            continue

    # --- Test Best Model ---
    if best_model:
        X_test = scaler.transform(test_data[feature_cols])
        test_preds = best_model.predict(X_test)

        # Track predictions and accuracy
        all_test_preds.extend(test_preds)
        y_test = test_data[f'Profit{best_horizon}'].values
        test_accuracies.append(np.mean(test_preds == y_test))

        test_returns = np.where(
            test_preds == 1, test_data[f'Return{best_horizon}'] - total_cost,
            np.where(test_preds == 2, -test_data[f'Return{best_horizon}'] - total_cost, 0))

        all_test_returns.extend(test_returns)
        all_dates.extend(test_data['DateTime'].tolist())

    # Advance training window
    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (Random Forest)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()
    print(f"Final return: {cumulative_returns[-1]*100:.2f}%")

    print("\nTest Predictions Distribution:")
    print(pd.Series(all_test_preds).value_counts().sort_index())

    if test_accuracies:
        print(f"\nAverage Test Accuracy: {np.mean(test_accuracies):.2%}")
    else:
        print("\nNo accuracy metrics calculated")
else:
    print("No valid test periods found")
# Out:
# Final return: 239.51%
#
# Test Predictions Distribution:
# 1.0    8376
# 2.0    6292
# Name: count, dtype: int64
#
# Average Test Accuracy: 49.66%

# %% [markdown]
# **Rolling Logistic Regression Model**

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import os, random

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Main Loop ---
results = []
all_test_returns = []
all_dates = []
all_test_preds = []
test_accuracies = []

while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    # Check if remaining data is sufficient
    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data = df_ml[val_mask]
    test_data = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        try:
            # Feature scaling (critical for logistic regression)
            scaler = StandardScaler()
            X_train = scaler.fit_transform(train_data[feature_cols])
            X_val = scaler.transform(val_data[feature_cols])
            y_train = train_data[f'Profit{horizon}']
            y_val = val_data[f'Profit{horizon}']

            # Train Logistic Regression
            model = LogisticRegression(
                multi_class='multinomial',
                solver='saga',          # Stochastic Average Gradient Descent
                max_iter=100,
                random_state=42
            )
            model.fit(X_train, y_train)

            # Validate
            val_preds = model.predict(X_val)
            val_returns = np.where(
                val_preds == 1, val_data[f'Return{horizon}'] - total_cost,
                np.where(val_preds == 2, -val_data[f'Return{horizon}'] - total_cost, 0))
            total_val_return = (1 + val_returns).prod() - 1

            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon = horizon
                best_model = model

        except KeyError as e:
            print(f"Missing column {e} - skipping horizon {horizon}")
            continue

    # --- Test Best Model ---
    if best_model:
        X_test = scaler.transform(test_data[feature_cols])
        test_preds = best_model.predict(X_test)

        # Track predictions and accuracy
        all_test_preds.extend(test_preds)
        y_test = test_data[f'Profit{best_horizon}'].values
        test_accuracies.append(np.mean(test_preds == y_test))

        test_returns = np.where(
            test_preds == 1, test_data[f'Return{best_horizon}'] - total_cost,
            np.where(test_preds == 2, -test_data[f'Return{best_horizon}'] - total_cost, 0))

        all_test_returns.extend(test_returns)
        all_dates.extend(test_data['DateTime'].tolist())

    # Advance training window
    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (Multinomial Logistic Regression)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()
    print(f"Final return: {cumulative_returns[-1]*100:.2f}%")

    print("\nTest Predictions Distribution:")
    print(pd.Series(all_test_preds).value_counts().sort_index())

    if test_accuracies:
        print(f"\nAverage Test Accuracy: {np.mean(test_accuracies):.2%}")
    else:
        print("\nNo accuracy metrics calculated")
else:
    print("No valid test periods found")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Final return: -53.93%
#
# Test Predictions Distribution:
# 0.0     106
# 1.0    9200
# 2.0    5362
# Name: count, dtype: int64
#
# Average Test Accuracy: 48.42%

# %% [markdown]
# **Yet to do: Deal with same time surprises, figure out macro variables to include to improve XGBoost (can see it performs best during periods of high or low vol/ stress so maybe VIX), Kelly Criterion, other prediction metrics, check if all code is currently being done, number of total surprises to then get average OOS test sert return (disregard holding period) then compare to weighted average of non surprise related 10,20,40 mins holding period. Think about the relevant monetary variables to include based on Prof's feedback. Maybe add Shapley value stuff**

# %% [markdown]
# **Incorporating other prediction metrics and average return computation into rolling strategies**

# %% [markdown]
# **XGBoost**

# %%
import os
os.environ['OMP_NUM_THREADS']      = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS']      = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS']    = '1'
os.environ['PYTHONHASHSEED']         = '0'

import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score
)
import numpy as np
import pandas as pd
import random


# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
results = []
all_test_returns   = []
all_dates          = []
all_test_preds     = []  # track all predictions
all_test_truths    = []  # track all true labels
all_test_probas    = []  # track predicted probabilities
fold_mean_returns  = []
best_horizons_list = []

# --- Main Loop ---
while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date   = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date   = test_start_date + pd.DateOffset(years=1)

    # Check if remaining data is sufficient
    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data using datetime masks
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask   = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask  = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data   = df_ml[val_mask]
    test_data  = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        try:
            # Feature scaling
            scaler = StandardScaler()
            X_train = scaler.fit_transform(train_data[feature_cols])
            X_val   = scaler.transform(val_data[feature_cols])
            y_train = train_data[f'Profit{horizon}']
            y_val   = val_data[f'Profit{horizon}']

            # Train model
            model = xgb.XGBClassifier(
              num_class=3,
              n_estimators=60,
              max_depth=7,
              random_state=42,
              seed=42
            )
            model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)

            # Validate
            val_preds = model.predict(X_val)
            val_returns = np.where(
                val_preds == 1, val_data[f'Return{horizon}'] - total_cost,
                np.where(val_preds == 2, -val_data[f'Return{horizon}'] - total_cost, 0)
            )
            total_val_return = (1 + val_returns).prod() - 1

            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon    = horizon
                best_model      = model

        except KeyError as e:
            print(f"Missing column {e} - skipping horizon {horizon}")
            continue

    # --- Test Best Model ---
    if best_model:
        # Re-scale test features
        X_test   = scaler.transform(test_data[feature_cols])
        test_preds  = best_model.predict(X_test)
        test_probas = best_model.predict_proba(X_test)

        # Track predictions and truths
        all_test_preds.extend(test_preds)
        y_test = test_data[f'Profit{best_horizon}'].values
        all_test_truths.extend(y_test)
        all_test_probas.append(test_probas)

        # Compute returns
        test_returns = np.where(
            test_preds == 1,  test_data[f'Return{best_horizon}'] - total_cost,
            np.where(test_preds == 2, -test_data[f'Return{best_horizon}'] - total_cost, 0)
        )
        all_test_returns.extend(test_returns)
        all_dates.extend(test_data['DateTime'].tolist())

        # Fold-level metrics
        fold_mean_returns.append(test_returns.mean())
        best_horizons_list.append(best_horizon or 'standard')

    # Advance training window by 1 year
    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    # Continuous equity curve
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (DateTime-Based Rolling Windows)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")

    # Overall prediction metrics
    y_true = np.array(all_test_truths)
    y_pred = np.array(all_test_preds)
    y_proba = np.vstack(all_test_probas)

    overall_acc      = accuracy_score(y_true, y_pred)
    overall_precision= precision_score(y_true, y_pred, average='macro', zero_division=0)
    overall_recall   = recall_score(y_true, y_pred, average='macro', zero_division=0)
    overall_f1       = f1_score(y_true, y_pred, average='macro', zero_division=0)
    overall_roc_auc  = roc_auc_score(y_true, y_proba, multi_class='ovo', average='macro')

    print(f"\nOverall Test Accuracy : {overall_acc*100:.2f}%")
    print(f"Overall Precision     : {overall_precision*100:.2f}%")
    print(f"Overall Recall        : {overall_recall*100:.2f}%")
    print(f"Overall F1 Score      : {overall_f1*100:.2f}%")
    print(f"Overall ROC AUC       : {overall_roc_auc*100:.2f}%")

    # Average of per-fold mean test returns
    avg_test_return = np.mean(fold_mean_returns)
    print(f"\nAverage Fold Test Return : {avg_test_return*100:.5f}%")

    # Optimal horizon frequency
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# Final Cumulative Compounded Return: 236.26%
#
# Overall Test Accuracy : 48.74%
# Overall Precision     : 35.31%
# Overall Recall        : 34.06%
# Overall F1 Score      : 33.62%
# Overall ROC AUC       : 53.55%
#
# Average Fold Test Return : 0.00885%
#
# Optimal Horizon Counts:
# _half       8
# _double     5
# standard    4
# Name: count, dtype: int64

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score
)
import numpy as np
import pandas as pd
import os, random

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
results = []
all_test_returns   = []
all_dates          = []
all_test_preds     = []
all_test_truths    = []
all_test_probas    = []
fold_mean_returns  = []
best_horizons_list = []

# --- Main Loop ---
while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date   = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date   = test_start_date + pd.DateOffset(years=1)

    # Check if remaining data is sufficient
    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask   = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask  = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data   = df_ml[val_mask]
    test_data  = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        try:
            # Feature scaling
            scaler = StandardScaler()
            X_train = scaler.fit_transform(train_data[feature_cols])
            X_val   = scaler.transform(val_data[feature_cols])
            y_train = train_data[f'Profit{horizon}']
            y_val   = val_data[f'Profit{horizon}']

            # Train Random Forest
            model = RandomForestClassifier(
                n_estimators=100,
                criterion='gini',
                min_samples_leaf=4,
                random_state=42  # For reproducibility
            )
            model.fit(X_train, y_train)

            # Validate
            val_preds = model.predict(X_val)
            val_returns = np.where(
                val_preds == 1,  val_data[f'Return{horizon}'] - total_cost,
                np.where(val_preds == 2, -val_data[f'Return{horizon}'] - total_cost, 0)
            )
            total_val_return = (1 + val_returns).prod() - 1

            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon    = horizon
                best_model      = model

        except KeyError as e:
            print(f"Missing column {e} - skipping horizon {horizon}")
            continue

    # --- Test Best Model ---
    if best_model:
        X_test      = scaler.transform(test_data[feature_cols])
        test_preds  = best_model.predict(X_test)
        test_probas = best_model.predict_proba(X_test)

        # Track predictions and truths
        all_test_preds.extend(test_preds)
        y_test = test_data[f'Profit{best_horizon}'].values
        all_test_truths.extend(y_test)
        all_test_probas.append(test_probas)

        # Compute returns
        test_returns = np.where(
            test_preds == 1,  test_data[f'Return{best_horizon}'] - total_cost,
            np.where(test_preds == 2, -test_data[f'Return{best_horizon}'] - total_cost, 0)
        )
        all_test_returns.extend(test_returns)
        all_dates.extend(test_data['DateTime'].tolist())

        # Fold-level metrics
        fold_mean_returns.append(test_returns.mean())
        best_horizons_list.append(best_horizon or 'standard')

    # Advance training window
    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    # Continuous equity curve
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (Random Forest)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")

    # Overall prediction metrics
    y_true = np.array(all_test_truths)
    y_pred = np.array(all_test_preds)
    y_proba = np.vstack(all_test_probas)

    overall_acc       = accuracy_score(y_true, y_pred)
    overall_precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
    overall_recall    = recall_score(y_true, y_pred, average='macro', zero_division=0)
    overall_f1        = f1_score(y_true, y_pred, average='macro', zero_division=0)
    overall_roc_auc   = roc_auc_score(y_true, y_proba, multi_class='ovo', average='macro')

    print(f"\nOverall Test Accuracy : {overall_acc*100:.2f}%")
    print(f"Overall Precision     : {overall_precision*100:.2f}%")
    print(f"Overall Recall        : {overall_recall*100:.2f}%")
    print(f"Overall F1 Score      : {overall_f1*100:.2f}%")
    print(f"Overall ROC AUC       : {overall_roc_auc*100:.2f}%")

    # Average of per-fold mean test returns
    avg_test_return = np.mean(fold_mean_returns)
    print(f"\nAverage Fold Test Return : {avg_test_return*100:.5f}%")

    # Optimal horizon frequency
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# Final Cumulative Compounded Return: 52.50%
#
# Overall Test Accuracy : 48.98%
# Overall Precision     : 32.57%
# Overall Recall        : 33.72%
# Overall F1 Score      : 33.08%
# Overall ROC AUC       : 52.81%
#
# Average Fold Test Return : 0.00284%
#
# Optimal Horizon Counts:
# _double     8
# standard    7
# _half       2
# Name: count, dtype: int64

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score
)
import numpy as np
import pandas as pd
import os, random

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
all_test_returns   = []
all_dates          = []
all_test_preds     = []
all_test_truths    = []
all_test_probas    = []
fold_mean_returns  = []
best_horizons_list = []

# --- Main Loop ---
while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date   = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date   = test_start_date + pd.DateOffset(years=1)

    # Check if remaining data is sufficient
    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask   = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask  = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data   = df_ml[val_mask]
    test_data  = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        try:
            # Feature scaling (critical for logistic regression)
            scaler = StandardScaler()
            X_train = scaler.fit_transform(train_data[feature_cols])
            X_val   = scaler.transform(val_data[feature_cols])
            y_train = train_data[f'Profit{horizon}']
            y_val   = val_data[f'Profit{horizon}']

            # Train Logistic Regression
            model = LogisticRegression(
                multi_class='multinomial',
                solver='saga',
                max_iter=100,
                random_state=42
            )
            model.fit(X_train, y_train)

            # Validate
            val_preds = model.predict(X_val)
            val_returns = np.where(
                val_preds == 1,  val_data[f'Return{horizon}'] - total_cost,
                np.where(val_preds == 2, -val_data[f'Return{horizon}'] - total_cost, 0)
            )
            total_val_return = (1 + val_returns).prod() - 1

            if total_val_return > best_val_return:
                best_val_return = total_val_return
                best_horizon    = horizon
                best_model      = model

        except KeyError as e:
            print(f"Missing column {e} - skipping horizon {horizon}")
            continue

    # --- Test Best Model ---
    if best_model:
        X_test      = scaler.transform(test_data[feature_cols])
        test_preds  = best_model.predict(X_test)
        test_probas = best_model.predict_proba(X_test)

        # Track predictions and truths
        all_test_preds.extend(test_preds)
        y_test = test_data[f'Profit{best_horizon}'].values
        all_test_truths.extend(y_test)
        all_test_probas.append(test_probas)

        # Compute returns
        test_returns = np.where(
            test_preds == 1,  test_data[f'Return{best_horizon}'] - total_cost,
            np.where(test_preds == 2, -test_data[f'Return{best_horizon}'] - total_cost, 0)
        )
        all_test_returns.extend(test_returns)
        all_dates.extend(test_data['DateTime'].tolist())

        # Fold-level metrics
        fold_mean_returns.append(test_returns.mean())
        best_horizons_list.append(best_horizon or 'standard')

    # Advance training window
    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    # Continuous equity curve
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (Multinomial Logistic Regression)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")

    # Overall prediction metrics
    y_true = np.array(all_test_truths)
    y_pred = np.array(all_test_preds)
    y_proba = np.vstack(all_test_probas)

    overall_acc       = accuracy_score(y_true, y_pred)
    overall_precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
    overall_recall    = recall_score(y_true, y_pred, average='macro', zero_division=0)
    overall_f1        = f1_score(y_true, y_pred, average='macro', zero_division=0)
    overall_roc_auc   = roc_auc_score(y_true, y_proba, multi_class='ovo', average='macro')

    print(f"\nOverall Test Accuracy : {overall_acc*100:.2f}%")
    print(f"Overall Precision     : {overall_precision*100:.2f}%")
    print(f"Overall Recall        : {overall_recall*100:.2f}%")
    print(f"Overall F1 Score      : {overall_f1*100:.2f}%")
    print(f"Overall ROC AUC       : {overall_roc_auc*100:.2f}%")

    # Average of per-fold mean test returns
    avg_test_return = np.mean(fold_mean_returns)
    print(f"\nAverage Fold Test Return : {avg_test_return*100:.5f}%")

    # Optimal horizon frequency
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Final Cumulative Compounded Return: -53.93%
#
# Overall Test Accuracy : 48.40%
# Overall Precision     : 39.23%
# Overall Recall        : 34.67%
# Overall F1 Score      : 34.32%
# Overall ROC AUC       : 55.22%
#
# Average Fold Test Return : -0.00399%
#
# Optimal Horizon Counts:
# _half       8
# _double     5
# standard    4
# Name: count, dtype: int64

# %% [markdown]
# **Dealing with surprises at same time using Probability based weighting and only on long positions as short positions only require margin not capital (and we assume capital for initial margin to always be present and assume no margin calls) and long-short positions are not self-financing for futures like they are for stocks**

# %% [markdown]
# **XGBoost**

# %%
# Vas

import os
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['PYTHONHASHSEED'] = '0'

import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score
)
import numpy as np
import pandas as pd
import random

# --- Configuration ---
total_cost = 2 * transaction_cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
results = []
all_test_returns = []
all_dates = []
all_test_preds = []
all_test_truths = []
all_test_probas = []
fold_mean_returns = []
best_horizons_list = []

def calculate_grouped_returns(df_group, horizon):
    """Calculate returns with position sizing rules"""
    active_trades = df_group[df_group['pred'] != 0]
    if active_trades.empty:
        return 0.0

    longs = active_trades[active_trades['pred'] == 1]
    shorts = active_trades[active_trades['pred'] == 2]

    long_weights = []
    if not longs.empty:
        total_long_confidence = longs['proba'].sum()
        long_weights = longs['proba'] / total_long_confidence

    long_returns = (longs[f'Return{horizon}'] - total_cost) * long_weights
    short_returns = (-shorts[f'Return{horizon}'] - total_cost)

    return long_returns.sum() + short_returns.sum()

# --- Main Loop ---
while True:
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    if val_end_date > max_date or test_end_date > max_date:
        break

    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data = df_ml[val_mask]
    test_data = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        # Feature scaling
        scaler = StandardScaler()
        X_train = scaler.fit_transform(train_data[feature_cols])
        X_val = scaler.transform(val_data[feature_cols])
        y_train = train_data[f'Profit{horizon}']
        y_val = val_data[f'Profit{horizon}']

        # Train model
        model = xgb.XGBClassifier(
            num_class=3,
            n_estimators=60,
            max_depth=7,
            random_state=42,
            seed=42
        )
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)

        # Validate with position sizing
        val_preds = model.predict(X_val)
        val_probas = model.predict_proba(X_val)

        val_trade_df = pd.DataFrame({
            'DateTime': val_data['DateTime'],
            'pred': val_preds,
            'proba': [p[pred] for pred, p in zip(val_preds, val_probas)],
            f'Return{horizon}': val_data[f'Return{horizon}']
        })

        val_returns = val_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, horizon)
        ).values

        total_val_return = (1 + val_returns).prod() - 1

        if total_val_return > best_val_return:
            best_val_return = total_val_return
            best_horizon = horizon
            best_model = model

    # --- Test Best Model ---
    if best_model:
        X_test = scaler.transform(test_data[feature_cols])
        test_preds = best_model.predict(X_test)
        test_probas = best_model.predict_proba(X_test)
        y_test = test_data[f'Profit{best_horizon}'].values

        test_trade_df = pd.DataFrame({
            'DateTime': test_data['DateTime'],
            'pred': test_preds,
            'proba': [p[pred] for pred, p in zip(test_preds, test_probas)],
            f'Return{best_horizon}': test_data[f'Return{best_horizon}']
        })

        grouped_returns = test_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, best_horizon)
        ).values

        all_test_returns.extend(grouped_returns)
        all_dates.extend(test_trade_df['DateTime'].unique().tolist())
        all_test_preds.extend(test_preds)
        all_test_truths.extend(y_test)
        all_test_probas.append(test_probas)
        fold_mean_returns.append(np.mean(grouped_returns))
        best_horizons_list.append(best_horizon or 'standard')

    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (DateTime-Based Rolling Windows)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")
    print(f"\nOverall Test Accuracy : {accuracy_score(all_test_truths, all_test_preds)*100:.2f}%")
    print(f"Overall Precision     : {precision_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall Recall        : {recall_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall F1 Score      : {f1_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall ROC AUC       : {roc_auc_score(all_test_truths, np.vstack(all_test_probas), multi_class='ovo', average='macro')*100:.2f}%")
    print(f"\nAverage Fold Test Return : {np.mean(fold_mean_returns)*100:.5f}%")
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:122: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-128-519701f9c699>:147: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# Final Cumulative Compounded Return: 137.72%
#
# Overall Test Accuracy : 48.95%
# Overall Precision     : 35.11%
# Overall Recall        : 34.24%
# Overall F1 Score      : 33.76%
# Overall ROC AUC       : 53.66%
#
# Average Fold Test Return : 0.01314%
#
# Optimal Horizon Counts:
# _half       8
# _double     7
# standard    2
# Name: count, dtype: int64

# %% [markdown]
# **Random Forests**

# %%
#Vas

import os
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['PYTHONHASHSEED'] = '0'

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score
)
import numpy as np
import pandas as pd
import random

# --- Configuration ---
total_cost = 2 * transaction_cost  # Define your transaction cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
results = []
all_test_returns = []
all_dates = []
all_test_preds = []
all_test_truths = []
all_test_probas = []
fold_mean_returns = []
best_horizons_list = []

def calculate_grouped_returns(df_group, horizon):
    """Calculate returns with position sizing rules"""
    active_trades = df_group[df_group['pred'] != 0]
    if active_trades.empty:
        return 0.0

    longs = active_trades[active_trades['pred'] == 1]
    shorts = active_trades[active_trades['pred'] == 2]

    long_weights = []
    if not longs.empty:
        total_long_confidence = longs['proba'].sum()
        long_weights = longs['proba'] / total_long_confidence

    long_returns = (longs[f'Return{horizon}'] - total_cost) * long_weights
    short_returns = (-shorts[f'Return{horizon}'] - total_cost)

    return long_returns.sum() + short_returns.sum()

# --- Main Loop ---
while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data using datetime masks
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data = df_ml[val_mask]
    test_data = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        # Feature scaling
        scaler = StandardScaler()
        X_train = scaler.fit_transform(train_data[feature_cols])
        X_val = scaler.transform(val_data[feature_cols])
        y_train = train_data[f'Profit{horizon}']
        y_val = val_data[f'Profit{horizon}']

        # Train model
        model = RandomForestClassifier(
            n_estimators=100,
            criterion='gini',
            min_samples_leaf=4,
            random_state=42
        )
        model.fit(X_train, y_train)

        # Validate with position sizing
        val_preds = model.predict(X_val)
        val_probas = model.predict_proba(X_val)

        # Get correct probability indices using model.classes_
        class_indices = {cls: idx for idx, cls in enumerate(model.classes_)}
        proba_values = [proba[class_indices[pred]] for pred, proba in zip(val_preds, val_probas)]

        val_trade_df = pd.DataFrame({
            'DateTime': val_data['DateTime'],
            'pred': val_preds,
            'proba': proba_values,
            f'Return{horizon}': val_data[f'Return{horizon}']
        })

        val_returns = val_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, horizon)
        ).values

        total_val_return = (1 + val_returns).prod() - 1

        if total_val_return > best_val_return:
            best_val_return = total_val_return
            best_horizon = horizon
            best_model = model

    # --- Test Best Model ---
    if best_model:
        X_test = scaler.transform(test_data[feature_cols])
        test_preds = best_model.predict(X_test)
        test_probas = best_model.predict_proba(X_test)
        y_test = test_data[f'Profit{best_horizon}'].values

        # Get correct probability indices for test set
        class_indices = {cls: idx for idx, cls in enumerate(best_model.classes_)}
        test_proba_values = [proba[class_indices[pred]] for pred, proba in zip(test_preds, test_probas)]

        test_trade_df = pd.DataFrame({
            'DateTime': test_data['DateTime'],
            'pred': test_preds,
            'proba': test_proba_values,
            f'Return{best_horizon}': test_data[f'Return{best_horizon}']
        })

        grouped_returns = test_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, best_horizon)
        ).values

        all_test_returns.extend(grouped_returns)
        all_dates.extend(test_trade_df['DateTime'].unique().tolist())
        all_test_preds.extend(test_preds)
        all_test_truths.extend(y_test)
        all_test_probas.append(test_probas)
        fold_mean_returns.append(np.mean(grouped_returns))
        best_horizons_list.append(best_horizon or 'standard')

    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (Random Forest)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")
    print(f"\nOverall Test Accuracy : {accuracy_score(all_test_truths, all_test_preds)*100:.2f}%")
    print(f"Overall Precision     : {precision_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall Recall        : {recall_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall F1 Score      : {f1_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall ROC AUC       : {roc_auc_score(all_test_truths, np.vstack(all_test_probas), multi_class='ovo', average='macro')*100:.2f}%")
    print(f"\nAverage Fold Test Return : {np.mean(fold_mean_returns)*100:.5f}%")
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:129: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-126-eb8870f5ba54>:158: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# Final Cumulative Compounded Return: 84.70%
#
# Overall Test Accuracy : 49.14%
# Overall Precision     : 32.64%
# Overall Recall        : 33.82%
# Overall F1 Score      : 33.13%
# Overall ROC AUC       : 53.32%
#
# Average Fold Test Return : 0.01019%
#
# Optimal Horizon Counts:
# _double     9
# standard    5
# _half       3
# Name: count, dtype: int64

# %% [markdown]
# **Logistic Regression**

# %%
#Vas

from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score
)
import numpy as np
import pandas as pd
import os, random

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)

# --- Configuration ---
total_cost = 2 * transaction_cost
horizons = ['', '_half', '_double']

# --- Data Prep ---
df_ml = df_ml.dropna(subset=['Surprise']).sort_values('DateTime')
min_date = df_ml['DateTime'].min()
max_date = df_ml['DateTime'].max()

# --- Calculate Initial 30% Training Period ---
total_duration = max_date - min_date
initial_train_duration = total_duration * 0.3
train_end_date = min_date + initial_train_duration

# --- Tracking containers ---
all_test_returns = []
all_dates = []
all_test_preds = []
all_test_truths = []
all_test_probas = []
fold_mean_returns = []
best_horizons_list = []

def calculate_grouped_returns(df_group, horizon):
    """Identical position sizing logic to other models"""
    active_trades = df_group[df_group['pred'] != 0]
    if active_trades.empty:
        return 0.0

    longs = active_trades[active_trades['pred'] == 1]
    shorts = active_trades[active_trades['pred'] == 2]

    long_weights = []
    if not longs.empty:
        total_long_confidence = longs['proba'].sum()
        long_weights = longs['proba'] / total_long_confidence

    long_returns = (longs[f'Return{horizon}'] - total_cost) * long_weights
    short_returns = (-shorts[f'Return{horizon}'] - total_cost)

    return long_returns.sum() + short_returns.sum()

# --- Main Loop ---
while True:
    # Define validation period (1 year after training)
    val_start_date = train_end_date + pd.DateOffset(days=1)
    val_end_date = val_start_date + pd.DateOffset(years=1)

    # Define test period (1 year after validation)
    test_start_date = val_end_date + pd.DateOffset(days=1)
    test_end_date = test_start_date + pd.DateOffset(years=1)

    if val_end_date > max_date or test_end_date > max_date:
        break

    # Extract data
    train_mask = df_ml['DateTime'] <= train_end_date
    val_mask = (df_ml['DateTime'] >= val_start_date) & (df_ml['DateTime'] <= val_end_date)
    test_mask = (df_ml['DateTime'] >= test_start_date) & (df_ml['DateTime'] <= test_end_date)

    train_data = df_ml[train_mask]
    val_data = df_ml[val_mask]
    test_data = df_ml[test_mask]

    if val_data.empty or test_data.empty:
        print(f"Skipping period {val_start_date.date()} to {test_end_date.date()} (no data)")
        train_end_date += pd.DateOffset(years=1)
        continue

    # --- Horizon Optimization ---
    best_horizon, best_model = None, None
    best_val_return = -np.inf

    for horizon in horizons:
        # Feature scaling
        scaler = StandardScaler()
        X_train = scaler.fit_transform(train_data[feature_cols])
        X_val = scaler.transform(val_data[feature_cols])
        y_train = train_data[f'Profit{horizon}']
        y_val = val_data[f'Profit{horizon}']

        # Train Logistic Regression
        model = LogisticRegression(
            multi_class='multinomial',
            solver='saga',
            max_iter=100,
            random_state=42
        )
        model.fit(X_train, y_train)

        # Validate with position sizing
        val_preds = model.predict(X_val)
        val_probas = model.predict_proba(X_val)

        # Map class labels to probability indices
        class_indices = {cls: idx for idx, cls in enumerate(model.classes_)}
        proba_values = [proba[class_indices[pred]] for pred, proba in zip(val_preds, val_probas)]

        val_trade_df = pd.DataFrame({
            'DateTime': val_data['DateTime'],
            'pred': val_preds,
            'proba': proba_values,
            f'Return{horizon}': val_data[f'Return{horizon}']
        })

        val_returns = val_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, horizon)
        ).values

        total_val_return = (1 + val_returns).prod() - 1

        if total_val_return > best_val_return:
            best_val_return = total_val_return
            best_horizon = horizon
            best_model = model

    # --- Test Best Model ---
    if best_model:
        X_test = scaler.transform(test_data[feature_cols])
        test_preds = best_model.predict(X_test)
        test_probas = best_model.predict_proba(X_test)
        y_test = test_data[f'Profit{best_horizon}'].values

        # Map class labels for test set
        class_indices = {cls: idx for idx, cls in enumerate(best_model.classes_)}
        test_proba_values = [proba[class_indices[pred]] for pred, proba in zip(test_preds, test_probas)]

        test_trade_df = pd.DataFrame({
            'DateTime': test_data['DateTime'],
            'pred': test_preds,
            'proba': test_proba_values,
            f'Return{best_horizon}': test_data[f'Return{best_horizon}']
        })

        grouped_returns = test_trade_df.groupby('DateTime').apply(
            lambda x: calculate_grouped_returns(x, best_horizon)
        ).values

        # Store results
        all_test_returns.extend(grouped_returns)
        all_dates.extend(test_trade_df['DateTime'].unique().tolist())
        all_test_preds.extend(test_preds)
        all_test_truths.extend(y_test)
        all_test_probas.append(test_probas)
        fold_mean_returns.append(np.mean(grouped_returns))
        best_horizons_list.append(best_horizon or 'standard')

    train_end_date += pd.DateOffset(years=1)

# --- Results ---
if all_test_returns:
    cumulative_returns = (1 + np.array(all_test_returns)).cumprod() - 1
    plt.figure(figsize=(12, 6))
    plt.plot(all_dates, cumulative_returns * 100)
    plt.title('Cumulative Returns (Multinomial Logistic Regression)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return (%)')
    plt.grid(True)
    plt.show()

    print(f"Final Cumulative Compounded Return: {cumulative_returns[-1]*100:.2f}%")
    print(f"\nOverall Test Accuracy : {accuracy_score(all_test_truths, all_test_preds)*100:.2f}%")
    print(f"Overall Precision     : {precision_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall Recall        : {recall_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall F1 Score      : {f1_score(all_test_truths, all_test_preds, average='macro', zero_division=0)*100:.2f}%")
    print(f"Overall ROC AUC       : {roc_auc_score(all_test_truths, np.vstack(all_test_probas), multi_class='ovo', average='macro')*100:.2f}%")
    print(f"\nAverage Fold Test Return : {np.mean(fold_mean_returns)*100:.5f}%")
    print("\nOptimal Horizon Counts:")
    print(pd.Series(best_horizons_list).value_counts())

else:
    print("No valid test periods found")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# <ipython-input-127-cc8f4ed415f4>:124: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   val_returns = val_trade_df.groupby('DateTime').apply(
# <ipython-input-127-cc8f4ed415f4>:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_returns = test_trade_df.groupby('DateTime').apply(
# Final Cumulative Compounded Return: 6.48%
#
# Overall Test Accuracy : 48.75%
# Overall Precision     : 40.10%
# Overall Recall        : 35.02%
# Overall F1 Score      : 34.97%
# Overall ROC AUC       : 54.58%
#
# Average Fold Test Return : 0.00085%
#
# Optimal Horizon Counts:
# _half       9
# standard    5
# _double     3
# Name: count, dtype: int64

# %% [markdown]
# **Drawing comparison between surprise based and non-surprise based holding-period returns**

# %%
# Initialize columns
df_combined['Total_Return'] = np.nan
df_combined['Total_Return_half'] = np.nan
df_combined['Total_Return_double'] = np.nan

# Loop through all rows (not just surprise rows)
for index, row in df_combined.iterrows():
    row_position = df_combined.index.get_loc(index)

    # Standard holding period
    if row_position + holding_period < len(df_combined):
        current_price = row['Open']
        future_price = df_combined.iloc[row_position + holding_period]['Open']

        if current_price != 0:
            df_combined.at[index, 'Total_Return'] = (future_price - current_price) / current_price

    # Half holding period
    if row_position + int(holding_period * 0.5) < len(df_combined):
        current_price = row['Open']
        future_price = df_combined.iloc[row_position + int(holding_period * 0.5)]['Open']

        if current_price != 0:
            df_combined.at[index, 'Total_Return_half'] = (future_price - current_price) / current_price

    # Double holding period
    if row_position + int(holding_period * 2) < len(df_combined):
        current_price = row['Open']
        future_price = df_combined.iloc[row_position + int(holding_period * 2)]['Open']

        if current_price != 0:
            df_combined.at[index, 'Total_Return_double'] = (future_price - current_price) / current_price

# %%
df_combined[['Total_Return', 'Total_Return_half', 'Total_Return_double']].mean()
# Out:
# Total_Return           0.000004
# Total_Return_half      0.000002
# Total_Return_double    0.000009
# dtype: float64

# %%
df_combined[['Return', 'Return_half', 'Return_double']].mean()*100
# Out:
# Return           0.000325
# Return_half     -0.001230
# Return_double   -0.000822
# dtype: float64

# %%
df_combined.shape[0]

# %%
# Now we get the first and last observation in the test set so we can compute compounded return (comes out to almost exactly 17 years)

if 'all_dates' in globals() and len(all_dates) > 0:  # Check if all_dates exists
    first_test_date = pd.to_datetime(min(all_dates)).strftime('%Y-%m-%d %H:%M')
    last_test_date = pd.to_datetime(max(all_dates)).strftime('%Y-%m-%d %H:%M')
    print(f"Test Period: {first_test_date} to {last_test_date}")
else:
    print("No test dates found. Run backtest first.")

# %%
print(f"\nTotal number of test observations: {len(all_test_returns)}")
