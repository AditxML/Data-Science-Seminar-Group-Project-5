# %% [markdown]
# # **Data Loading & Preprocessing** with changes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# get all ES_part_X files, 1 up to 5 and place in one df_es dataframe
df_es = pd.DataFrame()
for i in range(1, 6):
    df_temp = pd.read_csv(f'ES_part_{i}.csv')
    df_es = pd.concat([df_es, df_temp], ignore_index=True)

# %%
df_es
# Out:
#                Date   Time     Open    Close  Volume
# 0        09/10/1997  00:01     0.00     0.00       0
# 1        09/10/1997  00:02     0.00     0.00       0
# 2        09/10/1997  00:03     0.00     0.00       0
# 3        09/10/1997  00:04     0.00     0.00       0
# 4        09/10/1997  00:05     0.00     0.00       0
# ...             ...    ...      ...      ...     ...
# 9682630  12/19/2024  15:56  5941.75  5941.75     318
# 9682631  12/19/2024  15:57  5941.75  5941.50     386
# 9682632  12/19/2024  15:58  5941.50  5941.00     484
# 9682633  12/19/2024  15:59  5940.75  5941.00    6462
# 9682634  12/19/2024  16:00  5941.00  5941.25    8864
#
# [9682635 rows x 5 columns]

# %%
df_surprise = pd.read_csv('US_economic_releases_events.csv')
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1241424920.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_surprise = pd.read_csv('US_economic_releases_events.csv')

# %%
df_surprise
# Out:
#        Unnamed: 0 Period                             Event          Ticker  \
# 0      1997-01-02    Dec                 ISM Manufacturing   NAPMPMI Index
# 1      1997-01-03    Nov             Construction Spending   VNCCTOT Index
# 2      1997-01-06    Dec               Housing Completions  PHUCCHNG Index
# 3      1997-01-07    Nov                    Factory Orders  TMNOCHNG Index
# 4      1997-01-08    Dec                   Consumer Credit   CICRTOT Index
# ...           ...    ...                               ...             ...
# 36053  2024-12-31    Oct        FHFA House Price Index MoM  HPIMMOM% Index
# 36054  2024-12-31    Oct   S&P CoreLogic CS 20-City MoM SA  SPCS20SM Index
# 36055  2024-12-31    Oct  S&P CoreLogic CS 20-City YoY NSA  SPCS20Y% Index
# 36056  2024-12-31    Oct   S&P CoreLogic CS US HPI YoY NSA  SPCSUSAY Index
# 36057  2024-12-31    Dec      Dallas Fed Services Activity  DSERGBCC Index
#
#         Actual    Prior Revised         S Freq. First Rev.  ... Month Surv(A)  \
# 0         55.2       53      --  94.81480     M         --  ...   Jan      --
# 1         1.9$     1.8$    1.5$   0.00000     M       1.5$  ...   Jan  -0.40$
# 2           2k      -1k      --   0.00000     M         --  ...   Jan      --
# 3       -0.004    0.009   0.011  84.44440     M      0.011  ...   Jan  -0.007
# 4      $7.400b  $2.200b      --  42.96300     M         --  ...   Jan  $3.60b
# ...        ...      ...     ...       ...   ...        ...  ...   ...     ...
# 36053       --    0.007      --  68.88890     M         --  ...   Dec      --
# 36054       --   0.0018      --  30.37040     M         --  ...   Dec      --
# 36055       --   0.0457      --  40.74070     M         --  ...   Dec      --
# 36056       --   0.0389      --  35.55560     M         --  ...   Dec      --
# 36057       --      9.8      --   5.92593     M         --  ...   Dec      --
#
#       Surv(H) Surv(L) Surv(M) # Ests.  Std Dev Surprise Country/Region  \
# 0          --      --      --     0.0       --       --  United States
# 1          --      --  -0.40$     0.0       --       --  United States
# 2          --      --      --     0.0       --       --  United States
# 3          --      --  -0.007     0.0       --       --  United States
# 4          --      --  $3.60b     0.0       --       --  United States
# ...       ...     ...     ...     ...      ...      ...            ...
# 36053      --      --      --     0.0       --       --  United States
# 36054      --      --      --     1.0       --       --  United States
# 36055      --      --      --     1.0       --       --  United States
# 36056      --      --      --     0.0       --       --  United States
# 36057      --      --      --     0.0       --       --  United States
#
#                 Flag
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...
# 36053  United States
# 36054  United States
# 36055  United States
# 36056  United States
# 36057  United States
#
# [36058 rows x 28 columns]

# %%
df_surprise.drop(columns=['S', 'Month', 'Surv(A)', 'Surv(H)', 'Surv(L)',], inplace=True)

# %%
df_surprise.columns
# Out:
# Index(['Unnamed: 0', 'Period', 'Event', 'Ticker', 'Actual', 'Prior', 'Revised',
#        'Freq.', 'First Rev.', 'Last Rev.', 'Date', 'Time', 'C', 'Category',
#        'Subcategory', 'R', 'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise',
#        'Country/Region', 'Flag'],
#       dtype='object')

# %%
df_surprise.drop(columns=['Flag', 'Country/Region', 'Day'])
# Out:
#        Unnamed: 0 Period                             Event          Ticker  \
# 0      1997-01-02    Dec                 ISM Manufacturing   NAPMPMI Index
# 1      1997-01-03    Nov             Construction Spending   VNCCTOT Index
# 2      1997-01-06    Dec               Housing Completions  PHUCCHNG Index
# 3      1997-01-07    Nov                    Factory Orders  TMNOCHNG Index
# 4      1997-01-08    Dec                   Consumer Credit   CICRTOT Index
# ...           ...    ...                               ...             ...
# 36053  2024-12-31    Oct        FHFA House Price Index MoM  HPIMMOM% Index
# 36054  2024-12-31    Oct   S&P CoreLogic CS 20-City MoM SA  SPCS20SM Index
# 36055  2024-12-31    Oct  S&P CoreLogic CS 20-City YoY NSA  SPCS20Y% Index
# 36056  2024-12-31    Oct   S&P CoreLogic CS US HPI YoY NSA  SPCSUSAY Index
# 36057  2024-12-31    Dec      Dallas Fed Services Activity  DSERGBCC Index
#
#         Actual    Prior Revised Freq. First Rev. Last Rev.  \
# 0         55.2       53      --     M         --        --
# 1         1.9$     1.8$    1.5$     M       1.5$        --
# 2           2k      -1k      --     M         --        --
# 3       -0.004    0.009   0.011     M      0.011    -0.001
# 4      $7.400b  $2.200b      --     M         --   $6.064b
# ...        ...      ...     ...   ...        ...       ...
# 36053       --    0.007      --     M         --        --
# 36054       --   0.0018      --     M         --        --
# 36055       --   0.0457      --     M         --        --
# 36056       --   0.0389      --     M         --        --
# 36057       --      9.8      --     M         --        --
#
#                       Date      Time   C           Category Subcategory  \
# 0      1997-01-02 00:00:00  09:00:00  US  Economic Releases         NaN
# 1      1997-01-03 00:00:00  09:00:00  US  Economic Releases         NaN
# 2      1997-01-06 00:00:00  09:00:00  US  Economic Releases         NaN
# 3      1997-01-07 00:00:00  09:00:00  US  Economic Releases         NaN
# 4      1997-01-08 00:00:00  14:00:00  US  Economic Releases         NaN
# ...                    ...       ...  ..                ...         ...
# 36053  2024-12-31 00:00:00  08:00:00  US  Economic Releases         NaN
# 36054  2024-12-31 00:00:00  08:00:00  US  Economic Releases         NaN
# 36055  2024-12-31 00:00:00  08:00:00  US  Economic Releases         NaN
# 36056  2024-12-31 00:00:00  08:00:00  US  Economic Releases         NaN
# 36057  2024-12-31 00:00:00  09:30:00  US  Economic Releases         NaN
#
#               R Surv(M)  # Ests. Std Dev Surprise
# 0      94.81480      --      0.0      --       --
# 1       0.00000  -0.40$      0.0      --       --
# 2       0.00000      --      0.0      --       --
# 3      84.44440  -0.007      0.0      --       --
# 4      42.96300  $3.60b      0.0      --       --
# ...         ...     ...      ...     ...      ...
# 36053  68.88890      --      0.0      --       --
# 36054  30.37040      --      1.0      --       --
# 36055  40.74070      --      1.0      --       --
# 36056  35.55560      --      0.0      --       --
# 36057   5.92593      --      0.0      --       --
#
# [36058 rows x 20 columns]

# %%
# Dropping all rows for which surprise column has NaN or 0 value
df_surprise.dropna(subset=['Surprise'], inplace=True)
df_surprise = df_surprise[df_surprise['Surprise'] != 0]

# %%
nan_count = df_surprise['Surprise'].isnull().sum()
print(f"Number of NaN values in 'Surprise' column: {nan_count}")
# Out:
# Number of NaN values in 'Surprise' column: 0

# %%
print(df_surprise.isna().sum())
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                 0
# Revised               0
# Freq.                 0
# First Rev.            0
# Last Rev.             0
# Date                  0
# Time                325
# C                     0
# Category              0
# Subcategory       35186
# R                     0
# Day                  25
# Surv(M)               0
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
df_surprise.replace("--", pd.NA, inplace=True)


print(df_surprise.isna().sum())
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual              987
# Prior               980
# Revised           17228
# Freq.                 0
# First Rev.        17228
# Last Rev.         10752
# Date                  0
# Time                325
# C                     0
# Category              0
# Subcategory       35186
# R                     0
# Day                  25
# Surv(M)            6942
# # Ests.               0
# Std Dev            7539
# Surprise           8564
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
# Redoing dropping all rows for which surprise column has NaN or 0 value
df_surprise.dropna(subset=['Surprise'], inplace=True)
df_surprise = df_surprise[df_surprise['Surprise'] != 0]

# %%
df_surprise
# Out:
#        Unnamed: 0               Period                                  Event  \
# 8      1997-01-10                  Dec                      Unemployment Rate
# 153    1997-06-25                 1Q F                     GDP Annualized QoQ
# 198    1997-08-01                  Jul             Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                     GDP Annualized QoQ
# 523    1998-03-26                 4Q F                     GDP Annualized QoQ
# ...           ...                  ...                                    ...
# 35998  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Current Yr
# 35999  2024-12-18  2024-12-18 00:00:00     FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00      FOMC Median Rate Forecast: +2 Yrs
# 36001  2024-12-18  2024-12-18 00:00:00      FOMC Median Rate Forecast: +3 Yrs
# 36002  2024-12-18  2024-12-18 00:00:00    FOMC Median Rate Forecast: Long-Run
#
#                Ticker   Actual    Prior Revised Freq. First Rev. Last Rev.  \
# 8       USURTOT Index    0.053    0.054   0.053     M      0.053      <NA>
# 153    GDP CQOQ Index    0.059    0.058    <NA>     Q       <NA>      <NA>
# 198     NFP TCH Index     316k     217k    228k     M       228k      265k
# 394    GDP CQOQ Index    0.031    0.033    <NA>     Q       <NA>     0.051
# 523    GDP CQOQ Index    0.037    0.039    <NA>     Q       <NA>      <NA>
# ...               ...      ...      ...     ...   ...        ...       ...
# 35998  DOTDY0MD Index  0.04375  0.04375    <NA>     D       <NA>      <NA>
# 35999  DOTDY1MD Index  0.03875  0.03375    <NA>     D       <NA>      <NA>
# 36000  DOTDY2MD Index  0.03375  0.02875    <NA>     D       <NA>      <NA>
# 36001  DOTDY3MD Index  0.03125  0.02875    <NA>     D       <NA>      <NA>
# 36002  DOTDLTMD Index     0.03  0.02875    <NA>     D       <NA>      <NA>
#
#        ...           Category Subcategory          R  Day  Surv(M)  # Ests.  \
# 8      ...  Economic Releases         NaN  89.333300  Fri    0.053     10.0
# 153    ...  Economic Releases         NaN  96.296300  Wed    0.058     13.0
# 198    ...  Economic Releases         NaN  99.259300  Fri      70k     20.0
# 394    ...  Economic Releases         NaN  96.296300  Tue    0.033     11.0
# 523    ...  Economic Releases         NaN  96.296300  Thu    0.039     22.0
# ...    ...                ...         ...        ...  ...      ...      ...
# 35998  ...  Economic Releases         NaN   2.962960  Wed  0.04375      9.0
# 35999  ...  Economic Releases         NaN   2.222220  Wed  0.03625     12.0
# 36000  ...  Economic Releases         NaN   0.740741  Wed  0.03125     11.0
# 36001  ...  Economic Releases         NaN   0.000000  Wed  0.03125     11.0
# 36002  ...  Economic Releases         NaN   1.481480  Wed     0.03     11.0
#
#       Std Dev Surprise  Country/Region           Flag
# 8        0.07        0   United States  United States
# 153      0.22     0.45   United States  United States
# 198     33.84     7.27   United States  United States
# 394      0.07    -2.98   United States  United States
# 523      0.08    -2.52   United States  United States
# ...       ...      ...             ...            ...
# 35998       0        0   United States  United States
# 35999    0.12     2.03   United States  United States
# 36000    0.11     2.35   United States  United States
# 36001    0.08        0   United States  United States
# 36002    0.06        0   United States  United States
#
# [26622 rows x 23 columns]

# %%
# We suspected that 0s were not being filtered out because the data type of the surprise column was an object and thus converting it to float and then redoing
# the filtering should help and it did

# Convert 'Surprise' column to float
df_surprise['Surprise'] = pd.to_numeric(df_surprise['Surprise'], errors='coerce')

# Again filtering out rows where 'Surprise' is 0 or NaN
df_surprise = df_surprise[df_surprise['Surprise'] != 0].dropna(subset=['Surprise'])

df_surprise
# Out:
#        Unnamed: 0               Period                               Event  \
# 153    1997-06-25                 1Q F                  GDP Annualized QoQ
# 198    1997-08-01                  Jul          Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                  GDP Annualized QoQ
# 523    1998-03-26                 4Q F                  GDP Annualized QoQ
# 569    1998-04-30                 1Q A                  GDP Annualized QoQ
# ...           ...                  ...                                 ...
# 35992  2024-12-18                Nov P                    Building Permits
# 35993  2024-12-18                Nov P                Building Permits MoM
# 35994  2024-12-18                   3Q             Current Account Balance
# 35999  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00   FOMC Median Rate Forecast: +2 Yrs
#
#                Ticker    Actual     Prior   Revised Freq. First Rev.  \
# 153    GDP CQOQ Index     0.059     0.058      <NA>     Q       <NA>
# 198     NFP TCH Index      316k      217k      228k     M       228k
# 394    GDP CQOQ Index     0.031     0.033      <NA>     Q       <NA>
# 523    GDP CQOQ Index     0.037     0.039      <NA>     Q       <NA>
# 569    GDP CQOQ Index     0.042     0.037      <NA>     Q       <NA>
# ...               ...       ...       ...       ...   ...        ...
# 35992  NHSPATOT Index     1505k     1416k     1419k     M      1419k
# 35993  NHCHATCH Index     0.061    -0.006    -0.004     M     -0.004
# 35994   USCABAL Index  -$310.9b  -$266.8b  -$275.0b     Q   -$275.0b
# 35999  DOTDY1MD Index   0.03875   0.03375      <NA>     D       <NA>
# 36000  DOTDY2MD Index   0.03375   0.02875      <NA>     D       <NA>
#
#       Last Rev.  ...           Category Subcategory          R  Day   Surv(M)  \
# 153        <NA>  ...  Economic Releases         NaN  96.296300  Wed     0.058
# 198        265k  ...  Economic Releases         NaN  99.259300  Fri       70k
# 394       0.051  ...  Economic Releases         NaN  96.296300  Tue     0.033
# 523        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.039
# 569        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.034
# ...         ...  ...                ...         ...        ...  ...       ...
# 35992     1419k  ...  Economic Releases         NaN  61.185200  Wed     1430k
# 35993    -0.004  ...  Economic Releases         NaN  31.851900  Wed      0.01
# 35994  -$275.0b  ...  Economic Releases         NaN  71.111100  Wed  -$287.1b
# 35999      <NA>  ...  Economic Releases         NaN   2.222220  Wed   0.03625
# 36000      <NA>  ...  Economic Releases         NaN   0.740741  Wed   0.03125
#
#        # Ests. Std Dev Surprise  Country/Region           Flag
# 153       13.0    0.22     0.45   United States  United States
# 198       20.0   33.84     7.27   United States  United States
# 394       11.0    0.07    -2.98   United States  United States
# 523       22.0    0.08    -2.52   United States  United States
# 569       19.0    0.36     2.22   United States  United States
# ...        ...     ...      ...             ...            ...
# 35992     46.0   22.21     3.38   United States  United States
# 35993     46.0    1.78     2.87   United States  United States
# 35994     18.0    6.22    -3.84   United States  United States
# 35999     12.0    0.12     2.03   United States  United States
# 36000     11.0    0.11     2.35   United States  United States
#
# [23715 rows x 23 columns]

# %%
# Seeing if anything looks weird to see what else to filter out eg. Time having missing values despite surprises being non missing values is now problematic for
# our analysis so we should get rid of it and number of subcategory missings are equal to total number of current observations so can also get rid of that column
print(df_surprise.isna().sum())
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            9125
# Freq.                 0
# First Rev.         9125
# Last Rev.          4439
# Date                  0
# Time                310
# C                     0
# Category              0
# Subcategory       23715
# R                     0
# Day                  23
# Surv(M)               2
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
df_surprise.dropna(subset=['Time'], inplace=True)

df_surprise
# Out:
#        Unnamed: 0               Period                               Event  \
# 153    1997-06-25                 1Q F                  GDP Annualized QoQ
# 198    1997-08-01                  Jul          Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                  GDP Annualized QoQ
# 523    1998-03-26                 4Q F                  GDP Annualized QoQ
# 569    1998-04-30                 1Q A                  GDP Annualized QoQ
# ...           ...                  ...                                 ...
# 35992  2024-12-18                Nov P                    Building Permits
# 35993  2024-12-18                Nov P                Building Permits MoM
# 35994  2024-12-18                   3Q             Current Account Balance
# 35999  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00   FOMC Median Rate Forecast: +2 Yrs
#
#                Ticker    Actual     Prior   Revised Freq. First Rev.  \
# 153    GDP CQOQ Index     0.059     0.058      <NA>     Q       <NA>
# 198     NFP TCH Index      316k      217k      228k     M       228k
# 394    GDP CQOQ Index     0.031     0.033      <NA>     Q       <NA>
# 523    GDP CQOQ Index     0.037     0.039      <NA>     Q       <NA>
# 569    GDP CQOQ Index     0.042     0.037      <NA>     Q       <NA>
# ...               ...       ...       ...       ...   ...        ...
# 35992  NHSPATOT Index     1505k     1416k     1419k     M      1419k
# 35993  NHCHATCH Index     0.061    -0.006    -0.004     M     -0.004
# 35994   USCABAL Index  -$310.9b  -$266.8b  -$275.0b     Q   -$275.0b
# 35999  DOTDY1MD Index   0.03875   0.03375      <NA>     D       <NA>
# 36000  DOTDY2MD Index   0.03375   0.02875      <NA>     D       <NA>
#
#       Last Rev.  ...           Category Subcategory          R  Day   Surv(M)  \
# 153        <NA>  ...  Economic Releases         NaN  96.296300  Wed     0.058
# 198        265k  ...  Economic Releases         NaN  99.259300  Fri       70k
# 394       0.051  ...  Economic Releases         NaN  96.296300  Tue     0.033
# 523        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.039
# 569        <NA>  ...  Economic Releases         NaN  96.296300  Thu     0.034
# ...         ...  ...                ...         ...        ...  ...       ...
# 35992     1419k  ...  Economic Releases         NaN  61.185200  Wed     1430k
# 35993    -0.004  ...  Economic Releases         NaN  31.851900  Wed      0.01
# 35994  -$275.0b  ...  Economic Releases         NaN  71.111100  Wed  -$287.1b
# 35999      <NA>  ...  Economic Releases         NaN   2.222220  Wed   0.03625
# 36000      <NA>  ...  Economic Releases         NaN   0.740741  Wed   0.03125
#
#        # Ests. Std Dev Surprise  Country/Region           Flag
# 153       13.0    0.22     0.45   United States  United States
# 198       20.0   33.84     7.27   United States  United States
# 394       11.0    0.07    -2.98   United States  United States
# 523       22.0    0.08    -2.52   United States  United States
# 569       19.0    0.36     2.22   United States  United States
# ...        ...     ...      ...             ...            ...
# 35992     46.0   22.21     3.38   United States  United States
# 35993     46.0    1.78     2.87   United States  United States
# 35994     18.0    6.22    -3.84   United States  United States
# 35999     12.0    0.12     2.03   United States  United States
# 36000     11.0    0.11     2.35   United States  United States
#
# [23405 rows x 23 columns]

# %%
print(df_surprise.isna().sum())

# Based on the output below let's next observe the two missing values for Surv(M), specifically looking at their Surprise column values to see if anything is striking, if it is
# then we'll drop those two rows. This is because in principle Surv(M) should not have missing values given that Surprise has none and is a function of Surv(M)
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            8820
# Freq.                 0
# First Rev.         8820
# Last Rev.          4265
# Date                  0
# Time                  0
# C                     0
# Category              0
# Subcategory       23405
# R                     0
# Day                   0
# Surv(M)               2
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# dtype: int64

# %%
rows_with_missing_survm = df_surprise[df_surprise['Surv(M)'].isnull()]
rows_with_missing_survm
# Out:
#      Unnamed: 0 Period                       Event          Ticker Actual  \
# 816  1998-10-15    Sep                     PPI MoM  PPI CHNG Index  0.003
# 817  1998-10-15    Sep  PPI Ex Food and Energy MoM  PXFECHNG Index  0.004
#
#       Prior Revised Freq. First Rev. Last Rev.  ...           Category  \
# 816  -0.004    <NA>     M       <NA>    -0.002  ...  Economic Releases
# 817  -0.001    <NA>     M       <NA>         0  ...  Economic Releases
#
#     Subcategory    R  Day  Surv(M)  # Ests. Std Dev     Surprise  \
# 816         NaN  0.0  Thu     <NA>     36.0    0.05  21213370.81
# 817         NaN  0.0  Thu     <NA>     34.0    0.05  21213372.93
#
#      Country/Region           Flag
# 816   United States  United States
# 817   United States  United States
#
# [2 rows x 23 columns]

# %%
# Based on the output above let's see what the average, IQR and max is for the surprise column to see if surprise values of 21213370.81 and 21213372.93 are troubling
# and should thus be removed

df_surprise['Surprise'].describe()
# Out:
# count    2.340500e+04
# mean     4.521226e+03
# std      2.374934e+05
# min     -8.167000e+01
# 25%     -1.520000e+00
# 50%     -1.000000e-02
# 75%      1.550000e+00
# max      2.121337e+07
# Name: Surprise, dtype: float64

# %%
# Let's actually plot a histogram of those values to identify if the values above are outliers

plt.hist(df_surprise['Surprise'], bins=20)
plt.xlabel('Surprise')
plt.ylabel('Frequency')
plt.title('Histogram of Surprise Values')
plt.ticklabel_format(axis='x', style='sci', scilimits=(1,1))
plt.show()

# by using ticklabel_format and scilimits here we can see (although not obvious from the graph) that there are outliers as the scale of the x-axis hasn't automatically adjusted to be being around -10 to 10

# %%
# Wincorsizing to get results between 0.5% and 99.5% percentile for Surprise values

lower_bound = df_surprise['Surprise'].quantile(0.005)
upper_bound = df_surprise['Surprise'].quantile(0.995)

df_surprise = df_surprise[(df_surprise['Surprise'] >= lower_bound) & (df_surprise['Surprise'] <= upper_bound)]

# %%
plt.hist(df_surprise['Surprise'], bins=20)
plt.xlabel('Surprise')
plt.ylabel('Frequency')
plt.title('Histogram of Surprise Values')
plt.ticklabel_format(axis='x', style='sci', scilimits=(1,1))
plt.show()

# Now the scale has automatically adjusted to being between -10 and 10 so outliers are removed, also we notice that surprises are quite normally distributed

# %%
# Let's now print the 10 rows with the largest Surprise values to see if anything looks abnormal - and it doesn't, as expected max values are around 10

df_surprise.nlargest(10, 'Surprise')
# Out:
#        Unnamed: 0               Period                           Event  \
# 2456   2001-04-18                  Feb                   Trade Balance
# 32474  2023-01-13                Jan P  U. of Mich. Current Conditions
# 14287  2012-05-31                  May                   ISM Milwaukee
# 26021  2019-05-17                May P        U. of Mich. Expectations
# 4815   2004-06-25                 1Q F              GDP Price Deflator
# 22353  2017-05-11                  Apr  PPI Ex Food, Energy, Trade MoM
# 12370  2011-01-05                  Dec           ADP Employment Change
# 34665  2024-03-28                Mar F  U. of Mich. Current Conditions
# 7542   2007-02-15  2024-02-10 00:00:00          Initial Jobless Claims
# 34457  2024-02-16                  Jan  PPI Ex Food, Energy, Trade MoM
#
#                Ticker   Actual    Prior Revised Freq. First Rev. Last Rev.  \
# 2456    USTBTOT Index  -$27.0b  -$33.3b    <NA>     M       <NA>   -$35.2b
# 32474  CONSCURR Index     68.6     59.4    <NA>     M       <NA>      <NA>
# 14287  MAPMINDX Index     57.7     52.9    <NA>     M       <NA>      <NA>
# 26021   CONSEXP Index       96     87.4    <NA>     M       <NA>      <NA>
# 4815   GDP DCHG Index    0.029    0.026    <NA>     Q       <NA>      <NA>
# 22353  FDIDSGUM Index    0.007    0.001    <NA>     M       <NA>     0.001
# 12370  ADP CHNG Index     297k      93k     92k     M        92k      240k
# 34665  CONSCURR Index     82.5     79.4    <NA>     M       <NA>      <NA>
# 7542     INJCJC Index     357k     311k    313k     W       313k      310k
# 34457  FDIDSGUM Index    0.006    0.002   0.003     M      0.003     0.003
#
#        ...           Category Subcategory        R  Day  Surv(M)  # Ests.  \
# 2456   ...  Economic Releases         NaN  82.9630  Wed  -$33.0b     40.0
# 32474  ...  Economic Releases         NaN  21.4815  Fri       60      5.0
# 14287  ...  Economic Releases         NaN   0.0000  Thu     53.4      3.0
# 26021  ...  Economic Releases         NaN  23.7037  Fri     86.8      3.0
# 4815   ...  Economic Releases         NaN   0.0000  Fri    0.026     47.0
# 22353  ...  Economic Releases         NaN  22.9630  Thu    0.002      8.0
# 12370  ...  Economic Releases         NaN  90.3704  Wed     100k     33.0
# 34665  ...  Economic Releases         NaN  21.4815  Thu     79.6      3.0
# 7542   ...  Economic Releases         NaN  98.5185  Thu     314k     39.0
# 34457  ...  Economic Releases         NaN  22.9630  Fri    0.001      9.0
#
#       Std Dev Surprise  Country/Region           Flag
# 2456     0.57    10.58   United States  United States
# 32474    0.82    10.54   United States  United States
# 14287    0.41    10.46   United States  United States
# 26021    0.88    10.45   United States  United States
# 4815     0.03    10.39   United States  United States
# 22353    0.05    10.33   United States  United States
# 12370   19.15    10.29   United States  United States
# 34665    0.28    10.25   United States  United States
# 7542      4.2    10.23   United States  United States
# 34457    0.05    10.06   United States  United States
#
# [10 rows x 23 columns]

# %%
df_surprise.columns
# Out:
# Index(['Unnamed: 0', 'Period', 'Event', 'Ticker', 'Actual', 'Prior', 'Revised',
#        'Freq.', 'First Rev.', 'Last Rev.', 'Date', 'Time', 'C', 'Category',
#        'Subcategory', 'R', 'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise',
#        'Country/Region', 'Flag'],
#       dtype='object')

# %%
df_surprise[['Date','Time']]
# Out:
#                       Date      Time
# 153    1997-06-25 00:00:00  07:30:00
# 198    1997-08-01 00:00:00  07:30:00
# 394    1997-12-23 00:00:00  07:30:00
# 523    1998-03-26 00:00:00  07:30:00
# 569    1998-04-30 00:00:00  07:30:00
# ...                    ...       ...
# 35992  2024-12-18 00:00:00  07:30:00
# 35993  2024-12-18 00:00:00  07:30:00
# 35994  2024-12-18 00:00:00  07:30:00
# 35999  2024-12-18 00:00:00  13:00:00
# 36000  2024-12-18 00:00:00  13:00:00
#
# [23169 rows x 2 columns]

# %%
# Step 1: Ensure columns are strings
df_surprise['Date'] = df_surprise['Date'].astype(str)
df_surprise['Time'] = df_surprise['Time'].astype(str)

# Step 2: Handle missing times (if any)
df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')

# Step 3: Combine Date and Time into DateTime
df_surprise['DateTime'] = pd.to_datetime(
    df_surprise['Date'].str[:10] + ' ' + df_surprise['Time'],
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'  # Converts invalid parsing to NaT instead of raising error
)

# Step 4: Verify the new column
print("\nFirst 5 rows of DateTime column:")
print(df_surprise['DateTime'].head())

# Step 5: Check for any parsing errors (NaT values)
print("\nNumber of invalid DateTime entries:")
print(df_surprise['DateTime'].isna().sum())
# Out:
# First 5 rows of DateTime column:
# 153   1997-06-25 07:30:00
# 198   1997-08-01 07:30:00
# 394   1997-12-23 07:30:00
# 523   1998-03-26 07:30:00
# 569   1998-04-30 07:30:00
# Name: DateTime, dtype: datetime64[ns]
#
# Number of invalid DateTime entries:
# 464
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1303372904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Date'] = df_surprise['Date'].astype(str)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1303372904.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].astype(str)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1303372904.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1303372904.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['DateTime'] = pd.to_datetime(

# %%
# Strangely we get NaN values for DateTime so we next look into why that is
df_surprise.isna().sum()
# Out:
# Unnamed: 0            0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            8690
# Freq.                 0
# First Rev.         8690
# Last Rev.          4186
# Date                  0
# Time                  0
# C                     0
# Category              0
# Subcategory       23169
# R                     0
# Day                   0
# Surv(M)               0
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# DateTime            464
# dtype: int64

# %%
# To do so we print the rows for which DateTime was NaN and we see the Date variable is weirdly formatted
nan_rows = df_surprise[df_surprise['DateTime'].isna()]
nan_rows[['Date','Time']]
# Out:
#            Date      Time
# 1583  01/03/000  09:00:00
# 1585  01/04/000  09:00:00
# 1587  01/05/000  09:00:00
# 1588  01/05/000  09:00:00
# 1590  01/06/000  07:30:00
# ...         ...       ...
# 2245  12/22/000  09:00:00
# 2248  12/28/000  07:30:00
# 2249  12/28/000  09:00:00
# 2250  12/28/000  09:00:00
# 2251  12/29/000  09:00:00
#
# [464 rows x 2 columns]

# %%
# The first column is also a Date column and looks more appropriate from the output below so let's use that instead to create our DateTime variable
nan_rows[['Date','Unnamed: 0']]
# Out:
#            Date  Unnamed: 0
# 1583  01/03/000  2000-01-03
# 1585  01/04/000  2000-01-04
# 1587  01/05/000  2000-01-05
# 1588  01/05/000  2000-01-05
# 1590  01/06/000  2000-01-06
# ...         ...         ...
# 2245  12/22/000  2000-12-22
# 2248  12/28/000  2000-12-28
# 2249  12/28/000  2000-12-28
# 2250  12/28/000  2000-12-28
# 2251  12/29/000  2000-12-29
#
# [464 rows x 2 columns]

# %%
# First we drop Date and DateTime and change the column name for Unnamed: 0 to Date

df_surprise.drop(columns=['Date', 'DateTime'], inplace=True)
df_surprise.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
df_surprise.columns
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1316665770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise.drop(columns=['Date', 'DateTime'], inplace=True)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1316665770.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
# Index(['Date', 'Period', 'Event', 'Ticker', 'Actual', 'Prior', 'Revised',
#        'Freq.', 'First Rev.', 'Last Rev.', 'Time', 'C', 'Category',
#        'Subcategory', 'R', 'Day', 'Surv(M)', '# Ests.', 'Std Dev', 'Surprise',
#        'Country/Region', 'Flag'],
#       dtype='object')

# %%
# Now let's again create a DateTime column with the new Date column and check for number of NaN values
# Step 1: Ensure columns are strings
df_surprise['Date'] = df_surprise['Date'].astype(str)
df_surprise['Time'] = df_surprise['Time'].astype(str)

# Step 2: Handle missing times (if any)
df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')

# Step 3: Combine Date and Time into DateTime
df_surprise['DateTime'] = pd.to_datetime(
    df_surprise['Date'].str[:10] + ' ' + df_surprise['Time'],
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'  # Converts invalid parsing to NaT instead of raising error
)

df_surprise.isna().sum()

# Our new variable has no NaN values and is thus appropriate for the next part of our analysis
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\2809420286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Date'] = df_surprise['Date'].astype(str)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\2809420286.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].astype(str)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\2809420286.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['Time'] = df_surprise['Time'].fillna('00:00:00')
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\2809420286.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_surprise['DateTime'] = pd.to_datetime(
# Date                  0
# Period                0
# Event                 0
# Ticker                0
# Actual                0
# Prior                19
# Revised            8690
# Freq.                 0
# First Rev.         8690
# Last Rev.          4186
# Time                  0
# C                     0
# Category              0
# Subcategory       23169
# R                     0
# Day                   0
# Surv(M)               0
# # Ests.               0
# Std Dev               0
# Surprise              0
# Country/Region        0
# Flag                  0
# DateTime              0
# dtype: int64

# %%
df_surprise
# Out:
#              Date               Period                               Event  \
# 153    1997-06-25                 1Q F                  GDP Annualized QoQ
# 198    1997-08-01                  Jul          Change in Nonfarm Payrolls
# 394    1997-12-23                 3Q F                  GDP Annualized QoQ
# 523    1998-03-26                 4Q F                  GDP Annualized QoQ
# 569    1998-04-30                 1Q A                  GDP Annualized QoQ
# ...           ...                  ...                                 ...
# 35992  2024-12-18                Nov P                    Building Permits
# 35993  2024-12-18                Nov P                Building Permits MoM
# 35994  2024-12-18                   3Q             Current Account Balance
# 35999  2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: Next Yr
# 36000  2024-12-18  2024-12-18 00:00:00   FOMC Median Rate Forecast: +2 Yrs
#
#                Ticker    Actual     Prior   Revised Freq. First Rev.  \
# 153    GDP CQOQ Index     0.059     0.058      <NA>     Q       <NA>
# 198     NFP TCH Index      316k      217k      228k     M       228k
# 394    GDP CQOQ Index     0.031     0.033      <NA>     Q       <NA>
# 523    GDP CQOQ Index     0.037     0.039      <NA>     Q       <NA>
# 569    GDP CQOQ Index     0.042     0.037      <NA>     Q       <NA>
# ...               ...       ...       ...       ...   ...        ...
# 35992  NHSPATOT Index     1505k     1416k     1419k     M      1419k
# 35993  NHCHATCH Index     0.061    -0.006    -0.004     M     -0.004
# 35994   USCABAL Index  -$310.9b  -$266.8b  -$275.0b     Q   -$275.0b
# 35999  DOTDY1MD Index   0.03875   0.03375      <NA>     D       <NA>
# 36000  DOTDY2MD Index   0.03375   0.02875      <NA>     D       <NA>
#
#       Last Rev.  ... Subcategory          R  Day   Surv(M)  # Ests. Std Dev  \
# 153        <NA>  ...         NaN  96.296300  Wed     0.058     13.0    0.22
# 198        265k  ...         NaN  99.259300  Fri       70k     20.0   33.84
# 394       0.051  ...         NaN  96.296300  Tue     0.033     11.0    0.07
# 523        <NA>  ...         NaN  96.296300  Thu     0.039     22.0    0.08
# 569        <NA>  ...         NaN  96.296300  Thu     0.034     19.0    0.36
# ...         ...  ...         ...        ...  ...       ...      ...     ...
# 35992     1419k  ...         NaN  61.185200  Wed     1430k     46.0   22.21
# 35993    -0.004  ...         NaN  31.851900  Wed      0.01     46.0    1.78
# 35994  -$275.0b  ...         NaN  71.111100  Wed  -$287.1b     18.0    6.22
# 35999      <NA>  ...         NaN   2.222220  Wed   0.03625     12.0    0.12
# 36000      <NA>  ...         NaN   0.740741  Wed   0.03125     11.0    0.11
#
#       Surprise  Country/Region           Flag            DateTime
# 153       0.45   United States  United States 1997-06-25 07:30:00
# 198       7.27   United States  United States 1997-08-01 07:30:00
# 394      -2.98   United States  United States 1997-12-23 07:30:00
# 523      -2.52   United States  United States 1998-03-26 07:30:00
# 569       2.22   United States  United States 1998-04-30 07:30:00
# ...        ...             ...            ...                 ...
# 35992     3.38   United States  United States 2024-12-18 07:30:00
# 35993     2.87   United States  United States 2024-12-18 07:30:00
# 35994    -3.84   United States  United States 2024-12-18 07:30:00
# 35999     2.03   United States  United States 2024-12-18 13:00:00
# 36000     2.35   United States  United States 2024-12-18 13:00:00
#
# [23169 rows x 23 columns]

# %%
# Now let's do the same for df_es

df_es
# Out:
#                Date   Time     Open    Close  Volume
# 0        09/10/1997  00:01     0.00     0.00       0
# 1        09/10/1997  00:02     0.00     0.00       0
# 2        09/10/1997  00:03     0.00     0.00       0
# 3        09/10/1997  00:04     0.00     0.00       0
# 4        09/10/1997  00:05     0.00     0.00       0
# ...             ...    ...      ...      ...     ...
# 9682630  12/19/2024  15:56  5941.75  5941.75     318
# 9682631  12/19/2024  15:57  5941.75  5941.50     386
# 9682632  12/19/2024  15:58  5941.50  5941.00     484
# 9682633  12/19/2024  15:59  5940.75  5941.00    6462
# 9682634  12/19/2024  16:00  5941.00  5941.25    8864
#
# [9682635 rows x 5 columns]

# %%
df_es.isna().sum()
# Out:
# Date      0
# Time      0
# Open      0
# Close     0
# Volume    0
# dtype: int64

# %%
# Step 1: Ensure columns are strings
df_es['Date'] = df_es['Date'].astype(str)
df_es['Time'] = df_es['Time'].astype(str)

# Step 2: Handle missing times (if any) and pad with seconds
df_es['Time'] = df_es['Time'].fillna('00:00')  # Fill missing times
df_es['Time'] = df_es['Time'] + ':00'  # Add seconds to make HH:MM:SS format

# Step 3: Combine Date and Time into DateTime with correct format
df_es['DateTime'] = pd.to_datetime(
    df_es['Date'] + ' ' + df_es['Time'],
    format='%m/%d/%Y %H:%M:%S',  # Matches MM/DD/YYYY date and HH:MM:SS time
    errors='coerce'
)

# Count NaN values in each column
print(df_es.isna().sum())
# Out:
# Date        0
# Time        0
# Open        0
# Close       0
# Volume      0
# DateTime    0
# dtype: int64

# %%
df_es
# Out:
#                Date      Time     Open    Close  Volume            DateTime
# 0        09/10/1997  00:01:00     0.00     0.00       0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00     0.00     0.00       0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00     0.00     0.00       0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00     0.00     0.00       0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00     0.00     0.00       0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9682630  12/19/2024  15:56:00  5941.75  5941.75     318 2024-12-19 15:56:00
# 9682631  12/19/2024  15:57:00  5941.75  5941.50     386 2024-12-19 15:57:00
# 9682632  12/19/2024  15:58:00  5941.50  5941.00     484 2024-12-19 15:58:00
# 9682633  12/19/2024  15:59:00  5940.75  5941.00    6462 2024-12-19 15:59:00
# 9682634  12/19/2024  16:00:00  5941.00  5941.25    8864 2024-12-19 16:00:00
#
# [9682635 rows x 6 columns]

# %%
# Now we create the merged dataframe for our analysis - to allow us to match times of surprise with the price of the future at the time
df_combined = pd.merge(
    df_es,
    df_surprise,
    on='DateTime',
    how='outer',
    suffixes=('_es', '_surprise'),
    indicator=True  # this shows the source of each using suffix
)

df_combined
# Out:
#             Date_es   Time_es  Open  Close  Volume            DateTime  \
# 0        09/10/1997  00:01:00   0.0    0.0     0.0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00   0.0    0.0     0.0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00   0.0    0.0     0.0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00   0.0    0.0     0.0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00   0.0    0.0     0.0 1997-09-10 00:05:00
# ...             ...       ...   ...    ...     ...                 ...
# 9695761         NaN       NaN   NaN    NaN     NaN 2024-03-29 07:30:00
# 9695762         NaN       NaN   NaN    NaN     NaN 2024-03-29 07:30:00
# 9695763         NaN       NaN   NaN    NaN     NaN 2024-03-29 07:30:00
# 9695764         NaN       NaN   NaN    NaN     NaN 2024-03-29 07:30:00
# 9695765         NaN       NaN   NaN    NaN     NaN 2024-03-29 07:30:00
#
#         Date_surprise Period                        Event          Ticker  \
# 0                 NaN    NaN                          NaN             NaN
# 1                 NaN    NaN                          NaN             NaN
# 2                 NaN    NaN                          NaN             NaN
# 3                 NaN    NaN                          NaN             NaN
# 4                 NaN    NaN                          NaN             NaN
# ...               ...    ...                          ...             ...
# 9695761    2024-03-29    Feb              Personal Income  PITLCHNG Index
# 9695762    2024-03-29    Feb          PCE Price Index MoM  PCE DEFM Index
# 9695763    2024-03-29    Feb  Advance Goods Trade Balance  USTGTTCB Index
# 9695764    2024-03-29    Feb       Retail Inventories MoM  RSRSTMOM Index
# 9695765    2024-03-29  Feb P    Wholesale Inventories MoM  MWINCHNG Index
#
#          ... Subcategory        R  Day  Surv(M) # Ests. Std Dev Surprise  \
# 0        ...         NaN      NaN  NaN      NaN     NaN     NaN      NaN
# 1        ...         NaN      NaN  NaN      NaN     NaN     NaN      NaN
# 2        ...         NaN      NaN  NaN      NaN     NaN     NaN      NaN
# 3        ...         NaN      NaN  NaN      NaN     NaN     NaN      NaN
# 4        ...         NaN      NaN  NaN      NaN     NaN     NaN      NaN
# ...      ...         ...      ...  ...      ...     ...     ...      ...
# 9695761  ...         NaN  85.9259  Fri    0.004    58.0    0.13    -0.74
# 9695762  ...         NaN  38.5185  Fri    0.004    47.0    0.04    -2.24
# 9695763  ...         NaN  14.0741  Fri  -$90.0b    34.0    1.63    -1.10
# 9695764  ...         NaN  12.5926  Fri    0.004     6.0    0.16     0.92
# 9695765  ...         NaN  80.0000  Fri    0.002     9.0    0.09     3.43
#
#         Country/Region           Flag      _merge
# 0                  NaN            NaN   left_only
# 1                  NaN            NaN   left_only
# 2                  NaN            NaN   left_only
# 3                  NaN            NaN   left_only
# 4                  NaN            NaN   left_only
# ...                ...            ...         ...
# 9695761  United States  United States  right_only
# 9695762  United States  United States  right_only
# 9695763  United States  United States  right_only
# 9695764  United States  United States  right_only
# 9695765  United States  United States  right_only
#
# [9695766 rows x 29 columns]

# %%
df_combined.isna().sum()
# Out:
# Date_es               101
# Time_es               101
# Open                  101
# Close                 101
# Volume                101
# DateTime                0
# Date_surprise     9672597
# Period            9672597
# Event             9672597
# Ticker            9672597
# Actual            9672597
# Prior             9672616
# Revised           9681287
# Freq.             9672597
# First Rev.        9681287
# Last Rev.         9676783
# Time_surprise     9672597
# C                 9672597
# Category          9672597
# Subcategory       9695766
# R                 9672597
# Day               9672597
# Surv(M)           9672597
# # Ests.           9672597
# Std Dev           9672597
# Surprise          9672597
# Country/Region    9672597
# Flag              9672597
# _merge                  0
# dtype: int64

# %%
# Some surprise announcements might have come before the starting point for the data on the futures, these would be meaningless for our analysis and should thus
# be removed by removing all rows with NaN values for Open

df_combined.dropna(subset=['Open'], inplace=True)

df_combined.isna().sum()
# Out:
# Date_es                 0
# Time_es                 0
# Open                    0
# Close                   0
# Volume                  0
# DateTime                0
# Date_surprise     9672597
# Period            9672597
# Event             9672597
# Ticker            9672597
# Actual            9672597
# Prior             9672616
# Revised           9681231
# Freq.             9672597
# First Rev.        9681231
# Last Rev.         9676757
# Time_surprise     9672597
# C                 9672597
# Category          9672597
# Subcategory       9695665
# R                 9672597
# Day               9672597
# Surv(M)           9672597
# # Ests.           9672597
# Std Dev           9672597
# Surprise          9672597
# Country/Region    9672597
# Flag              9672597
# _merge                  0
# dtype: int64

# %%
# Upon analysing our combined dataframe again we now see that it all looks good

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 0        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695660  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695661  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695662  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695663  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695664  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ... Subcategory   R  Day Surv(M)  \
# 0                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 1                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 2                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 3                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 4                 NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# ...               ...    ...   ...    ...  ...         ...  ..  ...     ...
# 9695660           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695661           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695662           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695663           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
# 9695664           NaN    NaN   NaN    NaN  ...         NaN NaN  NaN     NaN
#
#         # Ests. Std Dev Surprise Country/Region Flag     _merge
# 0           NaN     NaN      NaN            NaN  NaN  left_only
# 1           NaN     NaN      NaN            NaN  NaN  left_only
# 2           NaN     NaN      NaN            NaN  NaN  left_only
# 3           NaN     NaN      NaN            NaN  NaN  left_only
# 4           NaN     NaN      NaN            NaN  NaN  left_only
# ...         ...     ...      ...            ...  ...        ...
# 9695660     NaN     NaN      NaN            NaN  NaN  left_only
# 9695661     NaN     NaN      NaN            NaN  NaN  left_only
# 9695662     NaN     NaN      NaN            NaN  NaN  left_only
# 9695663     NaN     NaN      NaN            NaN  NaN  left_only
# 9695664     NaN     NaN      NaN            NaN  NaN  left_only
#
# [9695665 rows x 29 columns]

# %% [markdown]
# # **Creating a naive benchmark strategy that trades whenever a surprise occurs - comparing this with our more sophisticated strategies should show the importance of only trading on surprises in significant determinants of asset returns**

# %%
# First we create an indicator variable with a value True if the column for Surprise is non-missing for that row

df_combined['Surprise Occurred'] = df_combined['Surprise'].notna()

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 0        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695660  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695661  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695662  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695663  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695664  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ...   R  Day Surv(M) # Ests.  \
# 0                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 1                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 2                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 3                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 4                 NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# ...               ...    ...   ...    ...  ...  ..  ...     ...     ...
# 9695660           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695661           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695662           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695663           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
# 9695664           NaN    NaN   NaN    NaN  ... NaN  NaN     NaN     NaN
#
#         Std Dev Surprise Country/Region Flag     _merge  Surprise Occurred
# 0           NaN      NaN            NaN  NaN  left_only              False
# 1           NaN      NaN            NaN  NaN  left_only              False
# 2           NaN      NaN            NaN  NaN  left_only              False
# 3           NaN      NaN            NaN  NaN  left_only              False
# 4           NaN      NaN            NaN  NaN  left_only              False
# ...         ...      ...            ...  ...        ...                ...
# 9695660     NaN      NaN            NaN  NaN  left_only              False
# 9695661     NaN      NaN            NaN  NaN  left_only              False
# 9695662     NaN      NaN            NaN  NaN  left_only              False
# 9695663     NaN      NaN            NaN  NaN  left_only              False
# 9695664     NaN      NaN            NaN  NaN  left_only              False
#
# [9695665 rows x 30 columns]

# %%
df_combined.isna().sum()
# Out:
# Date_es                    0
# Time_es                    0
# Open                       0
# Close                      0
# Volume                     0
# DateTime                   0
# Date_surprise        9672597
# Period               9672597
# Event                9672597
# Ticker               9672597
# Actual               9672597
# Prior                9672616
# Revised              9681231
# Freq.                9672597
# First Rev.           9681231
# Last Rev.            9676757
# Time_surprise        9672597
# C                    9672597
# Category             9672597
# Subcategory          9695665
# R                    9672597
# Day                  9672597
# Surv(M)              9672597
# # Ests.              9672597
# Std Dev              9672597
# Surprise             9672597
# Country/Region       9672597
# Flag                 9672597
# _merge                     0
# Surprise Occurred          0
# dtype: int64

# %%
# count the number of times the Surprise Occurred variable is True and False
df_combined['Surprise Occurred'].value_counts()
# Out:
# Surprise Occurred
# False    9672597
# True       23068
# Name: count, dtype: int64

# %%
# Same number of False values for the new surprise variables as original surprise variable
# so the new variables were correctly created
df_combined[df_combined['Surprise Occurred'] == False].count()
# Out:
# Date_es              9672597
# Time_es              9672597
# Open                 9672597
# Close                9672597
# Volume               9672597
# DateTime             9672597
# Date_surprise              0
# Period                     0
# Event                      0
# Ticker                     0
# Actual                     0
# Prior                      0
# Revised                    0
# Freq.                      0
# First Rev.                 0
# Last Rev.                  0
# Time_surprise              0
# C                          0
# Category                   0
# Subcategory                0
# R                          0
# Day                        0
# Surv(M)                    0
# # Ests.                    0
# Std Dev                    0
# Surprise                   0
# Country/Region             0
# Flag                       0
# _merge               9672597
# Surprise Occurred    9672597
# dtype: int64

# %%
# Lets now create a new indicator called First Post Surprise which takes a value or true for being the first minute level observation after a surprise occurs
# i.e. right after the Surprise Occurred variable take a value of True this should take a value of True



df_combined['First Post Surprise'] = df_combined['Surprise Occurred'].shift(1)
df_combined['First Post Surprise'].iloc[0] = False

df_combined
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1750306210.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined['First Post Surprise'].iloc[0] = False
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 0        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695660  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695661  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695662  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695663  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695664  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ...  Day Surv(M) # Ests. Std Dev  \
# 0                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 1                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 2                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 3                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 4                 NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# ...               ...    ...   ...    ...  ...  ...     ...     ...     ...
# 9695660           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695661           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695662           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695663           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
# 9695664           NaN    NaN   NaN    NaN  ...  NaN     NaN     NaN     NaN
#
#         Surprise Country/Region Flag     _merge Surprise Occurred  \
# 0            NaN            NaN  NaN  left_only             False
# 1            NaN            NaN  NaN  left_only             False
# 2            NaN            NaN  NaN  left_only             False
# 3            NaN            NaN  NaN  left_only             False
# 4            NaN            NaN  NaN  left_only             False
# ...          ...            ...  ...        ...               ...
# 9695660      NaN            NaN  NaN  left_only             False
# 9695661      NaN            NaN  NaN  left_only             False
# 9695662      NaN            NaN  NaN  left_only             False
# 9695663      NaN            NaN  NaN  left_only             False
# 9695664      NaN            NaN  NaN  left_only             False
#
#          First Post Surprise
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 9695660                False
# 9695661                False
# 9695662                False
# 9695663                False
# 9695664                False
#
# [9695665 rows x 31 columns]

# %%
# print df combined where columsn surprise occurred and first post surprise are true, 1 of them true is enough to show row
df_combined[(df_combined['Surprise Occurred'] == True) | (df_combined['First Post Surprise'] == True)]
# Out:
#             Date_es   Time_es     Open    Close   Volume            DateTime  \
# 102674   12/23/1997  07:30:00  1189.71  1189.71      0.0 1997-12-23 07:30:00
# 102675   12/23/1997  07:31:00  1189.40  1189.09      0.0 1997-12-23 07:31:00
# 191129   03/26/1998  07:30:00  1355.65  1355.96      0.0 1998-03-26 07:30:00
# 191130   03/26/1998  07:31:00  1355.96  1355.04      0.0 1998-03-26 07:31:00
# 224729   04/30/1998  07:30:00  1338.85  1338.85      0.0 1998-04-30 07:30:00
# ...             ...       ...      ...      ...      ...                 ...
# 9693773  12/18/2024  07:30:00  6145.50  6145.75    131.0 2024-12-18 07:30:00
# 9693774  12/18/2024  07:31:00  6145.50  6145.25    305.0 2024-12-18 07:31:00
# 9694103  12/18/2024  13:00:00  6135.75  6136.00    801.0 2024-12-18 13:00:00
# 9694104  12/18/2024  13:00:00  6135.75  6136.00    801.0 2024-12-18 13:00:00
# 9694105  12/18/2024  13:01:00  6136.25  6120.50  13401.0 2024-12-18 13:01:00
#
#         Date_surprise               Period  \
# 102674     1997-12-23                 3Q F
# 102675            NaN                  NaN
# 191129     1998-03-26                 4Q F
# 191130            NaN                  NaN
# 224729     1998-04-30                 1Q A
# ...               ...                  ...
# 9693773    2024-12-18                   3Q
# 9693774           NaN                  NaN
# 9694103    2024-12-18  2024-12-18 00:00:00
# 9694104    2024-12-18  2024-12-18 00:00:00
# 9694105           NaN                  NaN
#
#                                       Event          Ticker  ...  Day  \
# 102674                   GDP Annualized QoQ  GDP CQOQ Index  ...  Tue
# 102675                                  NaN             NaN  ...  NaN
# 191129                   GDP Annualized QoQ  GDP CQOQ Index  ...  Thu
# 191130                                  NaN             NaN  ...  NaN
# 224729                   GDP Annualized QoQ  GDP CQOQ Index  ...  Thu
# ...                                     ...             ...  ...  ...
# 9693773             Current Account Balance   USCABAL Index  ...  Wed
# 9693774                                 NaN             NaN  ...  NaN
# 9694103  FOMC Median Rate Forecast: Next Yr  DOTDY1MD Index  ...  Wed
# 9694104   FOMC Median Rate Forecast: +2 Yrs  DOTDY2MD Index  ...  Wed
# 9694105                                 NaN             NaN  ...  NaN
#
#           Surv(M) # Ests. Std Dev Surprise Country/Region           Flag  \
# 102674      0.033    11.0    0.07    -2.98  United States  United States
# 102675        NaN     NaN     NaN      NaN            NaN            NaN
# 191129      0.039    22.0    0.08    -2.52  United States  United States
# 191130        NaN     NaN     NaN      NaN            NaN            NaN
# 224729      0.034    19.0    0.36     2.22  United States  United States
# ...           ...     ...     ...      ...            ...            ...
# 9693773  -$287.1b    18.0    6.22    -3.84  United States  United States
# 9693774       NaN     NaN     NaN      NaN            NaN            NaN
# 9694103   0.03625    12.0    0.12     2.03  United States  United States
# 9694104   0.03125    11.0    0.11     2.35  United States  United States
# 9694105       NaN     NaN     NaN      NaN            NaN            NaN
#
#             _merge Surprise Occurred  First Post Surprise
# 102674        both              True                False
# 102675   left_only             False                 True
# 191129        both              True                False
# 191130   left_only             False                 True
# 224729        both              True                False
# ...            ...               ...                  ...
# 9693773       both              True                 True
# 9693774  left_only             False                 True
# 9694103       both              True                False
# 9694104       both              True                 True
# 9694105  left_only             False                 True
#
# [33096 rows x 31 columns]

# %% [markdown]
# **Defining key hyperparameter of holding period (based on literature but also varied up and down slightly)**

# %%
holding_period = 20

# %%
df_combined[df_combined['First Post Surprise'] == True]
# Out:
#             Date_es   Time_es     Open    Close   Volume            DateTime  \
# 102675   12/23/1997  07:31:00  1189.40  1189.09      0.0 1997-12-23 07:31:00
# 191130   03/26/1998  07:31:00  1355.96  1355.04      0.0 1998-03-26 07:31:00
# 224730   04/30/1998  07:31:00  1339.15  1345.26      0.0 1998-04-30 07:31:00
# 254265   06/01/1998  09:01:00  1334.87  1335.18      0.0 1998-06-01 09:01:00
# 255690   06/02/1998  09:00:00  1343.12  1342.51      0.0 1998-06-02 09:00:00
# ...             ...       ...      ...      ...      ...                 ...
# 9693772  12/18/2024  07:30:00  6145.50  6145.75    131.0 2024-12-18 07:30:00
# 9693773  12/18/2024  07:30:00  6145.50  6145.75    131.0 2024-12-18 07:30:00
# 9693774  12/18/2024  07:31:00  6145.50  6145.25    305.0 2024-12-18 07:31:00
# 9694104  12/18/2024  13:00:00  6135.75  6136.00    801.0 2024-12-18 13:00:00
# 9694105  12/18/2024  13:01:00  6136.25  6120.50  13401.0 2024-12-18 13:01:00
#
#         Date_surprise               Period                              Event  \
# 102675            NaN                  NaN                                NaN
# 191130            NaN                  NaN                                NaN
# 224730            NaN                  NaN                                NaN
# 254265            NaN                  NaN                                NaN
# 255690     1998-06-02                  Apr                      Leading Index
# ...               ...                  ...                                ...
# 9693772    2024-12-18                Nov P               Building Permits MoM
# 9693773    2024-12-18                   3Q            Current Account Balance
# 9693774           NaN                  NaN                                NaN
# 9694104    2024-12-18  2024-12-18 00:00:00  FOMC Median Rate Forecast: +2 Yrs
# 9694105           NaN                  NaN                                NaN
#
#                  Ticker  ...  Day   Surv(M) # Ests. Std Dev Surprise  \
# 102675              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 191130              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 224730              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 254265              NaN  ...  NaN       NaN     NaN     NaN      NaN
# 255690   LEI CHNG Index  ...  Tue    -0.002     6.0    0.21     1.41
# ...                 ...  ...  ...       ...     ...     ...      ...
# 9693772  NHCHATCH Index  ...  Wed      0.01    46.0    1.78     2.87
# 9693773   USCABAL Index  ...  Wed  -$287.1b    18.0    6.22    -3.84
# 9693774             NaN  ...  NaN       NaN     NaN     NaN      NaN
# 9694104  DOTDY2MD Index  ...  Wed   0.03125    11.0    0.11     2.35
# 9694105             NaN  ...  NaN       NaN     NaN     NaN      NaN
#
#         Country/Region           Flag     _merge Surprise Occurred  \
# 102675             NaN            NaN  left_only             False
# 191130             NaN            NaN  left_only             False
# 224730             NaN            NaN  left_only             False
# 254265             NaN            NaN  left_only             False
# 255690   United States  United States       both              True
# ...                ...            ...        ...               ...
# 9693772  United States  United States       both              True
# 9693773  United States  United States       both              True
# 9693774            NaN            NaN  left_only             False
# 9694104  United States  United States       both              True
# 9694105            NaN            NaN  left_only             False
#
#          First Post Surprise
# 102675                  True
# 191130                  True
# 224730                  True
# 254265                  True
# 255690                  True
# ...                      ...
# 9693772                 True
# 9693773                 True
# 9693774                 True
# 9694104                 True
# 9694105                 True
#
# [23068 rows x 31 columns]

# %%
# As can be seen there as instances where we have multiple returns on the same day but this
# is not an issue - we take positions independent of other surprises in all 3 models i.e.
# a position that is held due to one suprise is not impacted by a different variable's surprise

df_combined.iloc[255689:255691, 8:29]
# Out:
#                  Event          Ticker Actual  Prior Revised Freq. First Rev.  \
# 255689  New Home Sales   NHSLTOT Index   888k   828k    844k     M       844k
# 255690   Leading Index  LEI CHNG Index  0.001  0.002    <NA>     M       <NA>
#
#        Last Rev. Time_surprise   C  ... Subcategory        R  Day Surv(M)  \
# 255689      836k      09:00:00  US  ...         NaN  88.1481  Tue    840k
# 255690     0.001      09:00:00  US  ...         NaN  82.2222  Tue  -0.002
#
#        # Ests.  Std Dev Surprise  Country/Region           Flag _merge
# 255689    14.0    13.02     3.69   United States  United States   both
# 255690     6.0     0.21     1.41   United States  United States   both
#
# [2 rows x 21 columns]

# %%
"""
 Now we create general returns for our 3 variants of holding periods (to be optimized on
 validation set for statistical and ML models) and returns for our naive model which goes
 long when there's a positive surprise and short when there's a negative surprise (the returns
 with a prefix of N_)
"""

df_combined['N_Return'] = np.nan
df_combined['N_Return_half'] = np.nan
df_combined['N_Return_double'] = np.nan
df_combined['Return'] = np.nan
df_combined['Return_half'] = np.nan
df_combined['Return_double'] = np.nan

surprise_rows = df_combined[df_combined['First Post Surprise'] == True]

for index, row in surprise_rows.iterrows():
    row_position = df_combined.index.get_loc(index)

    # Get the Surprise value from the previous row
    if index > df_combined.index[0]:
        prev_surprise = df_combined.at[df_combined.index[df_combined.index.get_loc(index)-1], 'Surprise']
    else:
        prev_surprise = 0  # Default if no previous row exists

    if row_position + holding_period < len(df_combined):
        current_price = row['Open']
        future_row = df_combined.iloc[row_position + holding_period]
        future_price = future_row['Open']

        if current_price != 0:
            percentage_increase = (future_price - current_price) / current_price
        else:
            percentage_increase = np.nan

        df_combined.at[index, 'Return'] = percentage_increase
        if prev_surprise < 0:
            df_combined.at[index, 'N_Return'] = -percentage_increase
        else:
            df_combined.at[index, 'N_Return'] = percentage_increase

    if row_position + int(holding_period*0.5) < len(df_combined): # int converts to whole number to avoid that potential error
        current_price = row['Open']
        future_row = df_combined.iloc[row_position + int(holding_period*0.5)]
        future_price = future_row['Open']

        if current_price != 0:
            percentage_increase = (future_price - current_price) / current_price
        else:
            percentage_increase = np.nan

        df_combined.at[index, 'Return_half'] = percentage_increase
        if prev_surprise < 0:
            df_combined.at[index, 'N_Return_half'] = -percentage_increase
        else:
            df_combined.at[index, 'N_Return_half'] = percentage_increase

    if row_position + int(holding_period*2) < len(df_combined):
        current_price = row['Open']
        future_row = df_combined.iloc[row_position + int(holding_period*2)]
        future_price = future_row['Open']

        if current_price != 0:
            percentage_increase = (future_price - current_price) / current_price
        else:
            percentage_increase = np.nan

        df_combined.at[index, 'Return_double'] = percentage_increase
        if prev_surprise < 0:
            df_combined.at[index, 'N_Return_double'] = -percentage_increase
        else:
            df_combined.at[index, 'N_Return_double'] = percentage_increase

df_combined
# Out:
#             Date_es   Time_es     Open    Close  Volume            DateTime  \
# 0        09/10/1997  00:01:00     0.00     0.00     0.0 1997-09-10 00:01:00
# 1        09/10/1997  00:02:00     0.00     0.00     0.0 1997-09-10 00:02:00
# 2        09/10/1997  00:03:00     0.00     0.00     0.0 1997-09-10 00:03:00
# 3        09/10/1997  00:04:00     0.00     0.00     0.0 1997-09-10 00:04:00
# 4        09/10/1997  00:05:00     0.00     0.00     0.0 1997-09-10 00:05:00
# ...             ...       ...      ...      ...     ...                 ...
# 9695660  12/19/2024  15:56:00  5941.75  5941.75   318.0 2024-12-19 15:56:00
# 9695661  12/19/2024  15:57:00  5941.75  5941.50   386.0 2024-12-19 15:57:00
# 9695662  12/19/2024  15:58:00  5941.50  5941.00   484.0 2024-12-19 15:58:00
# 9695663  12/19/2024  15:59:00  5940.75  5941.00  6462.0 2024-12-19 15:59:00
# 9695664  12/19/2024  16:00:00  5941.00  5941.25  8864.0 2024-12-19 16:00:00
#
#         Date_surprise Period Event Ticker  ... Flag     _merge  \
# 0                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 1                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 2                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 3                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# 4                 NaN    NaN   NaN    NaN  ...  NaN  left_only
# ...               ...    ...   ...    ...  ...  ...        ...
# 9695660           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695661           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695662           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695663           NaN    NaN   NaN    NaN  ...  NaN  left_only
# 9695664           NaN    NaN   NaN    NaN  ...  NaN  left_only
#
#         Surprise Occurred First Post Surprise N_Return N_Return_half  \
# 0                   False               False      NaN           NaN
# 1                   False               False      NaN           NaN
# 2                   False               False      NaN           NaN
# 3                   False               False      NaN           NaN
# 4                   False               False      NaN           NaN
# ...                   ...                 ...      ...           ...
# 9695660             False               False      NaN           NaN
# 9695661             False               False      NaN           NaN
# 9695662             False               False      NaN           NaN
# 9695663             False               False      NaN           NaN
# 9695664             False               False      NaN           NaN
#
#         N_Return_double Return Return_half  Return_double
# 0                   NaN    NaN         NaN            NaN
# 1                   NaN    NaN         NaN            NaN
# 2                   NaN    NaN         NaN            NaN
# 3                   NaN    NaN         NaN            NaN
# 4                   NaN    NaN         NaN            NaN
# ...                 ...    ...         ...            ...
# 9695660             NaN    NaN         NaN            NaN
# 9695661             NaN    NaN         NaN            NaN
# 9695662             NaN    NaN         NaN            NaN
# 9695663             NaN    NaN         NaN            NaN
# 9695664             NaN    NaN         NaN            NaN
#
# [9695665 rows x 37 columns]

# %%
zero_count = (df_combined['Surprise'] == 0).sum()

print(zero_count)
# Out:
# 0

# %%
# The number of NaN values for this new column make sense - same as the number of NaNs for the Surprise column
df_combined.isna().sum()
# Out:
# Date_es                      0
# Time_es                      0
# Open                         0
# Close                        0
# Volume                       0
# DateTime                     0
# Date_surprise          9672597
# Period                 9672597
# Event                  9672597
# Ticker                 9672597
# Actual                 9672597
# Prior                  9672616
# Revised                9681231
# Freq.                  9672597
# First Rev.             9681231
# Last Rev.              9676757
# Time_surprise          9672597
# C                      9672597
# Category               9672597
# Subcategory            9695665
# R                      9672597
# Day                    9672597
# Surv(M)                9672597
# # Ests.                9672597
# Std Dev                9672597
# Surprise               9672597
# Country/Region         9672597
# Flag                   9672597
# _merge                       0
# Surprise Occurred            0
# First Post Surprise          0
# N_Return               9672597
# N_Return_half          9672597
# N_Return_double        9672597
# Return                 9672597
# Return_half            9672597
# Return_double          9672597
# dtype: int64

# %% [markdown]
# **Now we get Returns & Standard Deviation**

# %%
# Just checking how long futures market is typically open for (some surprises on same day might bias this value a bit but not by muchh)
date_counts = df_combined['DateTime'].dt.floor('D').value_counts()

# Calculate statistics
avg_minutes_per_day = date_counts.mean()
avg_holding_period_intervals = avg_minutes_per_day / holding_period

print(f"Average market open minutes per day: {avg_minutes_per_day:.1f}")
print(f"Average holding-period intervals per day: {holding_period:.1f}")
# Out:
# Average market open minutes per day: 1147.8
# Average holding-period intervals per day: 20.0

# %%
average_return = df_combined['Return'].dropna().mean()
print(average_return)
# Out:
# 3.253384860842976e-06

# %%
train_end = int(0.3 * len(df_combined))
validation_end = int(0.5 * len(df_combined))
print(train_end)
print(validation_end)
# Out:
# 2908699
# 4847832

# %%
"""Computing average annual returns for all of the years in the dataframe using the naive strategy as follows:
   Validation set used to determine which of the 3 holding periods performed best and then the following year is used as the test set with that specific holding period and then
   this process is repeated
"""

# Group by year and compute compounded returns
annual_returns = {}
for year, group in df_combined[df_combined['Return'].notna()].groupby(df_combined['DateTime'].dt.year):
    compounded_return = (1 + group['Return']).prod() - 1
    annual_returns[year] = compounded_return

# Convert to percentage and display
annual_returns_pct = {year: f"{ret*100:.2f}%" for year, ret in annual_returns.items()}
print("Annual Compounded Returns:")
print(annual_returns_pct)
# Out:
# Annual Compounded Returns:
# {1997: '0.03%', 1998: '-3.79%', 1999: '23.17%', 2000: '12.73%', 2001: '-23.17%', 2002: '-11.97%', 2003: '-3.47%', 2004: '-6.25%', 2005: '12.02%', 2006: '4.17%', 2007: '23.11%', 2008: '12.10%', 2009: '-15.67%', 2010: '-4.45%', 2011: '-3.59%', 2012: '-18.80%', 2013: '6.40%', 2014: '2.24%', 2015: '-18.95%', 2016: '-5.29%', 2017: '9.22%', 2018: '-6.42%', 2019: '-2.83%', 2020: '75.86%', 2021: '28.83%', 2022: '-51.30%', 2023: '17.57%', 2024: '8.81%'}

# %%
# This strategy: 1) Uses validation period to pick best return horizon (half/normal/double),
# 2) Tests it on next 252 days, 3) Rolls forward annually, keeping window sizes constant


train_end = int(0.3 * len(df_combined))
validation_end = int(0.5 * len(df_combined))
test_days = 252
return_cols = ['N_Return_half', 'N_Return', 'N_Return_double']
df_combined.index = pd.to_datetime(df_combined.index)
results = []
optimal_horizons = []

while validation_end + test_days <= len(df_combined):
    validation_df = df_combined.iloc[train_end:validation_end]

    cum_returns = {}
    for col in return_cols:
        returns = validation_df[col].dropna()
        cum_returns[col] = (1 + returns).prod() - 1

    optimal_col = max(cum_returns, key=cum_returns.get)
    optimal_horizons.append(optimal_col)

    test_start = validation_end
    test_end = min(validation_end + test_days, len(df_combined))
    test_df = df_combined.iloc[test_start:test_end]

    optimal_returns = test_df[optimal_col].dropna()
    compounded_return = (1 + optimal_returns).prod() - 1

    results.append({
        'train_start': df_combined.index[0],
        'train_end': df_combined.index[train_end],
        'validation_start': df_combined.index[train_end],
        'validation_end': df_combined.index[validation_end],
        'test_start': df_combined.index[test_start],
        'test_end': df_combined.index[test_end - 1],
        'optimal_horizon': optimal_col,
        'compounded_return': compounded_return
    })

    train_end += 252
    validation_end += 252

results_df = pd.DataFrame(results)
print(results_df)
print("\nOptimal horizons selected:", pd.Series(optimal_horizons).value_counts())
# Out:
#       train_start                     train_end              validation_start  \
# 0      1970-01-01 1970-01-01 00:00:00.002908699 1970-01-01 00:00:00.002908699
# 1      1970-01-01 1970-01-01 00:00:00.002908951 1970-01-01 00:00:00.002908951
# 2      1970-01-01 1970-01-01 00:00:00.002909203 1970-01-01 00:00:00.002909203
# 3      1970-01-01 1970-01-01 00:00:00.002909455 1970-01-01 00:00:00.002909455
# 4      1970-01-01 1970-01-01 00:00:00.002909707 1970-01-01 00:00:00.002909707
# ...           ...                           ...                           ...
# 19232  1970-01-01 1970-01-01 00:00:00.007755163 1970-01-01 00:00:00.007755163
# 19233  1970-01-01 1970-01-01 00:00:00.007755415 1970-01-01 00:00:00.007755415
# 19234  1970-01-01 1970-01-01 00:00:00.007755667 1970-01-01 00:00:00.007755667
# 19235  1970-01-01 1970-01-01 00:00:00.007755919 1970-01-01 00:00:00.007755919
# 19236  1970-01-01 1970-01-01 00:00:00.007756171 1970-01-01 00:00:00.007756171
#
#                      validation_end                    test_start  \
# 0     1970-01-01 00:00:00.004847832 1970-01-01 00:00:00.004847832
# 1     1970-01-01 00:00:00.004848084 1970-01-01 00:00:00.004848084
# 2     1970-01-01 00:00:00.004848336 1970-01-01 00:00:00.004848336
# 3     1970-01-01 00:00:00.004848588 1970-01-01 00:00:00.004848588
# 4     1970-01-01 00:00:00.004848840 1970-01-01 00:00:00.004848840
# ...                             ...                           ...
# 19232 1970-01-01 00:00:00.009694296 1970-01-01 00:00:00.009694296
# 19233 1970-01-01 00:00:00.009694548 1970-01-01 00:00:00.009694548
# 19234 1970-01-01 00:00:00.009694800 1970-01-01 00:00:00.009694800
# 19235 1970-01-01 00:00:00.009695052 1970-01-01 00:00:00.009695052
# 19236 1970-01-01 00:00:00.009695304 1970-01-01 00:00:00.009695304
#
#                            test_end optimal_horizon  compounded_return
# 0     1970-01-01 00:00:00.004848083   N_Return_half                0.0
# 1     1970-01-01 00:00:00.004848335   N_Return_half                0.0
# 2     1970-01-01 00:00:00.004848587   N_Return_half                0.0
# 3     1970-01-01 00:00:00.004848839   N_Return_half                0.0
# 4     1970-01-01 00:00:00.004849091   N_Return_half                0.0
# ...                             ...             ...                ...
# 19232 1970-01-01 00:00:00.009694547   N_Return_half                0.0
# 19233 1970-01-01 00:00:00.009694799   N_Return_half                0.0
# 19234 1970-01-01 00:00:00.009695051   N_Return_half                0.0
# 19235 1970-01-01 00:00:00.009695303   N_Return_half                0.0
# 19236 1970-01-01 00:00:00.009695555   N_Return_half                0.0
#
# [19237 rows x 8 columns]
#
# Optimal horizons selected: N_Return_half      11527
# N_Return_double     4880
# N_Return            2830
# Name: count, dtype: int64

# %%
results_df
# Out:
#       train_start                     train_end              validation_start  \
# 0      1970-01-01 1970-01-01 00:00:00.002908699 1970-01-01 00:00:00.002908699
# 1      1970-01-01 1970-01-01 00:00:00.002908951 1970-01-01 00:00:00.002908951
# 2      1970-01-01 1970-01-01 00:00:00.002909203 1970-01-01 00:00:00.002909203
# 3      1970-01-01 1970-01-01 00:00:00.002909455 1970-01-01 00:00:00.002909455
# 4      1970-01-01 1970-01-01 00:00:00.002909707 1970-01-01 00:00:00.002909707
# ...           ...                           ...                           ...
# 19232  1970-01-01 1970-01-01 00:00:00.007755163 1970-01-01 00:00:00.007755163
# 19233  1970-01-01 1970-01-01 00:00:00.007755415 1970-01-01 00:00:00.007755415
# 19234  1970-01-01 1970-01-01 00:00:00.007755667 1970-01-01 00:00:00.007755667
# 19235  1970-01-01 1970-01-01 00:00:00.007755919 1970-01-01 00:00:00.007755919
# 19236  1970-01-01 1970-01-01 00:00:00.007756171 1970-01-01 00:00:00.007756171
#
#                      validation_end                    test_start  \
# 0     1970-01-01 00:00:00.004847832 1970-01-01 00:00:00.004847832
# 1     1970-01-01 00:00:00.004848084 1970-01-01 00:00:00.004848084
# 2     1970-01-01 00:00:00.004848336 1970-01-01 00:00:00.004848336
# 3     1970-01-01 00:00:00.004848588 1970-01-01 00:00:00.004848588
# 4     1970-01-01 00:00:00.004848840 1970-01-01 00:00:00.004848840
# ...                             ...                           ...
# 19232 1970-01-01 00:00:00.009694296 1970-01-01 00:00:00.009694296
# 19233 1970-01-01 00:00:00.009694548 1970-01-01 00:00:00.009694548
# 19234 1970-01-01 00:00:00.009694800 1970-01-01 00:00:00.009694800
# 19235 1970-01-01 00:00:00.009695052 1970-01-01 00:00:00.009695052
# 19236 1970-01-01 00:00:00.009695304 1970-01-01 00:00:00.009695304
#
#                            test_end optimal_horizon  compounded_return
# 0     1970-01-01 00:00:00.004848083   N_Return_half                0.0
# 1     1970-01-01 00:00:00.004848335   N_Return_half                0.0
# 2     1970-01-01 00:00:00.004848587   N_Return_half                0.0
# 3     1970-01-01 00:00:00.004848839   N_Return_half                0.0
# 4     1970-01-01 00:00:00.004849091   N_Return_half                0.0
# ...                             ...             ...                ...
# 19232 1970-01-01 00:00:00.009694547   N_Return_half                0.0
# 19233 1970-01-01 00:00:00.009694799   N_Return_half                0.0
# 19234 1970-01-01 00:00:00.009695051   N_Return_half                0.0
# 19235 1970-01-01 00:00:00.009695303   N_Return_half                0.0
# 19236 1970-01-01 00:00:00.009695555   N_Return_half                0.0
#
# [19237 rows x 8 columns]

# %%
train_end = int(0.3 * len(df_combined))
validation_end = int(0.5 * len(df_combined))
return_cols = ['N_Return_half', 'N_Return', 'N_Return_double']

# Convert DateTime column to datetime if not already
df_combined['DateTime'] = pd.to_datetime(df_combined['DateTime'])
results = []
optimal_horizons = []
iteration = 0

current_date = df_combined['DateTime'].iloc[validation_end]

while current_date <= df_combined['DateTime'].iloc[-1]:
    iteration += 1

    validation_mask = (df_combined['DateTime'] >= df_combined['DateTime'].iloc[train_end]) & (df_combined['DateTime'] < current_date)
    validation_df = df_combined[validation_mask]

    cum_returns = {}
    for col in return_cols:
        returns = validation_df[col].dropna()
        cum_returns[col] = (1 + returns).prod() - 1

    optimal_col = max(cum_returns, key=cum_returns.get)
    optimal_horizons.append(optimal_col)

    next_year = current_date + pd.DateOffset(years=1)
    test_mask = (df_combined['DateTime'] >= current_date) & (df_combined['DateTime'] < next_year)
    test_df = df_combined[test_mask]

    optimal_returns = test_df[optimal_col].dropna()
    compounded_return = (1 + optimal_returns).prod() - 1

    results.append({
        'iteration': iteration,
        'train_start': df_combined['DateTime'].iloc[0],
        'train_end': df_combined['DateTime'].iloc[train_end],
        'validation_start': df_combined['DateTime'].iloc[train_end],
        'validation_end': current_date,
        'test_start': current_date,
        'test_end': min(next_year, df_combined['DateTime'].iloc[-1]),
        'optimal_horizon': optimal_col,
        'compounded_return': compounded_return * 100
    })

    current_date = next_year
    train_end = len(df_combined[df_combined['DateTime'] < current_date])

results_df = pd.DataFrame(results)

all_returns = results_df['compounded_return'] / 100
volatility = np.std(all_returns) * np.sqrt(252) * 100
overall_return = ((1 + all_returns).prod() - 1) * 100

print(results_df)
print("\nOptimal horizons selected:", pd.Series(optimal_horizons).value_counts())
print(f"\nAnnualized Volatility: {volatility:.2f}%")
print(f"Overall Compounded Return: {overall_return:.2f}%")
# Out:
#     iteration         train_start           train_end    validation_start  \
# 0           1 1997-09-10 00:01:00 2005-11-22 02:29:00 2005-11-22 02:29:00
# 1           2 1997-09-10 00:01:00 2012-04-08 17:01:00 2012-04-08 17:01:00
# 2           3 1997-09-10 00:01:00 2013-04-08 00:31:00 2013-04-08 00:31:00
# 3           4 1997-09-10 00:01:00 2014-04-08 00:31:00 2014-04-08 00:31:00
# 4           5 1997-09-10 00:01:00 2015-04-08 00:31:00 2015-04-08 00:31:00
# 5           6 1997-09-10 00:01:00 2016-04-08 00:31:00 2016-04-08 00:31:00
# 6           7 1997-09-10 00:01:00 2017-04-09 17:01:00 2017-04-09 17:01:00
# 7           8 1997-09-10 00:01:00 2018-04-08 17:01:00 2018-04-08 17:01:00
# 8           9 1997-09-10 00:01:00 2019-04-08 00:31:00 2019-04-08 00:31:00
# 9          10 1997-09-10 00:01:00 2020-04-08 00:31:00 2020-04-08 00:31:00
# 10         11 1997-09-10 00:01:00 2021-04-08 00:31:00 2021-04-08 00:31:00
# 11         12 1997-09-10 00:01:00 2022-04-08 00:31:00 2022-04-08 00:31:00
# 12         13 1997-09-10 00:01:00 2023-04-09 17:01:00 2023-04-09 17:01:00
# 13         14 1997-09-10 00:01:00 2024-04-08 00:31:00 2024-04-08 00:31:00
#
#         validation_end          test_start            test_end  \
# 0  2011-04-08 00:31:00 2011-04-08 00:31:00 2012-04-08 00:31:00
# 1  2012-04-08 00:31:00 2012-04-08 00:31:00 2013-04-08 00:31:00
# 2  2013-04-08 00:31:00 2013-04-08 00:31:00 2014-04-08 00:31:00
# 3  2014-04-08 00:31:00 2014-04-08 00:31:00 2015-04-08 00:31:00
# 4  2015-04-08 00:31:00 2015-04-08 00:31:00 2016-04-08 00:31:00
# 5  2016-04-08 00:31:00 2016-04-08 00:31:00 2017-04-08 00:31:00
# 6  2017-04-08 00:31:00 2017-04-08 00:31:00 2018-04-08 00:31:00
# 7  2018-04-08 00:31:00 2018-04-08 00:31:00 2019-04-08 00:31:00
# 8  2019-04-08 00:31:00 2019-04-08 00:31:00 2020-04-08 00:31:00
# 9  2020-04-08 00:31:00 2020-04-08 00:31:00 2021-04-08 00:31:00
# 10 2021-04-08 00:31:00 2021-04-08 00:31:00 2022-04-08 00:31:00
# 11 2022-04-08 00:31:00 2022-04-08 00:31:00 2023-04-08 00:31:00
# 12 2023-04-08 00:31:00 2023-04-08 00:31:00 2024-04-08 00:31:00
# 13 2024-04-08 00:31:00 2024-04-08 00:31:00 2024-12-19 16:00:00
#
#    optimal_horizon  compounded_return
# 0    N_Return_half          55.123150
# 1    N_Return_half          29.975148
# 2    N_Return_half           7.900002
# 3    N_Return_half          18.313646
# 4    N_Return_half          19.223195
# 5    N_Return_half           6.132837
# 6    N_Return_half           2.728130
# 7    N_Return_half           4.392992
# 8    N_Return_half           2.378174
# 9    N_Return_half          10.647013
# 10   N_Return_half         -12.777041
# 11   N_Return_half         -70.621792
# 12   N_Return_half         -23.689760
# 13   N_Return_half         -15.127027
#
# Optimal horizons selected: N_Return_half    14
# Name: count, dtype: int64
#
# Annualized Volatility: 439.74%
# Overall Compounded Return: -34.34%

# %%
results_df.describe()
# Out:
#        iteration          train_start                      train_end  \
# count    14.0000                   14                             14
# mean      7.5000  1997-09-10 00:01:00  2017-05-20 15:39:25.714285824
# min       1.0000  1997-09-10 00:01:00            2005-11-22 02:29:00
# 25%       4.2500  1997-09-10 00:01:00            2014-07-08 06:31:00
# 50%       7.5000  1997-09-10 00:01:00            2017-10-08 17:01:00
# 75%      10.7500  1997-09-10 00:01:00            2021-01-06 18:31:00
# max      14.0000  1997-09-10 00:01:00            2024-04-08 00:31:00
# std       4.1833                  NaN                            NaN
#
#                     validation_start                 validation_end  \
# count                             14                             14
# mean   2017-05-20 15:39:25.714285824  2017-10-07 12:30:59.999999744
# min              2005-11-22 02:29:00            2011-04-08 00:31:00
# 25%              2014-07-08 06:31:00            2014-07-08 06:31:00
# 50%              2017-10-08 17:01:00            2017-10-07 12:31:00
# 75%              2021-01-06 18:31:00            2021-01-06 18:31:00
# max              2024-04-08 00:31:00            2024-04-08 00:31:00
# std                              NaN                            NaN
#
#                           test_start                       test_end  \
# count                             14                             14
# mean   2017-10-07 12:30:59.999999744  2018-09-29 23:54:29.999999744
# min              2011-04-08 00:31:00            2012-04-08 00:31:00
# 25%              2014-07-08 06:31:00            2015-07-08 12:31:00
# 50%              2017-10-07 12:31:00            2018-10-07 12:31:00
# 75%              2021-01-06 18:31:00            2022-01-06 18:31:00
# max              2024-04-08 00:31:00            2024-12-19 16:00:00
# std                              NaN                            NaN
#
#        compounded_return
# count          14.000000
# mean            2.471333
# min           -70.621792
# 25%            -8.988237
# 50%             5.262914
# 75%            16.396988
# max            55.123150
# std            28.746888

# %%
import matplotlib.pyplot as plt

# Plot histogram
plt.hist(results_df['compounded_return'], bins=20, edgecolor='black', alpha=0.7)
plt.xlabel('Compounded Return (%)')
plt.ylabel('Frequency')
plt.title('Histogram of Compounded Returns')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
compounded_return = (1 + results_df['compounded_return'] / 100).prod() - 1
print(f"Compounded Return: {compounded_return * 100:.2f}%")
# Out:
# Compounded Return: -34.34%

# %%
results_df
# Out:
#     iteration         train_start           train_end    validation_start  \
# 0           1 1997-09-10 00:01:00 2005-11-22 02:29:00 2005-11-22 02:29:00
# 1           2 1997-09-10 00:01:00 2012-04-08 17:01:00 2012-04-08 17:01:00
# 2           3 1997-09-10 00:01:00 2013-04-08 00:31:00 2013-04-08 00:31:00
# 3           4 1997-09-10 00:01:00 2014-04-08 00:31:00 2014-04-08 00:31:00
# 4           5 1997-09-10 00:01:00 2015-04-08 00:31:00 2015-04-08 00:31:00
# 5           6 1997-09-10 00:01:00 2016-04-08 00:31:00 2016-04-08 00:31:00
# 6           7 1997-09-10 00:01:00 2017-04-09 17:01:00 2017-04-09 17:01:00
# 7           8 1997-09-10 00:01:00 2018-04-08 17:01:00 2018-04-08 17:01:00
# 8           9 1997-09-10 00:01:00 2019-04-08 00:31:00 2019-04-08 00:31:00
# 9          10 1997-09-10 00:01:00 2020-04-08 00:31:00 2020-04-08 00:31:00
# 10         11 1997-09-10 00:01:00 2021-04-08 00:31:00 2021-04-08 00:31:00
# 11         12 1997-09-10 00:01:00 2022-04-08 00:31:00 2022-04-08 00:31:00
# 12         13 1997-09-10 00:01:00 2023-04-09 17:01:00 2023-04-09 17:01:00
# 13         14 1997-09-10 00:01:00 2024-04-08 00:31:00 2024-04-08 00:31:00
#
#         validation_end          test_start            test_end  \
# 0  2011-04-08 00:31:00 2011-04-08 00:31:00 2012-04-08 00:31:00
# 1  2012-04-08 00:31:00 2012-04-08 00:31:00 2013-04-08 00:31:00
# 2  2013-04-08 00:31:00 2013-04-08 00:31:00 2014-04-08 00:31:00
# 3  2014-04-08 00:31:00 2014-04-08 00:31:00 2015-04-08 00:31:00
# 4  2015-04-08 00:31:00 2015-04-08 00:31:00 2016-04-08 00:31:00
# 5  2016-04-08 00:31:00 2016-04-08 00:31:00 2017-04-08 00:31:00
# 6  2017-04-08 00:31:00 2017-04-08 00:31:00 2018-04-08 00:31:00
# 7  2018-04-08 00:31:00 2018-04-08 00:31:00 2019-04-08 00:31:00
# 8  2019-04-08 00:31:00 2019-04-08 00:31:00 2020-04-08 00:31:00
# 9  2020-04-08 00:31:00 2020-04-08 00:31:00 2021-04-08 00:31:00
# 10 2021-04-08 00:31:00 2021-04-08 00:31:00 2022-04-08 00:31:00
# 11 2022-04-08 00:31:00 2022-04-08 00:31:00 2023-04-08 00:31:00
# 12 2023-04-08 00:31:00 2023-04-08 00:31:00 2024-04-08 00:31:00
# 13 2024-04-08 00:31:00 2024-04-08 00:31:00 2024-12-19 16:00:00
#
#    optimal_horizon  compounded_return
# 0    N_Return_half          55.123150
# 1    N_Return_half          29.975148
# 2    N_Return_half           7.900002
# 3    N_Return_half          18.313646
# 4    N_Return_half          19.223195
# 5    N_Return_half           6.132837
# 6    N_Return_half           2.728130
# 7    N_Return_half           4.392992
# 8    N_Return_half           2.378174
# 9    N_Return_half          10.647013
# 10   N_Return_half         -12.777041
# 11   N_Return_half         -70.621792
# 12   N_Return_half         -23.689760
# 13   N_Return_half         -15.127027

# %%
df_combined.loc[df_combined['Return'].notna(), 'Return']
# Out:
# 1970-01-01 00:00:00.000102675    0.000261
# 1970-01-01 00:00:00.000191130   -0.000229
# 1970-01-01 00:00:00.000224730    0.012553
# 1970-01-01 00:00:00.000254265    0.003439
# 1970-01-01 00:00:00.000255690    0.000000
#                                    ...
# 1970-01-01 00:00:00.009693772   -0.001464
# 1970-01-01 00:00:00.009693773   -0.001627
# 1970-01-01 00:00:00.009693774   -0.001505
# 1970-01-01 00:00:00.009694104   -0.008923
# 1970-01-01 00:00:00.009694105   -0.008515
# Name: Return, Length: 23068, dtype: float64

# %%
# Looking at the geometric average of the entire series of returns not by year to see if grouping by year was done correctly
valid_returns = df_combined['Return'].dropna()
geometric_avg = (np.prod(1 + valid_returns) ** (1 / len(valid_returns))) - 1
print(geometric_avg)

avg_return = sum(annual_returns.values()) / len(annual_returns)
print(avg_return)
# Out:
# -1.21324095059272e-06
# 0.02153005681275683

# %%
annual_returns = df_combined.groupby(df_combined['DateTime'].dt.year)['Return'].mean().to_dict()
annual_returns
# Out:
# {1997: 0.0002606356145955485,
#  1998: -0.00020956893538819717,
#  1999: 0.0004988244574145141,
#  2000: 0.0002684986460893807,
#  2001: -0.0005444645664330749,
#  2002: -0.00023953302427943407,
#  2003: -5.533194836225224e-05,
#  2004: -9.937709768718997e-05,
#  2005: 0.00016534471275487115,
#  2006: 5.8232589402879836e-05,
#  2007: 0.0002746571988829703,
#  2008: 0.00014852595474129738,
#  2009: -0.00018221715084193647,
#  2010: -4.344048817019308e-05,
#  2011: -3.304701673406604e-05,
#  2012: -0.00020994857907724417,
#  2013: 6.255189303160092e-05,
#  2014: 2.3087986043625278e-05,
#  2015: -0.00019676055581657395,
#  2016: -5.077011334314036e-05,
#  2017: 8.835157803330207e-05,
#  2018: -6.597518711908979e-05,
#  2019: -2.5769074671865625e-05,
#  2020: 0.0004969704147510501,
#  2021: 0.00022514998176836494,
#  2022: -0.0005787472358058938,
#  2023: 0.0001427812597372052,
#  2024: 7.529344895350401e-05}

# %%
# Compute geometric mean per year
annual_returns = (
    df_combined.groupby(df_combined['DateTime'].dt.year)['Return']
    .apply(lambda x: (np.prod(1 + x.dropna())) ** (1 / len(x.dropna())) - 1)
    .to_dict()
)

# Print results
print("Annual Geometric Mean Returns:")
for year, ret in annual_returns.items():
    print(f"{year}: {ret:.6f} (or {ret*100:.4f}%)")
# Out:
# Annual Geometric Mean Returns:
# 1997: 0.000261 (or 0.0261%)
# 1998: -0.000218 (or -0.0218%)
# 1999: 0.000489 (or 0.0489%)
# 2000: 0.000258 (or 0.0258%)
# 2001: -0.000550 (or -0.0550%)
# 2002: -0.000249 (or -0.0249%)
# 2003: -0.000061 (or -0.0061%)
# 2004: -0.000101 (or -0.0101%)
# 2005: 0.000164 (or 0.0164%)
# 2006: 0.000056 (or 0.0056%)
# 2007: 0.000272 (or 0.0272%)
# 2008: 0.000136 (or 0.0136%)
# 2009: -0.000191 (or -0.0191%)
# 2010: -0.000048 (or -0.0048%)
# 2011: -0.000038 (or -0.0038%)
# 2012: -0.000213 (or -0.0213%)
# 2013: 0.000061 (or 0.0061%)
# 2014: 0.000022 (or 0.0022%)
# 2015: -0.000199 (or -0.0199%)
# 2016: -0.000052 (or -0.0052%)
# 2017: 0.000088 (or 0.0088%)
# 2018: -0.000068 (or -0.0068%)
# 2019: -0.000027 (or -0.0027%)
# 2020: 0.000492 (or 0.0492%)
# 2021: 0.000224 (or 0.0224%)
# 2022: -0.000596 (or -0.0596%)
# 2023: 0.000140 (or 0.0140%)
# 2024: 0.000072 (or 0.0072%)

# %%
# Looking at the geometric average of the entire series of returns not by year but overall to see if grouping by year was done correctly
valid_returns = df_combined['Return'].dropna()
geometric_avg = (np.prod(1 + valid_returns) ** (1 / len(valid_returns))) - 1
print(geometric_avg)

avg_return = sum(annual_returns.values()) / len(annual_returns)
print(avg_return)

# DOESN'T LINE UP, PROBLEMATIC? - > Does line up when I run it again, not sure why it didn't before
# Out:
# -1.21324095059272e-06
# 4.422338537404416e-06

# %%
df_combined.loc[df_combined['Return'].notna(), 'Return'].describe()
# Out:
# count    23068.000000
# mean         0.000003
# std          0.002987
# min         -0.036467
# 25%         -0.000990
# 50%          0.000000
# 75%          0.001047
# max          0.029750
# Name: Return, dtype: float64

# %% [markdown]
# # **Statistical Model**

# %%
import pandas as pd
from pandas_datareader import data as pdr 
import datetime
import numpy as np
import yfinance as yf
import statsmodels.api as sm

# %% [markdown]
# **This is Consumer Price Index for All Urban Consumers: All Items Less Food Energy - preferred cos Removes volatile food/energy prices → better reflects underlying inflation trends**
#
# **Question: Use this or all items CPI?**

# %% [markdown]
# **The code below downloads US economic indicators (GDP, unemployment, CPI,
# etc.) and S&P 500 returns, then aligns all data to the exact quarterly dates when GDP is released. It ensures no future data leaks by using only values available on or before each GDP release date.t**

# %% [markdown]
# **CHECK IF LAGGING NEEDED!!!**

# %%
import datetime
import pandas as pd
import pandas_datareader as pdr
import yfinance as yf

# --- 1. Get GDP Release Dates (Quarterly) ---
start = datetime.datetime(1997, 1, 1)
end = datetime.datetime.today()
gdp_releases = pdr.DataReader('A191RL1Q225SBEA', 'fred', start, end).index

# --- 2. Download All Economic Data ---
raw_data = {
    # Quarterly
    'gdp_gr': pdr.DataReader('A191RL1Q225SBEA', 'fred', start, end),

    # Monthly
    'NFP': pdr.DataReader('PAYEMS', 'fred', start, end),
    'un_rate': pdr.DataReader('UNRATE', 'fred', start, end),
    'cci': pdr.DataReader('UMCSENT', 'fred', start, end),
    'ret_sales': pdr.DataReader('RSAFS', 'fred', start, end),
    'IPTI': pdr.DataReader('INDPRO', 'fred', start, end),
    'cpi': pdr.DataReader('CPIAUCSL', 'fred', start, end),
    'TXBPPRIVSA': pdr.DataReader('TXBPPRIVSA', 'fred', start, end),  # Added this line

    # Daily
    'ffr': pdr.DataReader('DFF', 'fred', start, end),

    # S&P 500 (via yfinance)
    'sp500': yf.download('^GSPC', start=start, end=end)['Close']
}

# --- 3. Align ALL Variables to GDP Release Dates ---
economic_data = pd.DataFrame(index=gdp_releases)

for name, series in raw_data.items():
    if name == 'gdp_gr':
        economic_data[name] = series  # Already aligned
    elif name == 'sp500':
        # Calculate quarterly returns between GDP releases
        prices_on_releases = series.reindex(gdp_releases, method='bfill')
        economic_data['SP500'] = prices_on_releases.pct_change()
    elif name == 'ffr':
        # Take FFR value ON the GDP release day
        economic_data[name] = series.reindex(gdp_releases, method='bfill')
    else:
        # Monthly series: last release BEFORE GDP date
        economic_data[name] = series.reindex(gdp_releases, method='ffill')

# --- 4. Clean and Verify ---
economic_data = economic_data.dropna(subset=['gdp_gr'])  # Remove quarters without GDP
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-01-01     2.6  121357      5.3   97.4     223481   77.5135  159.400
# 1997-04-01     6.8  122288      5.1  101.4     224615   78.9848  159.900
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2669  315.564
#
#               TXBPPRIVSA   ffr     SP500
# DATE
# 1997-01-01   9089.992363  6.26       NaN
# 1997-04-01  10519.564949  6.18  0.030705
# 1997-07-01  10145.968977  6.24  0.172964
# 1997-10-01  10842.090215  5.65  0.072253
# 1998-01-01   9467.306041  5.84  0.020546
# ...                  ...   ...       ...
# 2023-10-01  19511.605429  5.33 -0.037526
# 2024-01-01  19808.201310  5.33  0.105970
# 2024-04-01  20100.956606  5.33  0.105620
# 2024-07-01  18892.275746  5.33  0.044113
# 2024-10-01  19386.722110  4.83  0.042677
#
# [112 rows x 10 columns]

# %%
economic_data = economic_data.dropna()
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-04-01     6.8  122288      5.1  101.4     224615   78.9848  159.900
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# 1998-04-01     3.8  125446      4.3  108.7     235986   84.6339  162.200
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2669  315.564
#
#               TXBPPRIVSA   ffr     SP500
# DATE
# 1997-04-01  10519.564949  6.18  0.030705
# 1997-07-01  10145.968977  6.24  0.172964
# 1997-10-01  10842.090215  5.65  0.072253
# 1998-01-01   9467.306041  5.84  0.020546
# 1998-04-01  12156.664122  5.72  0.136518
# ...                  ...   ...       ...
# 2023-10-01  19511.605429  5.33 -0.037526
# 2024-01-01  19808.201310  5.33  0.105970
# 2024-04-01  20100.956606  5.33  0.105620
# 2024-07-01  18892.275746  5.33  0.044113
# 2024-10-01  19386.722110  4.83  0.042677
#
# [111 rows x 10 columns]

# %% [markdown]
# **Now we do Lasso penalization to see which of the macro variables are useful**

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
from statsmodels.api import OLS
import sklearn.model_selection as skm
import sklearn.linear_model as skl
from sklearn.preprocessing import StandardScaler
from ISLP import load_data
from ISLP.models import ModelSpec as MS
from functools import partial
from ISLP.models import \
(Stepwise,
sklearn_selected,
sklearn_selection_path)
from l0bnb import fit_path

# %%
economic_data.columns
# Out:
# Index(['gdp_gr', 'NFP', 'un_rate', 'cci', 'ret_sales', 'IPTI', 'cpi',
#        'TXBPPRIVSA', 'ffr', 'SP500'],
#       dtype='object')

# %%
economic_data['gdp_gr_L1'] = economic_data['gdp_gr'].shift(1)
economic_data['ffr_L1'] = economic_data['ffr'].shift(1)
economic_data['NFP_L1'] = economic_data['NFP'].shift(1)
economic_data['un_rate_L1'] = economic_data['un_rate'].shift(1)
economic_data['cci_L1'] = economic_data['cci'].shift(1)
economic_data['ret_sales_L1'] = economic_data['ret_sales'].shift(1)
economic_data['IPTI_L1'] = economic_data['IPTI'].shift(1)
economic_data['cpi_L1'] = economic_data['cpi'].shift(1)
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['gdp_gr_L1'] = economic_data['gdp_gr'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['ffr_L1'] = economic_data['ffr'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['NFP_L1'] = economic_data['NFP'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['un_rate_L1'] = economic_data['un_rate'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['cci_L1'] = economic_data['cci'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['ret_sales_L1'] = economic_data['ret_sales'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['IPTI_L1'] = economic_data['IPTI'].shift(1)
# C:\Users\User1\AppData\Local\Temp\ipykernel_12052\1870053740.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic_data['cpi_L1'] = economic_data['cpi'].shift(1)

# %%
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-04-01     6.8  122288      5.1  101.4     224615   78.9848  159.900
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# 1998-04-01     3.8  125446      4.3  108.7     235986   84.6339  162.200
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2669  315.564
#
#               TXBPPRIVSA   ffr     SP500  gdp_gr_L1  ffr_L1    NFP_L1  \
# DATE
# 1997-04-01  10519.564949  6.18  0.030705        NaN     NaN       NaN
# 1997-07-01  10145.968977  6.24  0.172964        6.8    6.18  122288.0
# 1997-10-01  10842.090215  5.65  0.072253        5.1    6.24  123114.0
# 1998-01-01   9467.306041  5.84  0.020546        3.5    5.65  123924.0
# 1998-04-01  12156.664122  5.72  0.136518        4.1    5.84  124806.0
# ...                  ...   ...       ...        ...     ...       ...
# 2023-10-01  19511.605429  5.33 -0.037526        4.4    5.08  156019.0
# 2024-01-01  19808.201310  5.33  0.105970        3.2    5.33  156520.0
# 2024-04-01  20100.956606  5.33  0.105620        1.6    5.33  157049.0
# 2024-07-01  18892.275746  5.33  0.044113        3.0    5.33  157635.0
# 2024-10-01  19386.722110  4.83  0.042677        3.1    5.33  158003.0
#
#             un_rate_L1  cci_L1  ret_sales_L1   IPTI_L1   cpi_L1
# DATE
# 1997-04-01         NaN     NaN           NaN       NaN      NaN
# 1997-07-01         5.1   101.4      224615.0   78.9848  159.900
# 1997-10-01         4.9   107.1      228703.0   80.4666  160.400
# 1998-01-01         4.7   105.6      229836.0   82.7656  161.500
# 1998-04-01         4.6   106.6      231587.0   84.1564  162.000
# ...                ...     ...           ...       ...      ...
# 2023-10-01         3.5    71.5      690641.0  103.0722  304.615
# 2024-01-01         3.9    63.8      699365.0  102.5781  307.653
# 2024-04-01         3.7    79.0      694131.0  101.4830  309.794
# 2024-07-01         3.9    77.2      702681.0  102.3568  313.016
# 2024-10-01         4.2    66.4      710851.0  102.5192  313.566
#
# [111 rows x 18 columns]

# %%
economic_data = economic_data.dropna()
economic_data
# Out:
#             gdp_gr     NFP  un_rate    cci  ret_sales      IPTI      cpi  \
# DATE
# 1997-07-01     5.1  123114      4.9  107.1     228703   80.4666  160.400
# 1997-10-01     3.5  123924      4.7  105.6     229836   82.7656  161.500
# 1998-01-01     4.1  124806      4.6  106.6     231587   84.1564  162.000
# 1998-04-01     3.8  125446      4.3  108.7     235986   84.6339  162.200
# 1998-07-01     5.1  126211      4.5  105.2     237411   84.3445  163.200
# ...            ...     ...      ...    ...        ...       ...      ...
# 2023-10-01     3.2  156520      3.9   63.8     699365  102.5781  307.653
# 2024-01-01     1.6  157049      3.7   79.0     694131  101.4830  309.794
# 2024-04-01     3.0  157635      3.9   77.2     702681  102.3568  313.016
# 2024-07-01     3.1  158003      4.2   66.4     710851  102.5192  313.566
# 2024-10-01     2.4  158358      4.1   70.5     720393  102.2669  315.564
#
#               TXBPPRIVSA   ffr     SP500  gdp_gr_L1  ffr_L1    NFP_L1  \
# DATE
# 1997-07-01  10145.968977  6.24  0.172964        6.8    6.18  122288.0
# 1997-10-01  10842.090215  5.65  0.072253        5.1    6.24  123114.0
# 1998-01-01   9467.306041  5.84  0.020546        3.5    5.65  123924.0
# 1998-04-01  12156.664122  5.72  0.136518        4.1    5.84  124806.0
# 1998-07-01  13269.278989  6.35  0.036466        3.8    5.72  125446.0
# ...                  ...   ...       ...        ...     ...       ...
# 2023-10-01  19511.605429  5.33 -0.037526        4.4    5.08  156019.0
# 2024-01-01  19808.201310  5.33  0.105970        3.2    5.33  156520.0
# 2024-04-01  20100.956606  5.33  0.105620        1.6    5.33  157049.0
# 2024-07-01  18892.275746  5.33  0.044113        3.0    5.33  157635.0
# 2024-10-01  19386.722110  4.83  0.042677        3.1    5.33  158003.0
#
#             un_rate_L1  cci_L1  ret_sales_L1   IPTI_L1   cpi_L1
# DATE
# 1997-07-01         5.1   101.4      224615.0   78.9848  159.900
# 1997-10-01         4.9   107.1      228703.0   80.4666  160.400
# 1998-01-01         4.7   105.6      229836.0   82.7656  161.500
# 1998-04-01         4.6   106.6      231587.0   84.1564  162.000
# 1998-07-01         4.3   108.7      235986.0   84.6339  162.200
# ...                ...     ...           ...       ...      ...
# 2023-10-01         3.5    71.5      690641.0  103.0722  304.615
# 2024-01-01         3.9    63.8      699365.0  102.5781  307.653
# 2024-04-01         3.7    79.0      694131.0  101.4830  309.794
# 2024-07-01         3.9    77.2      702681.0  102.3568  313.016
# 2024-10-01         4.2    66.4      710851.0  102.5192  313.566
#
# [110 rows x 18 columns]

# %%
train_splitpoint = round(111*0.5)
train = economic_data.iloc[:train_splitpoint]
test = economic_data.iloc[train_splitpoint:]

# %%
# I first run Lasso on this dataset to see if it works etc.
from sklearn.pipeline import Pipeline
scaler = StandardScaler(with_mean=True, with_std=True)

lambdas = np.linspace(0.001, 0.2, 20)

y = train['SP500']
model = MS(train.columns.drop(['gdp_gr', 'NFP', 'un_rate', 'cci', 'ret_sales', 'IPTI', 'cpi', 'ffr',
       'SP500']), intercept=False)
D = model.fit_transform(train)
feature_names = list(D.columns)
X = np.asarray(D)

validation = skm.ShuffleSplit(n_splits=1,
test_size=0.2,
random_state=0)

K=5
kfold = skm.KFold(K,
random_state=0,
shuffle=True)


lasso = skl.ElasticNet(alpha=lambdas[0], l1_ratio=1)
pipe = Pipeline(steps=[('scaler', scaler), ('lasso', lasso)])
pipe.fit(X, y)

param_grid = {'lasso__alpha': lambdas}
grid = skm.GridSearchCV(pipe,
param_grid,
cv=validation,
scoring='neg_mean_squared_error')
grid.fit(X, y)
grid.best_params_['lasso__alpha']
grid.best_estimator_

lassoCV = skl.ElasticNetCV(alphas=lambdas,
l1_ratio=1,
cv=kfold)
pipeCV = Pipeline(steps=[('scaler', scaler),
('lasso', lassoCV)])

pipeCV.fit(X, y)

tuned_lasso = pipeCV.named_steps['lasso']
tuned_lasso.coef_
# Out:
# array([-0.        ,  0.03040955, -0.        , -0.00566775,  0.00520073,
#        -0.        ,  0.        , -0.        ,  0.        ])

# %%
nonzero_mask = tuned_lasso.coef_ != 0
nonzero_coefs = tuned_lasso.coef_[nonzero_mask]
nonzero_features = [feature_names[i] for i in np.where(nonzero_mask)[0]]

# Create a DataFrame of results
coef_results = pd.DataFrame({
    'Feature': nonzero_features,
    'Coefficient': nonzero_coefs
}).sort_values('Coefficient', key=abs, ascending=False)

print("Nonzero coefficients:")
print(coef_results)
# Out:
# Nonzero coefficients:
#       Feature  Coefficient
# 0   gdp_gr_L1     0.030410
# 1      NFP_L1    -0.005668
# 2  un_rate_L1     0.005201

# %% [markdown]
# **Now we run standard OLS with all non-zero coefficient variables as explanatory variables to see which are significant**

# %%
X = sm.add_constant(train[['gdp_gr_L1','NFP_L1','un_rate_L1']])

model = sm.OLS(y, X).fit(cov_type = 'HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  SP500   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     5.961
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):            0.00143
# Time:                        21:48:00   Log-Likelihood:                 62.568
# No. Observations:                  56   AIC:                            -117.1
# Df Residuals:                      52   BIC:                            -109.0
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2694      0.400      0.674      0.500      -0.514       1.053
# gdp_gr_L1      0.0151      0.004      3.416      0.001       0.006       0.024
# NFP_L1     -2.684e-06   2.84e-06     -0.945      0.345   -8.25e-06    2.88e-06
# un_rate_L1     0.0108      0.009      1.233      0.218      -0.006       0.028
# ==============================================================================
# Omnibus:                        4.396   Durbin-Watson:                   2.321
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.511
# Skew:                          -0.591   Prob(JB):                        0.173
# Kurtosis:                       3.326   Cond. No.                     5.42e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 5.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Now we do standard OLS with all variables to see differences**

# %%
economic_data.columns
# Out:
# Index(['gdp_gr', 'NFP', 'un_rate', 'cci', 'ret_sales', 'IPTI', 'cpi',
#        'TXBPPRIVSA', 'ffr', 'SP500', 'gdp_gr_L1', 'ffr_L1', 'NFP_L1',
#        'un_rate_L1', 'cci_L1', 'ret_sales_L1', 'IPTI_L1', 'cpi_L1'],
#       dtype='object')

# %%
X = sm.add_constant(train[['gdp_gr_L1', 'ffr_L1', 'NFP_L1', 'un_rate_L1', 'cci_L1', 'ret_sales_L1', 'IPTI_L1', 'cpi_L1']])

model = sm.OLS(y, X).fit(cov_type = 'HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  SP500   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     3.514
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):            0.00293
# Time:                        21:48:13   Log-Likelihood:                 64.705
# No. Observations:                  56   AIC:                            -111.4
# Df Residuals:                      47   BIC:                            -93.18
# Df Model:                           8
# Covariance Type:                  HC3
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.1571      1.254      1.721      0.085      -0.300       4.614
# gdp_gr_L1        0.0146      0.006      2.367      0.018       0.003       0.027
# ffr_L1           0.0092      0.012      0.753      0.451      -0.015       0.033
# NFP_L1       -1.215e-05   1.21e-05     -1.006      0.314   -3.58e-05    1.15e-05
# un_rate_L1      -0.0039      0.041     -0.093      0.926      -0.085       0.077
# cci_L1          -0.0019      0.002     -0.883      0.377      -0.006       0.002
# ret_sales_L1  2.523e-06    2.3e-06      1.096      0.273   -1.99e-06    7.04e-06
# IPTI_L1         -0.0069      0.011     -0.610      0.542      -0.029       0.015
# cpi_L1          -0.0030      0.007     -0.423      0.672      -0.017       0.011
# ==============================================================================
# Omnibus:                        5.576   Durbin-Watson:                   2.400
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                4.530
# Skew:                          -0.618   Prob(JB):                        0.104
# Kurtosis:                       3.644   Cond. No.                     4.24e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 4.24e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
